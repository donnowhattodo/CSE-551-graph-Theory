# %%
# !pip install hypernetx matplotlib scikit-learn
# Out:
# Collecting hypernetx
#   Downloading hypernetx-2.3.8-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Collecting celluloid>=0.2.0 (from hypernetx)
#   Downloading celluloid-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting decorator>=5.1.1 (from hypernetx)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting igraph>=0.11.4 (from hypernetx)
#   Downloading igraph-0.11.6-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: networkx>=3.3 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (3.4.2)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (2.2.2)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Collecting texttable>=1.6.2 (from igraph>=0.11.4->hypernetx)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.2->hypernetx) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.2->hypernetx) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading hypernetx-2.3.8-py3-none-any.whl (583 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.8/583.8 kB 10.2 MB/s eta 0:00:00
# Downloading celluloid-0.2.0-py3-none-any.whl (5.4 kB)
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading igraph-0.11.6-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.7 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, decorator, celluloid, hypernetx
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# Successfully installed celluloid-0.2.0 decorator-5.1.1 hypernetx-2.3.8 igraph-0.11.6 texttable-1.7.0

# %%
# !pip install networkx numpy scikit-learn matplotlib
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from python-louvain) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-louvain) (1.26.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***Common Communities (Coverting to bipartite)***

# %%
import networkx as nx
import hypernetx as hnx
import community as community_louvain  # For Louvain on graph
from collections import defaultdict

# %%
# Step 1: Load undirected YouTube network data and create both graph and hypergraph representations
def load_youtube_network_data(filename):
    """Load the YouTube network data and return graph and hypergraph representations."""
    G = nx.Graph()  # For the graph-based representation
    hyperedges = defaultdict(list)  # For the hypergraph-based representation

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):  # Ignore comments
                nodes = list(map(int, line.strip().split()))
                u, v = nodes[0], nodes[1:]
                G.add_edges_from([(u, vi) for vi in v])  # Add edges to graph

                # For hypergraph, treat the first node as a "hyperedge" connected to all subsequent nodes
                hyperedges[u] = v

    H = hnx.Hypergraph(hyperedges)  # Create the hypergraph using HyperNetX
    return G, H

# Step 2: Convert hypergraph to bipartite graph manually
def convert_hypergraph_to_bipartite(H):
    """Convert hypergraph to a bipartite graph."""
    B = nx.Graph()  # Bipartite graph

    for edge_id, nodes in H.incidence_dict.items():
        # Add an edge between the hyperedge (edge_id) and each node in the hyperedge
        for node in nodes:
            B.add_edge(f"edge_{edge_id}", f"node_{node}")

    return B

# %%
# Step 3: Apply Louvain community detection on graph
def apply_louvain_on_graph(G):
    """Apply Louvain algorithm for community detection on graph and return partitions."""
    partition = community_louvain.best_partition(G)
    return partition

# Step 4: Apply Louvain-like community detection on hypergraph (via bipartite graph)
def apply_louvain_on_hypergraph(H):
    """Apply Louvain-like algorithm on hypergraph (based on converting to bipartite graph) and return partitions."""
    bipartite_graph = convert_hypergraph_to_bipartite(H)  # Convert hypergraph to bipartite graph
    partition = community_louvain.best_partition(bipartite_graph)  # Apply Louvain on bipartite graph
    return partition

# %%
# Step 5: Find common communities between graph and hypergraph partitions
def find_common_communities(graph_partition, hypergraph_partition):
    """Find common communities between the graph and hypergraph partitions."""
    common_communities = defaultdict(list)

    for node in graph_partition:
        # Ensure that the node exists in the hypergraph partition
        hyper_node = f"node_{node}"  # In bipartite graph, nodes are prefixed with "node_"
        if hyper_node in hypergraph_partition and graph_partition[node] == hypergraph_partition[hyper_node]:
            common_communities[graph_partition[node]].append(node)

    return common_communities

# %%
def main():
    filename = '/content/drive/My Drive/CSE551/Undirected_Youtube_network.txt' # Path to the YouTube network data

    # Step 1: Load data and create graph/hypergraph
    G, H = load_youtube_network_data(filename)
    print(f"Loaded graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Loaded hypergraph with {len(H.edges)} hyperedges.")

    # Step 2: Apply community detection on graph
    graph_partition = apply_louvain_on_graph(G)
    print(f"Detected {len(set(graph_partition.values()))} communities in the graph.")

    # Step 3: Apply community detection on hypergraph
    hypergraph_partition = apply_louvain_on_hypergraph(H)
    print(f"Detected {len(set(hypergraph_partition.values()))} communities in the hypergraph.")

    # Step 4: Find common communities
    common_communities = find_common_communities(graph_partition, hypergraph_partition)
    print(f"Found {len(common_communities)} common communities between graph and hypergraph.")

    # Print common communities
    for community, nodes in common_communities.items():
        print(f"Community {community} (common): Nodes = {nodes}")

if __name__ == "__main__":
    main()
# Out:
# Loaded graph with 1134890 nodes and 2987624 edges.
# Loaded hypergraph with 374785 hyperedges.
# Detected 5788 communities in the graph.
# Detected 291987 communities in the hypergraph.
# Found 2 common communities between graph and hypergraph.
# Community 0 (common): Nodes = [665258]
# Community 1838 (common): Nodes = [932537]

# %% [markdown]
# ---
#
#
#
# ---

# %%
# Step 1: Load undirected YouTube network data and create both graph and hypergraph representations
def load_youtube_network_data(filename):
    """Load the YouTube network data and return graph and hypergraph representations."""
    G = nx.Graph()  # For the graph-based representation
    hyperedges = defaultdict(list)  # For the hypergraph-based representation

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):  # Ignore comments
                nodes = list(map(int, line.strip().split()))
                u, v = nodes[0], nodes[1:]
                G.add_edges_from([(u, vi) for vi in v])  # Add edges to graph

                # For hypergraph, treat the first node as a "hyperedge" connected to all subsequent nodes
                hyperedges[u] = v

    H = hnx.Hypergraph(hyperedges)  # Create the hypergraph using HyperNetX
    return G, H

# Step 2: Convert hypergraph to bipartite graph manually
def convert_hypergraph_to_bipartite(H):
    """Convert hypergraph to a bipartite graph."""
    B = nx.Graph()  # Bipartite graph

    for edge_id, nodes in H.incidence_dict.items():
        # Add an edge between the hyperedge (edge_id) and each node in the hyperedge
        for node in nodes:
            B.add_edge(f"edge_{edge_id}", f"node_{node}")

    return B

# Step 3: Apply Louvain community detection on graph
def apply_louvain_on_graph(G):
    """Apply Louvain algorithm for community detection on graph and return partitions."""
    partition = community_louvain.best_partition(G)
    return partition

# Step 4: Apply Louvain-like community detection on hypergraph (via bipartite graph)
def apply_louvain_on_hypergraph(H):
    """Apply Louvain-like algorithm on hypergraph (based on converting to bipartite graph) and return partitions."""
    bipartite_graph = convert_hypergraph_to_bipartite(H)  # Convert hypergraph to bipartite graph
    partition = community_louvain.best_partition(bipartite_graph)  # Apply Louvain on bipartite graph
    return partition

# Step 5: Find common communities between graph and hypergraph partitions
def find_common_communities(graph_partition, hypergraph_partition):
    """Find common communities between the graph and hypergraph partitions."""
    common_communities = defaultdict(list)

    # Convert hypergraph partition node names back to their original form
    hypergraph_partition_cleaned = {
        int(node.split('_')[1]): community
        for node, community in hypergraph_partition.items() if node.startswith('node_')
    }

    for node in graph_partition:
        if node in hypergraph_partition_cleaned and graph_partition[node] == hypergraph_partition_cleaned[node]:
            common_communities[graph_partition[node]].append(node)

    return common_communities

# %%
# Main function
def main():
    filename = '/content/drive/My Drive/CSE551/Undirected_Youtube_network.txt' # Path to the YouTube network data

    # Step 1: Load data and create graph/hypergraph
    G, H = load_youtube_network_data(filename)
    print(f"Loaded graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Loaded hypergraph with {len(H.edges)} hyperedges.")

    # Step 2: Apply community detection on graph
    graph_partition = apply_louvain_on_graph(G)
    print(f"Detected {len(set(graph_partition.values()))} communities in the graph.")

    # Step 3: Apply community detection on hypergraph
    hypergraph_partition = apply_louvain_on_hypergraph(H)
    print(f"Detected {len(set(hypergraph_partition.values()))} communities in the hypergraph.")

    # Step 4: Find common communities
    common_communities = find_common_communities(graph_partition, hypergraph_partition)
    print(f"Found {len(common_communities)} common communities between graph and hypergraph.")

    # Step 5: Print common communities
    for community, nodes in common_communities.items():
        print(f"Community {community} (common): Nodes = {nodes}")

if __name__ == "__main__":
    main()
# Out:
# Loaded graph with 1134890 nodes and 2987624 edges.
# Loaded hypergraph with 374785 hyperedges.
# Detected 7191 communities in the graph.
# Detected 291987 communities in the hypergraph.
# Found 1 common communities between graph and hypergraph.
# Community 0 (common): Nodes = [665258]

# %% [markdown]
# # ***Simillar communities***

# %%
import networkx as nx
import hypernetx as hnx
import community as community_louvain  # For Louvain on graph
from collections import defaultdict
from itertools import combinations

# %%
# Step 1: Load undirected YouTube network data and create both graph and hypergraph representations
def load_youtube_network_data(filename):
    """Load the YouTube network data and return graph and hypergraph representations."""
    G = nx.Graph()  # For the graph-based representation
    hyperedges = defaultdict(list)  # For the hypergraph-based representation

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):  # Ignore comments
                nodes = list(map(int, line.strip().split()))
                u, v = nodes[0], nodes[1:]
                G.add_edges_from([(u, vi) for vi in v])  # Add edges to graph

                # For hypergraph, treat the first node as a "hyperedge" connected to all subsequent nodes
                hyperedges[u] = v

    H = hnx.Hypergraph(hyperedges)  # Create the hypergraph using HyperNetX
    return G, H

# Step 2: Convert hypergraph to bipartite graph manually
def convert_hypergraph_to_bipartite(H):
    """Convert hypergraph to a bipartite graph."""
    B = nx.Graph()  # Bipartite graph

    for edge_id, nodes in H.incidence_dict.items():
        # Add an edge between the hyperedge (edge_id) and each node in the hyperedge
        for node in nodes:
            B.add_edge(f"edge_{edge_id}", f"node_{node}")

    return B

# Step 3: Apply Louvain community detection on graph
def apply_louvain_on_graph(G):
    """Apply Louvain algorithm for community detection on graph and return partitions."""
    partition = community_louvain.best_partition(G)
    return partition

# Step 4: Apply Louvain-like community detection on hypergraph (via bipartite graph)
def apply_louvain_on_hypergraph(H):
    """Apply Louvain-like algorithm on hypergraph (based on converting to bipartite graph) and return partitions."""
    bipartite_graph = convert_hypergraph_to_bipartite(H)  # Convert hypergraph to bipartite graph
    partition = community_louvain.best_partition(bipartite_graph)  # Apply Louvain on bipartite graph
    return partition

# %%
# Helper function: Group nodes by community
def group_nodes_by_community(partition):
    """Group nodes by their community from the partition."""
    communities = defaultdict(list)
    for node, community in partition.items():
        communities[community].append(node)
    return communities

# Step 5: Calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    """Calculate Jaccard similarity between two sets."""
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union != 0 else 0

# %%
# Step 6: Find similar communities based on Jaccard similarity
def find_similar_communities(graph_partition, hypergraph_partition, threshold=0.1):
    """Find similar communities between the graph and hypergraph partitions."""
    graph_communities = group_nodes_by_community(graph_partition)
    hypergraph_communities = group_nodes_by_community(hypergraph_partition)

    similar_communities = []

    for g_comm, g_nodes in graph_communities.items():
        g_set = set(g_nodes)
        for h_comm, h_nodes in hypergraph_communities.items():
            h_set = set(int(node.split('_')[1]) for node in h_nodes if node.startswith('node_'))
            similarity = jaccard_similarity(g_set, h_set)
            if similarity > threshold:
                similar_communities.append((g_comm, h_comm, similarity, g_set & h_set))

    return similar_communities

# Step 7: Find the community pair with the maximum number of shared nodes
def find_maximum_shared_nodes(similar_communities):
    """Find the pair of communities with the maximum number of shared nodes."""
    max_shared_nodes = 0
    max_shared_pair = None

    for g_comm, h_comm, similarity, common_nodes in similar_communities:
        if len(common_nodes) > max_shared_nodes:
            max_shared_nodes = len(common_nodes)
            max_shared_pair = (g_comm, h_comm, common_nodes)

    return max_shared_pair, max_shared_nodes

# %%
# Main function
def main():
    filename = '/content/drive/My Drive/CSE551/Undirected_Youtube_network.txt' # Path to the YouTube network data

    # Step 1: Load data and create graph/hypergraph
    G, H = load_youtube_network_data(filename)
    print(f"Loaded graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Loaded hypergraph with {len(H.edges)} hyperedges.")

    # Step 2: Apply community detection on graph
    graph_partition = apply_louvain_on_graph(G)
    graph_communities = group_nodes_by_community(graph_partition)
    print(f"Detected {len(graph_communities)} communities in the graph.")

    # Step 3: Apply community detection on hypergraph
    hypergraph_partition = apply_louvain_on_hypergraph(H)
    hypergraph_communities = group_nodes_by_community(hypergraph_partition)
    print(f"Detected {len(hypergraph_communities)} communities in the hypergraph.")

    # Step 4: Print information about the communities in the graph
    print("\nGraph communities:")
    for comm, nodes in graph_communities.items():
        print(f"Community {comm}: {nodes}")

    # Step 5: Print information about the communities in the hypergraph
    print("\nHypergraph communities:")
    for comm, nodes in hypergraph_communities.items():
        print(f"Community {comm}: {nodes}")

    # Step 6: Find similar communities based on Jaccard similarity
    similar_communities = find_similar_communities(graph_partition, hypergraph_partition, threshold=0.2)
    print(f"\nFound {len(similar_communities)} similar communities between graph and hypergraph with a threshold of 0.2.")

    # Step 7: Print similar communities and shared nodes
    for g_comm, h_comm, similarity, common_nodes in similar_communities:
        print(f"Graph community {g_comm} and Hypergraph community {h_comm} have a Jaccard similarity of {similarity:.2f}.")
        print(f"Common nodes: {common_nodes}")

    # Step 8: Find and print the community pair with the maximum number of shared nodes
    max_shared_pair, max_shared_nodes = find_maximum_shared_nodes(similar_communities)
    if max_shared_pair:
        g_comm, h_comm, common_nodes = max_shared_pair
        print(f"\nCommunity pair with the maximum number of shared nodes:")
        print(f"Graph community {g_comm} and Hypergraph community {h_comm} share {max_shared_nodes} nodes.")
        print(f"Shared nodes: {common_nodes}")
    else:
        print("\nNo communities with shared nodes found.")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Community 114373: ['edge_1152678', 'node_1152680']
# Community 114374: ['edge_1152680', 'node_1152681']
# Community 114376: ['edge_1152700', 'node_1157821']
# Community 114378: ['edge_1152709', 'node_1152710']
# Community 114380: ['edge_1152713', 'node_1152714']
# Community 114382: ['edge_1152730', 'node_1157822']
# Community 114383: ['edge_1152733', 'node_1152736']
# Community 114386: ['edge_1152760', 'node_1152761']
# Community 114388: ['edge_1152792', 'node_1152793']
# Community 114390: ['edge_1152807', 'node_1152809']
# Community 114391: ['edge_1152810', 'node_1152811']
# Community 114393: ['edge_1152838', 'node_1157823']
# Community 114395: ['edge_1152844', 'node_1152845']
# Community 114397: ['edge_1152865', 'node_1157825']
# Community 114399: ['edge_1152874', 'node_1152881']
# Community 114402: ['edge_1152882', 'node_1157826']
# Community 114403: ['edge_1152927', 'node_1152931', 'edge_1152930']
# Community 114406: ['edge_1152936', 'node_1152949']
# Community 114407: ['edge_1152997', 'node_1152999']
# Community 114409: ['edge_1153025', 'node_1153026']
# Community 114411: ['edge_1153080', 'node_1153081']
# Community 114413: ['edge_1153081', 'node_1153082']
# Community 114416: ['edge_1153093', 'node_1153096']
# Community 114417: ['edge_1153095', 'node_1153097']
# Community 114420: ['edge_1153108', 'node_1153109']
# Community 114421: ['edge_1153132', 'node_1153137']
# Community 114423: ['edge_1153141', 'node_1153142']
# Community 114425: ['edge_1153148', 'node_1153181']
# Community 114426: ['edge_1153153', 'node_1153185']
# Community 114428: ['edge_1153154', 'node_1153182']
# Community 114431: ['edge_1153158', 'node_1153186']
# Community 114433: ['edge_1153163', 'node_1153187']
# Community 114434: ['edge_1153179', 'node_1153188']
# Community 114435: ['edge_1153184', 'node_1153189']
# Community 114438: ['edge_1153191', 'node_1153192']
# Community 114439: ['edge_1153195', 'node_1153200']
# Community 114441: ['edge_1153225', 'node_1153227', 'edge_1153226']
# Community 114444: ['edge_1153227', 'node_1153229']
# Community 114445: ['edge_1153237', 'node_1153239']
# Community 114447: ['edge_1153243', 'node_1153244']
# Community 114448: ['edge_1153245', 'node_1153246']
# Community 114449: ['edge_1153261', 'node_1153285']
# Community 114451: ['edge_1153262', 'node_1153287']
# Community 114452: ['edge_1153280', 'node_1153288']
# Community 114454: ['edge_1153283', 'node_1153291']
# Community 114455: ['edge_1153285', 'node_1153289']
# Community 114458: ['edge_1153289', 'node_1153295']
# Community 114460: ['edge_1153291', 'node_1153296']
# Community 114462: ['edge_1153296', 'node_1153297']
# Community 114464: ['edge_1153308', 'node_1153310']
# Community 114465: ['edge_1153343', 'node_1153346']
# Community 114468: ['edge_1153349', 'node_1153351']
# Community 114469: ['edge_1153355', 'node_1153356']
# Community 114471: ['edge_1153360', 'node_1153361']
# Community 114473: ['edge_1153362', 'node_1153363']
# Community 114476: ['edge_1153369', 'node_1153371']
# Community 114478: ['edge_1153419', 'node_1157714']
# Community 114480: ['edge_1153422', 'node_1153425']
# Community 114482: ['edge_1153502', 'node_1157827']
# Community 114483: ['edge_1153504', 'node_1153506']
# Community 114484: ['edge_1153505', 'node_1153507']
# Community 114486: ['edge_1153509', 'node_1153512']
# Community 114488: ['edge_1153510', 'node_1153513']
# Community 114490: ['edge_1153515', 'node_1153521']
# Community 114493: ['edge_1153519', 'node_1153524']
# Community 114495: ['edge_1153520', 'node_1153523']
# Community 114497: ['edge_1153534', 'node_1153536']
# Community 114499: ['edge_1153562', 'node_1153573']
# Community 114500: ['edge_1153570', 'node_1153574']
# Community 114502: ['edge_1153573', 'node_1153575']
# Community 114505: ['edge_1153580', 'node_1153581']
# Community 114506: ['edge_1153583', 'node_1153596']
# Community 114507: ['edge_1153584', 'node_1153594']
# Community 114508: ['edge_1153618', 'node_1153623']
# Community 114509: ['edge_1153631', 'node_1153633']
# Community 114511: ['edge_1153641', 'node_1153643']
# Community 114512: ['edge_1153661', 'node_1153662']
# Community 114514: ['edge_1153662', 'node_1153664']
# Community 114515: ['edge_1153669', 'node_1153671']
# Community 114516: ['edge_1153683', 'node_1153687']
# Community 114518: ['edge_1153696', 'node_1153697']
# Community 114520: ['edge_1153702', 'node_1153709']
# Community 114523: ['edge_1153705', 'node_1153712']
# Community 114525: ['edge_1153710', 'node_1153714']
# Community 114527: ['edge_1153711', 'node_1153715']
# Community 114528: ['edge_1153715', 'node_1153723']
# Community 114530: ['edge_1153744', 'node_1153746']
# Community 114532: ['edge_1153745', 'node_1153747']
# Community 114534: ['edge_1153746', 'node_1153748']
# Community 114535: ['edge_1153747', 'node_1153749']
# Community 114537: ['edge_1153751', 'node_1153752']
# Community 114539: ['edge_1153754', 'node_1153756']
# Community 114540: ['edge_1153757', 'node_1153758']
# Community 114543: ['edge_1153767', 'node_1153771']
# Community 114544: ['edge_1153776', 'node_1153780']
# Community 114546: ['edge_1153790', 'node_1153795']
# Community 114549: ['edge_1153834', 'node_1153915']
# Community 114551: ['edge_1153846', 'node_1153916']
# Community 114553: ['edge_1153921', 'node_1153923']
# Community 114554: ['edge_1153926', 'node_1153928']
# Community 114556: ['edge_1153931', 'node_1153932']
# Community 114557: ['edge_1153947', 'node_1153948']
# Community 114558: ['edge_1153959', 'node_1153960']
# Community 114560: ['edge_1153961', 'node_1153962']
# Community 114563: ['edge_1153988', 'node_1153990']
# Community 114565: ['edge_1153992', 'node_1153994']
# Community 114567: ['edge_1153993', 'node_1153995']
# Community 114569: ['edge_1154031', 'node_1156783']
# Community 114571: ['edge_1154035', 'node_1154036']
# Community 114573: ['edge_1154069', 'node_1154070']
# Community 114574: ['edge_1154074', 'node_1154076']
# Community 114579: ['edge_1154087', 'node_1154091']
# Community 114580: ['edge_1154096', 'node_1154098']
# Community 114582: ['edge_1154107', 'node_1154108']
# Community 114585: ['edge_1154133', 'node_1154134']
# Community 114586: ['edge_1154155', 'node_1154158']
# Community 114588: ['edge_1154158', 'node_1154159']
# Community 114590: ['edge_1154159', 'node_1154161']
# Community 114592: ['edge_1154175', 'node_1154176']
# Community 114594: ['edge_1154183', 'node_1154184']
# Community 114595: ['edge_1154213', 'node_1154214']
# Community 114597: ['edge_1154245', 'node_1154249']
# Community 114599: ['edge_1154286', 'node_1154293']
# Community 114600: ['edge_1154330', 'node_1154370']
# Community 114602: ['edge_1154374', 'node_1154378']
# Community 114605: ['edge_1154383', 'node_1154385']
# Community 114607: ['edge_1154412', 'node_1154427']
# Community 114609: ['edge_1154423', 'node_1154428']
# Community 114611: ['edge_1154428', 'node_1154429']
# Community 114613: ['edge_1154435', 'node_1154436']
# Community 114614: ['edge_1154442', 'node_1154443']
# Community 114617: ['edge_1154474', 'node_1154476']
# Community 114619: ['edge_1154480', 'node_1154481']
# Community 114620: ['edge_1154486', 'node_1154487']
# Community 114622: ['edge_1154493', 'node_1154494']
# Community 114623: ['edge_1154496', 'node_1154497']
# Community 114625: ['edge_1154499', 'node_1154502']
# Community 114627: ['edge_1154502', 'node_1154503']
# Community 114630: ['edge_1154503', 'node_1154508']
# Community 114631: ['edge_1154508', 'node_1154512']
# Community 114634: ['edge_1154517', 'node_1154518']
# Community 114635: ['edge_1154520', 'node_1154522']
# Community 114638: ['edge_1154536', 'node_1154568']
# Community 114639: ['edge_1154537', 'node_1154569']
# Community 114642: ['edge_1154555', 'node_1154573']
# Community 114643: ['edge_1154565', 'node_1154574']
# Community 114646: ['edge_1154584', 'node_1154585']
# Community 114647: ['edge_1154592', 'node_1154626']
# Community 114648: ['edge_1154598', 'node_1154628']
# Community 114650: ['edge_1154601', 'node_1154627']
# Community 114653: ['edge_1154603', 'node_1154629']
# Community 114655: ['edge_1154606', 'node_1154630']
# Community 114656: ['edge_1154613', 'node_1154631']
# Community 114658: ['edge_1154626', 'node_1154632']
# Community 114660: ['edge_1154627', 'node_1154637']
# Community 114662: ['edge_1154628', 'node_1154633']
# Community 114664: ['edge_1154634', 'node_1154640']
# Community 114667: ['edge_1154638', 'node_1154646']
# Community 114669: ['edge_1154650', 'node_1154652']
# Community 114670: ['edge_1154658', 'node_1154660']
# Community 114673: ['edge_1154667', 'node_1154668']
# Community 114675: ['edge_1154688', 'node_1154689']
# Community 114676: ['edge_1154689', 'node_1154690']
# Community 114678: ['edge_1154703', 'node_1154707']
# Community 114679: ['edge_1154706', 'node_1154709']
# Community 114681: ['edge_1154718', 'node_1154720']
# Community 114683: ['edge_1154722', 'node_1154724']
# Community 114685: ['edge_1154729', 'node_1154730']
# Community 114686: ['edge_1154754', 'node_1154756']
# Community 114688: ['edge_1154770', 'node_1154771']
# Community 114689: ['edge_1154824', 'node_1154825']
# Community 114691: ['edge_1154838', 'node_1154840']
# Community 114692: ['edge_1154843', 'node_1154844']
# Community 114695: ['edge_1154845', 'node_1154846']
# Community 114697: ['edge_1154854', 'node_1154856']
# Community 114698: ['edge_1154856', 'node_1154857']
# Community 114700: ['edge_1154861', 'node_1154863']
# Community 114702: ['edge_1154874', 'node_1154875']
# Community 114705: ['edge_1154876', 'node_1154877']
# Community 114706: ['edge_1154884', 'node_1154885']
# Community 114709: ['edge_1154891', 'node_1154892']
# Community 114710: ['edge_1154911', 'node_1154918']
# Community 114712: ['edge_1154942', 'node_1154944']
# Community 114714: ['edge_1154949', 'node_1154950']
# Community 114717: ['edge_1154957', 'node_1154959']
# Community 114718: ['edge_1154961', 'node_1154962']
# Community 114720: ['edge_1154976', 'node_1154977']
# Community 114722: ['edge_1154986', 'node_1154997']
# Community 114724: ['edge_1154993', 'node_1154998']
# Community 114726: ['edge_1155018', 'node_1155021']
# Community 114728: ['edge_1155020', 'node_1155023']
# Community 114730: ['edge_1155023', 'node_1155024']
# Community 114732: ['edge_1155038', 'node_1155042']
# Community 114734: ['edge_1155042', 'node_1155043']
# Community 114736: ['edge_1155074', 'node_1155075']
# Community 114738: ['edge_1155101', 'node_1155128']
# Community 114739: ['edge_1155135', 'node_1155136']
# Community 114741: ['edge_1155172', 'node_1155174']
# Community 114742: ['edge_1155180', 'node_1155181']
# Community 114745: ['edge_1155183', 'node_1155187']
# Community 114747: ['edge_1155187', 'node_1155193', 'edge_1155191']
# Community 114749: ['edge_1155235', 'node_1155236']
# Community 114751: ['edge_1155242', 'node_1155244']
# Community 114753: ['edge_1155249', 'node_1155251']
# Community 114755: ['edge_1155250', 'node_1155253']
# Community 114757: ['edge_1155251', 'node_1155254']
# Community 114758: ['edge_1155282', 'node_1155286']
# Community 114761: ['edge_1155284', 'node_1155287']
# Community 114763: ['edge_1155298', 'node_1155300']
# Community 114765: ['edge_1155299', 'node_1155301']
# Community 114767: ['edge_1155300', 'node_1155302']
# Community 114768: ['edge_1155301', 'node_1155303']
# Community 114769: ['edge_1155308', 'node_1155309']
# Community 114771: ['edge_1155323', 'node_1155324']
# Community 114773: ['edge_1155344', 'node_1155346']
# Community 114774: ['edge_1155353', 'node_1155354']
# Community 114775: ['edge_1155356', 'node_1155357']
# Community 114778: ['edge_1155413', 'node_1155414']
# Community 114780: ['edge_1155415', 'node_1155419']
# Community 114782: ['edge_1155421', 'node_1155424']
# Community 114784: ['edge_1155424', 'node_1155426']
# Community 114786: ['edge_1155432', 'node_1155433']
# Community 114789: ['edge_1155435', 'node_1155436']
# Community 114790: ['edge_1155456', 'node_1155460']
# Community 114793: ['edge_1155460', 'node_1155464']
# Community 114794: ['edge_1155464', 'node_1155466']
# Community 114796: ['edge_1155469', 'node_1155470']
# Community 114798: ['edge_1155473', 'node_1155476']
# Community 114800: ['edge_1155478', 'node_1155480']
# Community 114802: ['edge_1155479', 'node_1155481']
# Community 114804: ['edge_1155483', 'node_1155484']
# Community 114805: ['edge_1155486', 'node_1155488']
# Community 114807: ['edge_1155487', 'node_1155489']
# Community 114809: ['edge_1155494', 'node_1155495']
# Community 114810: ['edge_1155495', 'node_1155497']
# Community 114812: ['edge_1155508', 'node_1155509']
# Community 114814: ['edge_1155528', 'node_1155540']
# Community 114817: ['edge_1155538', 'node_1155543']
# Community 114818: ['edge_1155539', 'node_1155541']
# Community 114820: ['edge_1155541', 'node_1155550']
# Community 114821: ['edge_1155542', 'node_1155551']
# Community 114824: ['edge_1155566', 'node_1155569']
# Community 114825: ['edge_1155573', 'node_1155581']
# Community 114828: ['edge_1155580', 'node_1155582']
# Community 114830: ['edge_1155586', 'node_1155592']
# Community 114832: ['edge_1155587', 'node_1155591']
# Community 114833: ['edge_1155595', 'node_1155599']
# Community 114835: ['edge_1155596', 'node_1155600']
# Community 114837: ['edge_1155605', 'node_1155606']
# Community 114838: ['edge_1155609', 'node_1155612']
# Community 114840: ['edge_1155614', 'node_1155615']
# Community 114843: ['edge_1155621', 'node_1155623']
# Community 114845: ['edge_1155622', 'node_1155629']
# Community 114846: ['edge_1155630', 'node_1155631']
# Community 114847: ['edge_1155631', 'node_1155633']
# Community 114848: ['edge_1155645', 'node_1155646']
# Community 114850: ['edge_1155668', 'node_1155710']
# Community 114851: ['edge_1155679', 'node_1155711']
# Community 114852: ['edge_1155710', 'node_1155714']
# Community 114855: ['edge_1155722', 'node_1155735']
# Community 114856: ['edge_1155729', 'node_1155738']
# Community 114859: ['edge_1155731', 'node_1155736']
# Community 114861: ['edge_1155825', 'node_1155827']
# Community 114862: ['edge_1155884', 'node_1155958']
# Community 114864: ['edge_1155906', 'node_1155959']
# Community 114866: ['edge_1155918', 'node_1155960']
# Community 114867: ['edge_1155958', 'node_1155964']
# Community 114868: ['edge_1155959', 'node_1155965']
# Community 114871: ['edge_1155960', 'node_1155967']
# Community 114873: ['edge_1155967', 'node_1155968']
# Community 114874: ['edge_1155968', 'node_1155970']
# Community 114877: ['edge_1155970', 'node_1155971']
# Community 114878: ['edge_1155974', 'node_1155975']
# Community 114880: ['edge_1155975', 'node_1155976']
# Community 114882: ['edge_1156029', 'node_1156032']
# Community 114883: ['edge_1156046', 'node_1156047']
# Community 114884: ['edge_1156054', 'node_1156055']
# Community 114885: ['edge_1156058', 'node_1156059']
# Community 114886: ['edge_1156079', 'node_1156080']
# Community 114887: ['edge_1156086', 'node_1156087']
# Community 114890: ['edge_1156100', 'node_1156102']
# Community 114891: ['edge_1156105', 'node_1156106']
# Community 114892: ['edge_1156106', 'node_1156107']
# Community 114893: ['edge_1156109', 'node_1156110']
# Community 114895: ['edge_1156110', 'node_1156111']
# Community 114898: ['edge_1156119', 'node_1156120']
# Community 114900: ['edge_1156166', 'node_1156186']
# Community 114902: ['edge_1156177', 'node_1156188']
# Community 114904: ['edge_1156195', 'node_1156202']
# Community 114905: ['edge_1156198', 'node_1156205']
# Community 114907: ['edge_1156267', 'node_1156269']
# Community 114909: ['edge_1156268', 'node_1156271']
# Community 114911: ['edge_1156277', 'node_1156284']
# Community 114912: ['edge_1156293', 'node_1156294']
# Community 114915: ['edge_1156301', 'node_1156302']
# Community 114917: ['edge_1156319', 'node_1156320']
# Community 114919: ['edge_1156329', 'node_1156331']
# Community 114921: ['edge_1156339', 'node_1156340']
# Community 114923: ['edge_1156340', 'node_1156341']
# Community 114925: ['edge_1156346', 'node_1156347']
# Community 114926: ['edge_1156357', 'node_1156359']
# Community 114928: ['edge_1156370', 'node_1156372']
# Community 114929: ['edge_1156392', 'node_1156395']
# Community 114931: ['edge_1156400', 'node_1156401']
# Community 114933: ['edge_1156403', 'node_1156409']
# Community 114934: ['edge_1156404', 'node_1156410']
# Community 114936: ['edge_1156415', 'node_1156416']
# Community 114937: ['edge_1156417', 'node_1156418']
# Community 114941: ['edge_1156419', 'node_1156420']
# Community 114943: ['edge_1156433', 'node_1156436']
# Community 114945: ['edge_1156446', 'node_1156447']
# Community 114946: ['edge_1156447', 'node_1156448']
# Community 114948: ['edge_1156455', 'node_1156456']
# Community 114950: ['edge_1156456', 'node_1156457']
# Community 114952: ['edge_1156470', 'node_1156471']
# Community 114954: ['edge_1156476', 'node_1156477']
# Community 114956: ['edge_1156479', 'node_1156480']
# Community 114959: ['edge_1156481', 'node_1156482']
# Community 114960: ['edge_1156487', 'node_1156488']
# Community 114962: ['edge_1156490', 'node_1156491']
# Community 114965: ['edge_1156537', 'node_1156538']
# Community 114967: ['edge_1156557', 'node_1156561']
# Community 114969: ['edge_1156558', 'node_1156559']
# Community 114972: ['edge_1156579', 'node_1156581']
# Community 114975: ['edge_1156583', 'node_1156585']
# Community 114976: ['edge_1156596', 'node_1156599']
# Community 114979: ['edge_1156607', 'node_1156608']
# Community 114980: ['edge_1156621', 'node_1156622']
# Community 114982: ['edge_1156639', 'node_1156643']
# Community 114983: ['edge_1156640', 'node_1156644']
# Community 114984: ['edge_1156655', 'node_1156656']
# Community 114987: ['edge_1156687', 'node_1156688']
# Community 114989: ['edge_1156688', 'node_1156689']
# Community 114990: ['edge_1156690', 'node_1156691']
# Community 114992: ['edge_1156717', 'node_1156792']
# Community 114995: ['edge_1156727', 'node_1156794']
# Community 114996: ['edge_1156729', 'node_1156793']
# Community 114998: ['edge_1156735', 'node_1156796']
# Community 115000: ['edge_1156753', 'node_1156797']
# Community 115001: ['edge_1156763', 'node_1156799']
# Community 115003: ['edge_1156769', 'node_1156802']
# Community 115005: ['edge_1156771', 'node_1156800']
# Community 115007: ['edge_1156776', 'node_1156801']
# Community 115010: ['edge_1156777', 'node_1156803']
# Community 115011: ['edge_1156788', 'node_1156804']
# Community 115014: ['edge_1156790', 'node_1156805']
# Community 115015: ['edge_1156791', 'node_1156806']
# Community 115016: ['edge_1156798', 'node_1156807']
# Community 115019: ['edge_1156799', 'node_1156808']
# Community 115020: ['edge_1156808', 'node_1156809']
# Community 115024: ['edge_1156810', 'node_1156811']
# Community 115025: ['edge_1156830', 'node_1156834']
# Community 115027: ['edge_1156848', 'node_1156851']
# Community 115029: ['edge_1156851', 'node_1156853', 'edge_1156852']
# Community 115032: ['edge_1156863', 'node_1156864']
# Community 115034: ['edge_1156867', 'node_1156870']
# Community 115036: ['edge_1156868', 'node_1156874']
# Community 115038: ['edge_1156869', 'node_1156875']
# Community 115040: ['edge_1156897', 'node_1156898']
# Community 115041: ['edge_1156900', 'node_1156901']
# Community 115042: ['edge_1156901', 'node_1156902']
# Community 115044: ['edge_1156912', 'node_1156914']
# Community 115045: ['edge_1156913', 'node_1156918']
# Community 115046: ['edge_1156914', 'node_1156916']
# Community 115047: ['edge_1156917', 'node_1156929']
# Community 115050: ['edge_1156918', 'node_1156919']
# Community 115051: ['edge_1156931', 'node_1156932']
# Community 115053: ['edge_1156955', 'node_1156957']
# Community 115054: ['edge_1156958', 'node_1156960']
# Community 115056: ['edge_1156990', 'node_1156991']
# Community 115057: ['edge_1156997', 'node_1156998']
# Community 115058: ['edge_1157005', 'node_1157006']
# Community 115060: ['edge_1157010', 'node_1157011']
# Community 115061: ['edge_1157017', 'node_1157020']
# Community 115063: ['edge_1157020', 'node_1157021']
# Community 115065: ['edge_1157033', 'node_1157035']
# Community 115066: ['edge_1157045', 'node_1157046']
# Community 115067: ['edge_1157049', 'node_1157050']
# Community 115068: ['edge_1157054', 'node_1157055']
# Community 115069: ['edge_1157077', 'node_1157078']
# Community 115071: ['edge_1157101', 'node_1157102']
# Community 115073: ['edge_1157133', 'node_1157136']
# Community 115075: ['edge_1157170', 'node_1157183']
# Community 115077: ['edge_1157207', 'node_1157208']
# Community 115078: ['edge_1157222', 'node_1157225']
# Community 115081: ['edge_1157227', 'node_1157229']
# Community 115082: ['edge_1157228', 'node_1157230']
# Community 115085: ['edge_1157234', 'node_1157235']
# Community 115086: ['edge_1157244', 'node_1157246']
# Community 115087: ['edge_1157258', 'node_1157259']
# Community 115089: ['edge_1157274', 'node_1157277']
# Community 115091: ['edge_1157353', 'node_1157358']
# Community 115093: ['edge_1157407', 'node_1157425']
# Community 115094: ['edge_1157416', 'node_1157427']
# Community 115095: ['edge_1157417', 'node_1157426']
# Community 115097: ['edge_1157423', 'node_1157429']
# Community 115100: ['edge_1157426', 'node_1157430']
# Community 115101: ['edge_1157432', 'node_1157442']
# Community 115104: ['edge_1157444', 'node_1157447']
# Community 115105: ['edge_1157456', 'node_1157458']
# Community 115107: ['edge_1157460', 'node_1157484']
# Community 115109: ['edge_1157482', 'node_1157485']
# Community 115111: ['edge_1157483', 'node_1157494']
# Community 115113: ['edge_1157500', 'node_1157504']
# Community 115114: ['edge_1157518', 'node_1157529']
# Community 115116: ['edge_1157522', 'node_1157531']
# Community 115118: ['edge_1157525', 'node_1157532']
# Community 115121: ['edge_1157535', 'node_1157537']
# Community 115123: ['edge_1157537', 'node_1157538']
# Community 115124: ['edge_1157556', 'node_1157560']
# Community 115126: ['edge_1157560', 'node_1157562']
# Community 115128: ['edge_1157561', 'node_1157563']
# Community 115131: ['edge_1157564', 'node_1157567']
# Community 115132: ['edge_1157570', 'node_1157573']
# Community 115135: ['edge_1157575', 'node_1157577']
# Community 115137: ['edge_1157586', 'node_1157590']
# Community 115138: ['edge_1157596', 'node_1157599']
# Community 115140: ['edge_1157609', 'node_1157610']
# Community 115142: ['edge_1157613', 'node_1157614']
# Community 115143: ['edge_1157616', 'node_1157631']
# Community 115146: ['edge_1157682', 'node_1157688']
# Community 115148: ['edge_1157690', 'node_1157702']
# Community 115149: ['edge_1157701', 'node_1157703']
# Community 115152: ['edge_1157712', 'node_1157713']
# Community 115153: ['edge_1157728', 'node_1157756']
# Community 115156: ['edge_1157759', 'node_1157760']
# Community 115158: ['edge_1157803', 'node_1157805']
# Community 115160: ['edge_1157804', 'node_1157806']
#
# Found 2283 similar communities between graph and hypergraph with a threshold of 0.2.
# Graph community 43 and Hypergraph community 26337 have a Jaccard similarity of 0.25.
# Common nodes: {228026}
# Graph community 44 and Hypergraph community 26341 have a Jaccard similarity of 0.25.
# Common nodes: {712247}
# Graph community 44 and Hypergraph community 7772 have a Jaccard similarity of 0.25.
# Common nodes: {941870}
# Graph community 44 and Hypergraph community 69722 have a Jaccard similarity of 0.25.
# Common nodes: {998199}
# Graph community 75 and Hypergraph community 27236 have a Jaccard similarity of 0.25.
# Common nodes: {713465}
# Graph community 75 and Hypergraph community 8161 have a Jaccard similarity of 0.25.
# Common nodes: {941874}
# Graph community 75 and Hypergraph community 69724 have a Jaccard similarity of 0.25.
# Common nodes: {998196}
# Graph community 100 and Hypergraph community 280008 have a Jaccard similarity of 0.25.
# Common nodes: {897855}
# Graph community 100 and Hypergraph community 60601 have a Jaccard similarity of 0.25.
# Common nodes: {991305}
# Graph community 100 and Hypergraph community 81740 have a Jaccard similarity of 0.25.
# Common nodes: {1008639}
# Graph community 101 and Hypergraph community 191458 have a Jaccard similarity of 0.25.
# Common nodes: {663891}
# Graph community 101 and Hypergraph community 257188 have a Jaccard similarity of 0.25.
# Common nodes: {623833}
# Graph community 104 and Hypergraph community 280036 have a Jaccard similarity of 0.25.
# Common nodes: {1122710}
# Graph community 104 and Hypergraph community 109126 have a Jaccard similarity of 0.25.
# Common nodes: {1122711}
# Graph community 124 and Hypergraph community 200 have a Jaccard similarity of 0.25.
# Common nodes: {665646}
# Graph community 148 and Hypergraph community 231490 have a Jaccard similarity of 0.25.
# Common nodes: {1155264}
# Graph community 148 and Hypergraph community 265852 have a Jaccard similarity of 0.25.
# Common nodes: {629337}
# Graph community 151 and Hypergraph community 249863 have a Jaccard similarity of 0.25.
# Common nodes: {879590}
# Graph community 161 and Hypergraph community 285054 have a Jaccard similarity of 0.25.
# Common nodes: {1077937}
# Graph community 161 and Hypergraph community 100419 have a Jaccard similarity of 0.25.
# Common nodes: {1077938}
# Graph community 162 and Hypergraph community 285077 have a Jaccard similarity of 0.25.
# Common nodes: {915443}
# Graph community 163 and Hypergraph community 285088 have a Jaccard similarity of 0.25.
# Common nodes: {915317}
# Graph community 163 and Hypergraph community 64452 have a Jaccard similarity of 0.25.
# Common nodes: {1115628}
# Graph community 167 and Hypergraph community 285141 have a Jaccard similarity of 0.25.
# Common nodes: {915631}
# Graph community 167 and Hypergraph community 64537 have a Jaccard similarity of 0.25.
# Common nodes: {994362}
# Graph community 173 and Hypergraph community 285258 have a Jaccard similarity of 0.25.
# Common nodes: {915502}
# Graph community 173 and Hypergraph community 64511 have a Jaccard similarity of 0.25.
# Common nodes: {994342}
# Graph community 175 and Hypergraph community 285261 have a Jaccard similarity of 0.25.
# Common nodes: {915486}
# Graph community 175 and Hypergraph community 64507 have a Jaccard similarity of 0.25.
# Common nodes: {1062819}
# Graph community 178 and Hypergraph community 7417 have a Jaccard similarity of 0.25.
# Common nodes: {692909}
# Graph community 178 and Hypergraph community 134 have a Jaccard similarity of 0.25.
# Common nodes: {1081193}
# Graph community 198 and Hypergraph community 1640 have a Jaccard similarity of 0.25.
# Common nodes: {671077}
# Graph community 198 and Hypergraph community 80987 have a Jaccard similarity of 0.25.
# Common nodes: {642778}
# Graph community 204 and Hypergraph community 87238 have a Jaccard similarity of 0.25.
# Common nodes: {1014250}
# Graph community 204 and Hypergraph community 87240 have a Jaccard similarity of 0.25.
# Common nodes: {1014252}
# Graph community 233 and Hypergraph community 16940 have a Jaccard similarity of 0.25.
# Common nodes: {204953}
# Graph community 233 and Hypergraph community 228502 have a Jaccard similarity of 0.25.
# Common nodes: {494297}
# Graph community 233 and Hypergraph community 220592 have a Jaccard similarity of 0.25.
# Common nodes: {603013}
# Graph community 246 and Hypergraph community 113853 have a Jaccard similarity of 0.25.
# Common nodes: {1149118}
# Graph community 246 and Hypergraph community 113859 have a Jaccard similarity of 0.25.
# Common nodes: {1149119}
# Graph community 247 and Hypergraph community 19339 have a Jaccard similarity of 0.33.
# Common nodes: {213433}
# Graph community 249 and Hypergraph community 19882 have a Jaccard similarity of 0.25.
# Common nodes: {708306}
# Graph community 249 and Hypergraph community 6042 have a Jaccard similarity of 0.25.
# Common nodes: {1098513}
# Graph community 267 and Hypergraph community 24465 have a Jaccard similarity of 0.25.
# Common nodes: {711002}
# Graph community 285 and Hypergraph community 277687 have a Jaccard similarity of 0.25.
# Common nodes: {892003}
# Graph community 286 and Hypergraph community 285713 have a Jaccard similarity of 0.25.
# Common nodes: {1053943}
# Graph community 286 and Hypergraph community 95743 have a Jaccard similarity of 0.25.
# Common nodes: {1053944}
# Graph community 288 and Hypergraph community 285720 have a Jaccard similarity of 0.25.
# Common nodes: {916104}
# Graph community 288 and Hypergraph community 64656 have a Jaccard similarity of 0.25.
# Common nodes: {994449}
# Graph community 292 and Hypergraph community 285751 have a Jaccard similarity of 0.25.
# Common nodes: {916149}
# Graph community 292 and Hypergraph community 64668 have a Jaccard similarity of 0.25.
# Common nodes: {994460}
# Graph community 295 and Hypergraph community 285922 have a Jaccard similarity of 0.25.
# Common nodes: {916587}
# Graph community 295 and Hypergraph community 64762 have a Jaccard similarity of 0.25.
# Common nodes: {994556}
# Graph community 298 and Hypergraph community 286037 have a Jaccard similarity of 0.25.
# Common nodes: {1110543}
# Graph community 299 and Hypergraph community 286060 have a Jaccard similarity of 0.33.
# Common nodes: {916415}
# Graph community 302 and Hypergraph community 15976 have a Jaccard similarity of 0.25.
# Common nodes: {705362}
# Graph community 303 and Hypergraph community 16089 have a Jaccard similarity of 0.25.
# Common nodes: {1116884}
# Graph community 305 and Hypergraph community 9965 have a Jaccard similarity of 0.33.
# Common nodes: {944255}
# Graph community 306 and Hypergraph community 282813 have a Jaccard similarity of 0.25.
# Common nodes: {1084259}
# Graph community 306 and Hypergraph community 63221 have a Jaccard similarity of 0.25.
# Common nodes: {909101}
# Graph community 311 and Hypergraph community 4819 have a Jaccard similarity of 0.25.
# Common nodes: {691627}
# Graph community 314 and Hypergraph community 19033 have a Jaccard similarity of 0.25.
# Common nodes: {707728}
# Graph community 314 and Hypergraph community 5771 have a Jaccard similarity of 0.25.
# Common nodes: {939075}
# Graph community 326 and Hypergraph community 11761 have a Jaccard similarity of 0.25.
# Common nodes: {183419}
# Graph community 335 and Hypergraph community 280700 have a Jaccard similarity of 0.25.
# Common nodes: {900576}
# Graph community 335 and Hypergraph community 61311 have a Jaccard similarity of 0.25.
# Common nodes: {991874}
# Graph community 339 and Hypergraph community 280947 have a Jaccard similarity of 0.25.
# Common nodes: {902978}
# Graph community 339 and Hypergraph community 62108 have a Jaccard similarity of 0.25.
# Common nodes: {1075969}
# Graph community 341 and Hypergraph community 113062 have a Jaccard similarity of 0.33.
# Common nodes: {1144117}
# Graph community 344 and Hypergraph community 26025 have a Jaccard similarity of 0.25.
# Common nodes: {713134}
# Graph community 354 and Hypergraph community 13190 have a Jaccard similarity of 0.25.
# Common nodes: {702764}
# Graph community 358 and Hypergraph community 13443 have a Jaccard similarity of 0.25.
# Common nodes: {190107}
# Graph community 368 and Hypergraph community 14817 have a Jaccard similarity of 0.25.
# Common nodes: {196714}
# Graph community 368 and Hypergraph community 220531 have a Jaccard similarity of 0.25.
# Common nodes: {488268}
# Graph community 370 and Hypergraph community 15072 have a Jaccard similarity of 0.25.
# Common nodes: {704629}
# Graph community 370 and Hypergraph community 4340 have a Jaccard similarity of 0.25.
# Common nodes: {936714}
# Graph community 373 and Hypergraph community 15214 have a Jaccard similarity of 0.25.
# Common nodes: {705686}
# Graph community 373 and Hypergraph community 222671 have a Jaccard similarity of 0.25.
# Common nodes: {198912}
# Graph community 375 and Hypergraph community 15332 have a Jaccard similarity of 0.25.
# Common nodes: {705053}
# Graph community 386 and Hypergraph community 34428 have a Jaccard similarity of 0.25.
# Common nodes: {263125}
# Graph community 386 and Hypergraph community 281182 have a Jaccard similarity of 0.25.
# Common nodes: {525493}
# Graph community 387 and Hypergraph community 275444 have a Jaccard similarity of 0.25.
# Common nodes: {804493}
# Graph community 387 and Hypergraph community 279821 have a Jaccard similarity of 0.25.
# Common nodes: {896131}
# Graph community 389 and Hypergraph community 96875 have a Jaccard similarity of 0.25.
# Common nodes: {1059624}
# Graph community 389 and Hypergraph community 96879 have a Jaccard similarity of 0.25.
# Common nodes: {1059626}
# Graph community 395 and Hypergraph community 285465 have a Jaccard similarity of 0.25.
# Common nodes: {915789}
# Graph community 399 and Hypergraph community 34590 have a Jaccard similarity of 0.33.
# Common nodes: {722744}
# Graph community 404 and Hypergraph community 27902 have a Jaccard similarity of 0.25.
# Common nodes: {233321}
# Graph community 404 and Hypergraph community 255998 have a Jaccard similarity of 0.25.
# Common nodes: {480533}
# Graph community 405 and Hypergraph community 255974 have a Jaccard similarity of 0.25.
# Common nodes: {715174}
# Graph community 407 and Hypergraph community 28407 have a Jaccard similarity of 0.25.
# Common nodes: {714648}
# Graph community 407 and Hypergraph community 256518 have a Jaccard similarity of 0.25.
# Common nodes: {513082}
# Graph community 434 and Hypergraph community 1697 have a Jaccard similarity of 0.25.
# Common nodes: {931355}
# Graph community 438 and Hypergraph community 278885 have a Jaccard similarity of 0.25.
# Common nodes: {894117}
# Graph community 442 and Hypergraph community 281579 have a Jaccard similarity of 0.25.
# Common nodes: {903573}
# Graph community 442 and Hypergraph community 62292 have a Jaccard similarity of 0.25.
# Common nodes: {992684}
# Graph community 452 and Hypergraph community 49150 have a Jaccard similarity of 0.25.
# Common nodes: {735149}
# Graph community 452 and Hypergraph community 127974 have a Jaccard similarity of 0.25.
# Common nodes: {541190}
# Graph community 462 and Hypergraph community 49713 have a Jaccard similarity of 0.25.
# Common nodes: {735538}
# Graph community 482 and Hypergraph community 40363 have a Jaccard similarity of 0.25.
# Common nodes: {729797}
# Graph community 482 and Hypergraph community 13387 have a Jaccard similarity of 0.25.
# Common nodes: {1119095}
# Graph community 490 and Hypergraph community 46748 have a Jaccard similarity of 0.25.
# Common nodes: {539209}
# Graph community 490 and Hypergraph community 125544 have a Jaccard similarity of 0.25.
# Common nodes: {539210}
# Graph community 491 and Hypergraph community 47001 have a Jaccard similarity of 0.25.
# Common nodes: {293581}
# Graph community 491 and Hypergraph community 125823 have a Jaccard similarity of 0.25.
# Common nodes: {539381}
# Graph community 498 and Hypergraph community 48364 have a Jaccard similarity of 0.33.
# Common nodes: {416613}
# Graph community 505 and Hypergraph community 281414 have a Jaccard similarity of 0.25.
# Common nodes: {1037282}
# Graph community 505 and Hypergraph community 92212 have a Jaccard similarity of 0.25.
# Common nodes: {1037283}
# Graph community 505 and Hypergraph community 92214 have a Jaccard similarity of 0.25.
# Common nodes: {1037284}
# Graph community 507 and Hypergraph community 281466 have a Jaccard similarity of 0.25.
# Common nodes: {904336}
# Graph community 509 and Hypergraph community 100575 have a Jaccard similarity of 0.25.
# Common nodes: {1135202}
# Graph community 512 and Hypergraph community 41079 have a Jaccard similarity of 0.25.
# Common nodes: {1032257}
# Graph community 515 and Hypergraph community 43804 have a Jaccard similarity of 0.25.
# Common nodes: {1052099}
# Graph community 515 and Hypergraph community 14109 have a Jaccard similarity of 0.25.
# Common nodes: {1050808}
# Graph community 520 and Hypergraph community 861 have a Jaccard similarity of 0.25.
# Common nodes: {667790}
# Graph community 520 and Hypergraph community 282351 have a Jaccard similarity of 0.25.
# Common nodes: {1137178}
# Graph community 524 and Hypergraph community 42577 have a Jaccard similarity of 0.25.
# Common nodes: {732355}
# Graph community 524 and Hypergraph community 13834 have a Jaccard similarity of 0.25.
# Common nodes: {948530}
# Graph community 525 and Hypergraph community 42818 have a Jaccard similarity of 0.25.
# Common nodes: {285210}
# Graph community 525 and Hypergraph community 120766 have a Jaccard similarity of 0.25.
# Common nodes: {535976}
# Graph community 525 and Hypergraph community 237948 have a Jaccard similarity of 0.25.
# Common nodes: {876340}
# Graph community 553 and Hypergraph community 282546 have a Jaccard similarity of 0.25.
# Common nodes: {908247}
# Graph community 553 and Hypergraph community 63094 have a Jaccard similarity of 0.25.
# Common nodes: {993305}
# Graph community 553 and Hypergraph community 82244 have a Jaccard similarity of 0.25.
# Common nodes: {1009109}
# Graph community 554 and Hypergraph community 282615 have a Jaccard similarity of 0.25.
# Common nodes: {908926}
# Graph community 554 and Hypergraph community 63188 have a Jaccard similarity of 0.25.
# Common nodes: {993378}
# Graph community 555 and Hypergraph community 282671 have a Jaccard similarity of 0.25.
# Common nodes: {908970}
# Graph community 559 and Hypergraph community 98569 have a Jaccard similarity of 0.33.
# Common nodes: {1067360}
# Graph community 560 and Hypergraph community 112120 have a Jaccard similarity of 0.25.
# Common nodes: {1138909}
# Graph community 560 and Hypergraph community 112126 have a Jaccard similarity of 0.25.
# Common nodes: {1138960}
# Graph community 565 and Hypergraph community 51255 have a Jaccard similarity of 0.33.
# Common nodes: {301618}
# Graph community 569 and Hypergraph community 51365 have a Jaccard similarity of 0.25.
# Common nodes: {301837}
# Graph community 569 and Hypergraph community 129924 have a Jaccard similarity of 0.25.
# Common nodes: {542523}
# Graph community 577 and Hypergraph community 63741 have a Jaccard similarity of 0.25.
# Common nodes: {321362}
# Graph community 577 and Hypergraph community 140310 have a Jaccard similarity of 0.25.
# Common nodes: {550722}
# Graph community 578 and Hypergraph community 130878 have a Jaccard similarity of 0.33.
# Common nodes: {303563}
# Graph community 592 and Hypergraph community 59836 have a Jaccard similarity of 0.25.
# Common nodes: {747838}
# Graph community 592 and Hypergraph community 138250 have a Jaccard similarity of 0.25.
# Common nodes: {548972}
# Graph community 595 and Hypergraph community 286317 have a Jaccard similarity of 0.25.
# Common nodes: {916818}
# Graph community 595 and Hypergraph community 64809 have a Jaccard similarity of 0.25.
# Common nodes: {1147992}
# Graph community 595 and Hypergraph community 113640 have a Jaccard similarity of 0.25.
# Common nodes: {1147993}
# Graph community 601 and Hypergraph community 248109 have a Jaccard similarity of 0.33.
# Common nodes: {618607}
# Graph community 601 and Hypergraph community 269320 have a Jaccard similarity of 0.33.
# Common nodes: {886016}
# Graph community 602 and Hypergraph community 282367 have a Jaccard similarity of 0.25.
# Common nodes: {907599}
# Graph community 602 and Hypergraph community 62932 have a Jaccard similarity of 0.25.
# Common nodes: {993196}
# Graph community 602 and Hypergraph community 82212 have a Jaccard similarity of 0.25.
# Common nodes: {1009069}
# Graph community 603 and Hypergraph community 77322 have a Jaccard similarity of 0.25.
# Common nodes: {336803}
# Graph community 603 and Hypergraph community 148401 have a Jaccard similarity of 0.25.
# Common nodes: {557243}
# Graph community 611 and Hypergraph community 60252 have a Jaccard similarity of 0.25.
# Common nodes: {747749}
# Graph community 613 and Hypergraph community 60288 have a Jaccard similarity of 0.33.
# Common nodes: {317651}
# Graph community 613 and Hypergraph community 138329 have a Jaccard similarity of 0.33.
# Common nodes: {1140056}
# Graph community 616 and Hypergraph community 60440 have a Jaccard similarity of 0.25.
# Common nodes: {748081}
# Graph community 617 and Hypergraph community 60447 have a Jaccard similarity of 0.25.
# Common nodes: {747852}
# Graph community 618 and Hypergraph community 60524 have a Jaccard similarity of 0.25.
# Common nodes: {748372}
# Graph community 621 and Hypergraph community 60890 have a Jaccard similarity of 0.25.
# Common nodes: {748344}
# Graph community 632 and Hypergraph community 96931 have a Jaccard similarity of 0.25.
# Common nodes: {1059817}
# Graph community 632 and Hypergraph community 96949 have a Jaccard similarity of 0.25.
# Common nodes: {1059826}
# Graph community 632 and Hypergraph community 96951 have a Jaccard similarity of 0.25.
# Common nodes: {1059828}
# Graph community 633 and Hypergraph community 97729 have a Jaccard similarity of 0.25.
# Common nodes: {1063422}
# Graph community 633 and Hypergraph community 97741 have a Jaccard similarity of 0.25.
# Common nodes: {1063426}
# Graph community 634 and Hypergraph community 97736 have a Jaccard similarity of 0.25.
# Common nodes: {1063440}
# Graph community 636 and Hypergraph community 99139 have a Jaccard similarity of 0.25.
# Common nodes: {1096101}
# Graph community 637 and Hypergraph community 102578 have a Jaccard similarity of 0.25.
# Common nodes: {1089007}
# Graph community 638 and Hypergraph community 112128 have a Jaccard similarity of 0.25.
# Common nodes: {1138963}
# Graph community 640 and Hypergraph community 64134 have a Jaccard similarity of 0.33.
# Common nodes: {321933}
# Graph community 640 and Hypergraph community 140649 have a Jaccard similarity of 0.33.
# Common nodes: {1036591}
# Graph community 659 and Hypergraph community 99745 have a Jaccard similarity of 0.25.
# Common nodes: {1073615}
# Graph community 659 and Hypergraph community 99749 have a Jaccard similarity of 0.25.
# Common nodes: {1073621}
# Graph community 661 and Hypergraph community 65652 have a Jaccard similarity of 0.25.
# Common nodes: {749645}
# Graph community 661 and Hypergraph community 141709 have a Jaccard similarity of 0.25.
# Common nodes: {552078}
# Graph community 664 and Hypergraph community 65703 have a Jaccard similarity of 0.25.
# Common nodes: {324315}
# Graph community 667 and Hypergraph community 66029 have a Jaccard similarity of 0.25.
# Common nodes: {324822}
# Graph community 667 and Hypergraph community 142040 have a Jaccard similarity of 0.25.
# Common nodes: {1033251}
# Graph community 667 and Hypergraph community 91253 have a Jaccard similarity of 0.25.
# Common nodes: {1033252}
# Graph community 668 and Hypergraph community 66119 have a Jaccard similarity of 0.25.
# Common nodes: {324762}
# Graph community 668 and Hypergraph community 141993 have a Jaccard similarity of 0.25.
# Common nodes: {841720}
# Graph community 668 and Hypergraph community 44285 have a Jaccard similarity of 0.25.
# Common nodes: {976197}
# Graph community 671 and Hypergraph community 61174 have a Jaccard similarity of 0.25.
# Common nodes: {318588}
# Graph community 671 and Hypergraph community 138882 have a Jaccard similarity of 0.25.
# Common nodes: {1101128}
# Graph community 673 and Hypergraph community 61561 have a Jaccard similarity of 0.25.
# Common nodes: {319013}
# Graph community 673 and Hypergraph community 139117 have a Jaccard similarity of 0.25.
# Common nodes: {549704}
# Graph community 675 and Hypergraph community 61692 have a Jaccard similarity of 0.25.
# Common nodes: {748431}
# Graph community 675 and Hypergraph community 139158 have a Jaccard similarity of 0.25.
# Common nodes: {549717}
# Graph community 676 and Hypergraph community 61708 have a Jaccard similarity of 0.25.
# Common nodes: {748363}
# Graph community 676 and Hypergraph community 17484 have a Jaccard similarity of 0.25.
# Common nodes: {952288}
# Graph community 676 and Hypergraph community 72162 have a Jaccard similarity of 0.25.
# Common nodes: {1107174}
# Graph community 687 and Hypergraph community 140160 have a Jaccard similarity of 0.25.
# Common nodes: {321050}
# Graph community 699 and Hypergraph community 287638 have a Jaccard similarity of 0.25.
# Common nodes: {919841}
# Graph community 699 and Hypergraph community 65350 have a Jaccard similarity of 0.25.
# Common nodes: {1102966}
# Graph community 707 and Hypergraph community 1343 have a Jaccard similarity of 0.25.
# Common nodes: {1130590}
# Graph community 707 and Hypergraph community 110581 have a Jaccard similarity of 0.25.
# Common nodes: {1130593}
# Graph community 729 and Hypergraph community 55617 have a Jaccard similarity of 0.25.
# Common nodes: {738667}
# Graph community 729 and Hypergraph community 16140 have a Jaccard similarity of 0.25.
# Common nodes: {951045}
# Graph community 729 and Hypergraph community 71842 have a Jaccard similarity of 0.25.
# Common nodes: {999772}
# Graph community 741 and Hypergraph community 57686 have a Jaccard similarity of 0.25.
# Common nodes: {313471}
# Graph community 741 and Hypergraph community 136242 have a Jaccard similarity of 0.25.
# Common nodes: {839773}
# Graph community 748 and Hypergraph community 65033 have a Jaccard similarity of 0.25.
# Common nodes: {323616}
# Graph community 748 and Hypergraph community 141362 have a Jaccard similarity of 0.25.
# Common nodes: {841482}
# Graph community 753 and Hypergraph community 64081 have a Jaccard similarity of 0.25.
# Common nodes: {1108435}
# Graph community 753 and Hypergraph community 106206 have a Jaccard similarity of 0.25.
# Common nodes: {1108437}
# Graph community 757 and Hypergraph community 68051 have a Jaccard similarity of 0.25.
# Common nodes: {326954}
# Graph community 757 and Hypergraph community 143191 have a Jaccard similarity of 0.25.
# Common nodes: {553217}
# Graph community 757 and Hypergraph community 245040 have a Jaccard similarity of 0.25.
# Common nodes: {878146}
# Graph community 763 and Hypergraph community 67940 have a Jaccard similarity of 0.25.
# Common nodes: {750571}
# Graph community 763 and Hypergraph community 143079 have a Jaccard similarity of 0.25.
# Common nodes: {842152}
# Graph community 772 and Hypergraph community 66819 have a Jaccard similarity of 0.25.
# Common nodes: {325616}
# Graph community 772 and Hypergraph community 142500 have a Jaccard similarity of 0.25.
# Common nodes: {552744}
# Graph community 772 and Hypergraph community 244841 have a Jaccard similarity of 0.25.
# Common nodes: {616688}
# Graph community 782 and Hypergraph community 284523 have a Jaccard similarity of 0.25.
# Common nodes: {914794}
# Graph community 785 and Hypergraph community 85891 have a Jaccard similarity of 0.25.
# Common nodes: {756257}
# Graph community 785 and Hypergraph community 157440 have a Jaccard similarity of 0.25.
# Common nodes: {563507}
# Graph community 786 and Hypergraph community 68601 have a Jaccard similarity of 0.25.
# Common nodes: {327647}
# Graph community 786 and Hypergraph community 143576 have a Jaccard similarity of 0.25.
# Common nodes: {553473}
# Graph community 789 and Hypergraph community 76016 have a Jaccard similarity of 0.25.
# Common nodes: {752420}
# Graph community 789 and Hypergraph community 147531 have a Jaccard similarity of 0.25.
# Common nodes: {556642}
# Graph community 794 and Hypergraph community 283588 have a Jaccard similarity of 0.25.
# Common nodes: {911840}
# Graph community 794 and Hypergraph community 63786 have a Jaccard similarity of 0.25.
# Common nodes: {1051287}
# Graph community 802 and Hypergraph community 69550 have a Jaccard similarity of 0.25.
# Common nodes: {750805}
# Graph community 802 and Hypergraph community 18464 have a Jaccard similarity of 0.25.
# Common nodes: {953485}
# Graph community 806 and Hypergraph community 79826 have a Jaccard similarity of 0.25.
# Common nodes: {753719}
# Graph community 806 and Hypergraph community 19546 have a Jaccard similarity of 0.25.
# Common nodes: {954470}
# Graph community 817 and Hypergraph community 71836 have a Jaccard similarity of 0.25.
# Common nodes: {331243}
# Graph community 827 and Hypergraph community 74399 have a Jaccard similarity of 0.25.
# Common nodes: {333349}
# Graph community 827 and Hypergraph community 266143 have a Jaccard similarity of 0.25.
# Common nodes: {333348}
# Graph community 847 and Hypergraph community 276823 have a Jaccard similarity of 0.25.
# Common nodes: {1024498}
# Graph community 847 and Hypergraph community 89309 have a Jaccard similarity of 0.25.
# Common nodes: {1024499}
# Graph community 853 and Hypergraph community 76414 have a Jaccard similarity of 0.25.
# Common nodes: {752456}
# Graph community 853 and Hypergraph community 147816 have a Jaccard similarity of 0.25.
# Common nodes: {556869}
# Graph community 855 and Hypergraph community 76505 have a Jaccard similarity of 0.25.
# Common nodes: {752459}
# Graph community 858 and Hypergraph community 86347 have a Jaccard similarity of 0.25.
# Common nodes: {756560}
# Graph community 867 and Hypergraph community 88898 have a Jaccard similarity of 0.25.
# Common nodes: {757215}
# Graph community 867 and Hypergraph community 279656 have a Jaccard similarity of 0.25.
# Common nodes: {1105752}
# Graph community 869 and Hypergraph community 285288 have a Jaccard similarity of 0.25.
# Common nodes: {915693}
# Graph community 869 and Hypergraph community 64553 have a Jaccard similarity of 0.25.
# Common nodes: {994371}
# Graph community 872 and Hypergraph community 285401 have a Jaccard similarity of 0.25.
# Common nodes: {915715}
# Graph community 872 and Hypergraph community 64560 have a Jaccard similarity of 0.25.
# Common nodes: {994382}
# Graph community 883 and Hypergraph community 85899 have a Jaccard similarity of 0.25.
# Common nodes: {756478}
# ...
# Common nodes: {995074}
# Graph community 5104 and Hypergraph community 288167 have a Jaccard similarity of 0.25.
# Common nodes: {920957}
# Graph community 5104 and Hypergraph community 65552 have a Jaccard similarity of 0.25.
# Common nodes: {1051315}
# Graph community 5104 and Hypergraph community 95112 have a Jaccard similarity of 0.25.
# Common nodes: {1051316}
# Graph community 5119 and Hypergraph community 289357 have a Jaccard similarity of 0.25.
# Common nodes: {925951}
# Graph community 5119 and Hypergraph community 66328 have a Jaccard similarity of 0.25.
# Common nodes: {995576}
# Graph community 5121 and Hypergraph community 66307 have a Jaccard similarity of 0.25.
# Common nodes: {1009604}
# Graph community 5121 and Hypergraph community 82795 have a Jaccard similarity of 0.25.
# Common nodes: {1009605}
# Graph community 5143 and Hypergraph community 1482 have a Jaccard similarity of 0.25.
# Common nodes: {1072339}
# Graph community 5143 and Hypergraph community 99550 have a Jaccard similarity of 0.25.
# Common nodes: {1072340}
# Graph community 5143 and Hypergraph community 99553 have a Jaccard similarity of 0.25.
# Common nodes: {1072342}
# Graph community 5151 and Hypergraph community 2873 have a Jaccard similarity of 0.25.
# Common nodes: {934191}
# Graph community 5151 and Hypergraph community 68038 have a Jaccard similarity of 0.25.
# Common nodes: {996899}
# Graph community 5151 and Hypergraph community 83141 have a Jaccard similarity of 0.25.
# Common nodes: {1009990}
# Graph community 5153 and Hypergraph community 68145 have a Jaccard similarity of 0.25.
# Common nodes: {996970}
# Graph community 5153 and Hypergraph community 83156 have a Jaccard similarity of 0.25.
# Common nodes: {1010000}
# Graph community 5162 and Hypergraph community 4924 have a Jaccard similarity of 0.33.
# Common nodes: {938265}
# Graph community 5162 and Hypergraph community 68846 have a Jaccard similarity of 0.33.
# Common nodes: {997540}
# Graph community 5164 and Hypergraph community 108326 have a Jaccard similarity of 0.25.
# Common nodes: {1135716}
# Graph community 5167 and Hypergraph community 69125 have a Jaccard similarity of 0.25.
# Common nodes: {997725}
# Graph community 5167 and Hypergraph community 83356 have a Jaccard similarity of 0.25.
# Common nodes: {1129212}
# Graph community 5168 and Hypergraph community 6172 have a Jaccard similarity of 0.25.
# Common nodes: {939565}
# Graph community 5168 and Hypergraph community 69158 have a Jaccard similarity of 0.25.
# Common nodes: {997743}
# Graph community 5168 and Hypergraph community 83363 have a Jaccard similarity of 0.25.
# Common nodes: {1010237}
# Graph community 5168 and Hypergraph community 86416 have a Jaccard similarity of 0.25.
# Common nodes: {1013301}
# Graph community 5179 and Hypergraph community 9093 have a Jaccard similarity of 0.25.
# Common nodes: {1137530}
# Graph community 5179 and Hypergraph community 111889 have a Jaccard similarity of 0.25.
# Common nodes: {1137534}
# Graph community 5179 and Hypergraph community 111892 have a Jaccard similarity of 0.25.
# Common nodes: {1137537}
# Graph community 5181 and Hypergraph community 70160 have a Jaccard similarity of 0.25.
# Common nodes: {998461}
# Graph community 5181 and Hypergraph community 83550 have a Jaccard similarity of 0.25.
# Common nodes: {1010390}
# Graph community 5181 and Hypergraph community 86458 have a Jaccard similarity of 0.25.
# Common nodes: {1013330}
# Graph community 5184 and Hypergraph community 10103 have a Jaccard similarity of 0.25.
# Common nodes: {944358}
# Graph community 5184 and Hypergraph community 70225 have a Jaccard similarity of 0.25.
# Common nodes: {998493}
# Graph community 5185 and Hypergraph community 10287 have a Jaccard similarity of 0.25.
# Common nodes: {1119013}
# Graph community 5185 and Hypergraph community 108342 have a Jaccard similarity of 0.25.
# Common nodes: {1119014}
# Graph community 5185 and Hypergraph community 108344 have a Jaccard similarity of 0.25.
# Common nodes: {1119017}
# Graph community 5187 and Hypergraph community 97491 have a Jaccard similarity of 0.25.
# Common nodes: {1062287}
# Graph community 5187 and Hypergraph community 97494 have a Jaccard similarity of 0.25.
# Common nodes: {1062288}
# Graph community 5188 and Hypergraph community 70351 have a Jaccard similarity of 0.25.
# Common nodes: {998556}
# Graph community 5188 and Hypergraph community 83573 have a Jaccard similarity of 0.25.
# Common nodes: {1010395}
# Graph community 5193 and Hypergraph community 70876 have a Jaccard similarity of 0.25.
# Common nodes: {999043}
# Graph community 5193 and Hypergraph community 83697 have a Jaccard similarity of 0.25.
# Common nodes: {1129213}
# Graph community 5204 and Hypergraph community 109298 have a Jaccard similarity of 0.25.
# Common nodes: {1123867}
# Graph community 5204 and Hypergraph community 109300 have a Jaccard similarity of 0.25.
# Common nodes: {1123868}
# Graph community 5206 and Hypergraph community 15506 have a Jaccard similarity of 0.25.
# Common nodes: {950489}
# Graph community 5206 and Hypergraph community 71698 have a Jaccard similarity of 0.25.
# Common nodes: {999663}
# Graph community 5214 and Hypergraph community 91558 have a Jaccard similarity of 0.25.
# Common nodes: {1134894}
# Graph community 5219 and Hypergraph community 20220 have a Jaccard similarity of 0.25.
# Common nodes: {955271}
# Graph community 5219 and Hypergraph community 72889 have a Jaccard similarity of 0.25.
# Common nodes: {1000659}
# Graph community 5222 and Hypergraph community 73115 have a Jaccard similarity of 0.33.
# Common nodes: {1000824}
# Graph community 5224 and Hypergraph community 90862 have a Jaccard similarity of 0.25.
# Common nodes: {1138088}
# Graph community 5231 and Hypergraph community 73853 have a Jaccard similarity of 0.25.
# Common nodes: {1001474}
# Graph community 5232 and Hypergraph community 73884 have a Jaccard similarity of 0.33.
# Common nodes: {1001495}
# Graph community 5235 and Hypergraph community 25585 have a Jaccard similarity of 0.25.
# Common nodes: {960125}
# Graph community 5235 and Hypergraph community 74078 have a Jaccard similarity of 0.25.
# Common nodes: {1001656}
# Graph community 5237 and Hypergraph community 26759 have a Jaccard similarity of 0.25.
# Common nodes: {961128}
# Graph community 5237 and Hypergraph community 74317 have a Jaccard similarity of 0.25.
# Common nodes: {1001858}
# Graph community 5246 and Hypergraph community 29584 have a Jaccard similarity of 0.25.
# Common nodes: {963338}
# Graph community 5246 and Hypergraph community 74851 have a Jaccard similarity of 0.25.
# Common nodes: {1002345}
# Graph community 5253 and Hypergraph community 33743 have a Jaccard similarity of 0.25.
# Common nodes: {1058558}
# Graph community 5253 and Hypergraph community 96674 have a Jaccard similarity of 0.25.
# Common nodes: {1058561}
# Graph community 5257 and Hypergraph community 76415 have a Jaccard similarity of 0.33.
# Common nodes: {1003749}
# Graph community 5269 and Hypergraph community 77346 have a Jaccard similarity of 0.25.
# Common nodes: {1004581}
# Graph community 5270 and Hypergraph community 42373 have a Jaccard similarity of 0.25.
# Common nodes: {974462}
# Graph community 5270 and Hypergraph community 77683 have a Jaccard similarity of 0.25.
# Common nodes: {1004846}
# Graph community 5270 and Hypergraph community 85092 have a Jaccard similarity of 0.25.
# Common nodes: {1011862}
# Graph community 5270 and Hypergraph community 86795 have a Jaccard similarity of 0.25.
# Common nodes: {1095698}
# Graph community 5271 and Hypergraph community 77749 have a Jaccard similarity of 0.25.
# Common nodes: {1066803}
# Graph community 5271 and Hypergraph community 85100 have a Jaccard similarity of 0.25.
# Common nodes: {1011868}
# Graph community 5274 and Hypergraph community 108418 have a Jaccard similarity of 0.25.
# Common nodes: {1125468}
# Graph community 5282 and Hypergraph community 51914 have a Jaccard similarity of 0.25.
# Common nodes: {983110}
# Graph community 5282 and Hypergraph community 79877 have a Jaccard similarity of 0.25.
# Common nodes: {1006721}
# Graph community 5282 and Hypergraph community 85562 have a Jaccard similarity of 0.25.
# Common nodes: {1012433}
# Graph community 5285 and Hypergraph community 81291 have a Jaccard similarity of 0.25.
# Common nodes: {1008160}
# Graph community 5285 and Hypergraph community 85975 have a Jaccard similarity of 0.25.
# Common nodes: {1012866}
# Graph community 5288 and Hypergraph community 59372 have a Jaccard similarity of 0.25.
# Common nodes: {990284}
# Graph community 5288 and Hypergraph community 81531 have a Jaccard similarity of 0.25.
# Common nodes: {1031791}
# Graph community 5289 and Hypergraph community 60459 have a Jaccard similarity of 0.25.
# Common nodes: {991205}
# Graph community 5289 and Hypergraph community 81711 have a Jaccard similarity of 0.25.
# Common nodes: {1008623}
# Graph community 5289 and Hypergraph community 86076 have a Jaccard similarity of 0.25.
# Common nodes: {1012959}
# Graph community 5291 and Hypergraph community 61212 have a Jaccard similarity of 0.25.
# Common nodes: {991814}
# Graph community 5291 and Hypergraph community 81860 have a Jaccard similarity of 0.25.
# Common nodes: {1008737}
# Graph community 5294 and Hypergraph community 62963 have a Jaccard similarity of 0.33.
# Common nodes: {993219}
# Graph community 5294 and Hypergraph community 86174 have a Jaccard similarity of 0.33.
# Common nodes: {1009076}
# Graph community 5295 and Hypergraph community 82255 have a Jaccard similarity of 0.33.
# Common nodes: {1009117}
# Graph community 5296 and Hypergraph community 82265 have a Jaccard similarity of 0.25.
# Common nodes: {1009127}
# Graph community 5300 and Hypergraph community 82537 have a Jaccard similarity of 0.25.
# Common nodes: {1009404}
# Graph community 5300 and Hypergraph community 86235 have a Jaccard similarity of 0.25.
# Common nodes: {1013135}
# Graph community 5301 and Hypergraph community 65105 have a Jaccard similarity of 0.25.
# Common nodes: {1038409}
# Graph community 5301 and Hypergraph community 92399 have a Jaccard similarity of 0.25.
# Common nodes: {1038412}
# Graph community 5313 and Hypergraph community 107665 have a Jaccard similarity of 0.25.
# Common nodes: {1148682}
# Graph community 5313 and Hypergraph community 108590 have a Jaccard similarity of 0.25.
# Common nodes: {1120380}
# Graph community 5315 and Hypergraph community 87787 have a Jaccard similarity of 0.25.
# Common nodes: {1076095}
# Graph community 5315 and Hypergraph community 100122 have a Jaccard similarity of 0.25.
# Common nodes: {1076098}
# Graph community 5317 and Hypergraph community 89382 have a Jaccard similarity of 0.25.
# Common nodes: {1081959}
# Graph community 5322 and Hypergraph community 90603 have a Jaccard similarity of 0.25.
# Common nodes: {1069999}
# Graph community 5322 and Hypergraph community 99066 have a Jaccard similarity of 0.25.
# Common nodes: {1070001}
# Graph community 5322 and Hypergraph community 99068 have a Jaccard similarity of 0.25.
# Common nodes: {1070004}
# Graph community 5324 and Hypergraph community 91007 have a Jaccard similarity of 0.33.
# Common nodes: {1076156}
# Graph community 5324 and Hypergraph community 100127 have a Jaccard similarity of 0.33.
# Common nodes: {1076158}
# Graph community 17 and Hypergraph community 101822 have a Jaccard similarity of 0.25.
# Common nodes: {1085367}
# Graph community 29 and Hypergraph community 115034 have a Jaccard similarity of 0.25.
# Common nodes: {1156870}
# Graph community 29 and Hypergraph community 115038 have a Jaccard similarity of 0.25.
# Common nodes: {1156875}
# Graph community 59 and Hypergraph community 93177 have a Jaccard similarity of 0.25.
# Common nodes: {1042111}
# Graph community 59 and Hypergraph community 93182 have a Jaccard similarity of 0.25.
# Common nodes: {1042114}
# Graph community 69 and Hypergraph community 95189 have a Jaccard similarity of 0.25.
# Common nodes: {1051587}
# Graph community 70 and Hypergraph community 96769 have a Jaccard similarity of 0.25.
# Common nodes: {1063308}
# Graph community 77 and Hypergraph community 96793 have a Jaccard similarity of 0.25.
# Common nodes: {1059186}
# Graph community 81 and Hypergraph community 96806 have a Jaccard similarity of 0.25.
# Common nodes: {1059197}
# Graph community 82 and Hypergraph community 98504 have a Jaccard similarity of 0.25.
# Common nodes: {1066950}
# Graph community 82 and Hypergraph community 98510 have a Jaccard similarity of 0.25.
# Common nodes: {1066958}
# Graph community 94 and Hypergraph community 114371 have a Jaccard similarity of 0.25.
# Common nodes: {1152678}
# Graph community 94 and Hypergraph community 114373 have a Jaccard similarity of 0.25.
# Common nodes: {1152680}
# Graph community 94 and Hypergraph community 114374 have a Jaccard similarity of 0.25.
# Common nodes: {1152681}
# Graph community 106 and Hypergraph community 93801 have a Jaccard similarity of 0.25.
# Common nodes: {1107556}
# Graph community 106 and Hypergraph community 105991 have a Jaccard similarity of 0.25.
# Common nodes: {1143774}
# Graph community 114 and Hypergraph community 107726 have a Jaccard similarity of 0.33.
# Common nodes: {1116132}
# Graph community 131 and Hypergraph community 97691 have a Jaccard similarity of 0.25.
# Common nodes: {1063182}
# Graph community 136 and Hypergraph community 112966 have a Jaccard similarity of 0.25.
# Common nodes: {1143559}
# Graph community 139 and Hypergraph community 94896 have a Jaccard similarity of 0.25.
# Common nodes: {1055402}
# Graph community 139 and Hypergraph community 96030 have a Jaccard similarity of 0.25.
# Common nodes: {1055422}
# Graph community 147 and Hypergraph community 95846 have a Jaccard similarity of 0.25.
# Common nodes: {1054529}
# Graph community 147 and Hypergraph community 95848 have a Jaccard similarity of 0.25.
# Common nodes: {1054532}
# Graph community 157 and Hypergraph community 98544 have a Jaccard similarity of 0.25.
# Common nodes: {1067239}
# Graph community 183 and Hypergraph community 115061 have a Jaccard similarity of 0.25.
# Common nodes: {1157020}
# Graph community 183 and Hypergraph community 115063 have a Jaccard similarity of 0.25.
# Common nodes: {1157021}
# Graph community 205 and Hypergraph community 103838 have a Jaccard similarity of 0.33.
# Common nodes: {1107884}
# Graph community 206 and Hypergraph community 105248 have a Jaccard similarity of 0.25.
# Common nodes: {1103636}
# Graph community 206 and Hypergraph community 105251 have a Jaccard similarity of 0.25.
# Common nodes: {1120252}
# Graph community 214 and Hypergraph community 103211 have a Jaccard similarity of 0.25.
# Common nodes: {1092456}
# Graph community 214 and Hypergraph community 103214 have a Jaccard similarity of 0.25.
# Common nodes: {1096231}
# Graph community 226 and Hypergraph community 104517 have a Jaccard similarity of 0.25.
# Common nodes: {1099697}
# Graph community 226 and Hypergraph community 104518 have a Jaccard similarity of 0.25.
# Common nodes: {1116472}
# Graph community 259 and Hypergraph community 104332 have a Jaccard similarity of 0.25.
# Common nodes: {1157222}
# Graph community 259 and Hypergraph community 115078 have a Jaccard similarity of 0.25.
# Common nodes: {1157225}
# Graph community 271 and Hypergraph community 104843 have a Jaccard similarity of 0.25.
# Common nodes: {1116490}
# Graph community 271 and Hypergraph community 107805 have a Jaccard similarity of 0.25.
# Common nodes: {1116492}
# Graph community 271 and Hypergraph community 107808 have a Jaccard similarity of 0.25.
# Common nodes: {1116493}
# Graph community 318 and Hypergraph community 110503 have a Jaccard similarity of 0.33.
# Common nodes: {1130428}
# Graph community 353 and Hypergraph community 111555 have a Jaccard similarity of 0.25.
# Common nodes: {1135841}
# Graph community 353 and Hypergraph community 111584 have a Jaccard similarity of 0.25.
# Common nodes: {1135856}
# Graph community 417 and Hypergraph community 114426 have a Jaccard similarity of 0.25.
# Common nodes: {1153185}
# Graph community 417 and Hypergraph community 114435 have a Jaccard similarity of 0.25.
# Common nodes: {1153189}
# Graph community 484 and Hypergraph community 112114 have a Jaccard similarity of 0.25.
# Common nodes: {1138855}
#
# Community pair with the maximum number of shared nodes:
# Graph community 43 and Hypergraph community 26337 share 1 nodes.
# Shared nodes: {228026}

# %% [markdown]
# # ***Jacard Similarrities maximum number of shared nodes***

# %%
import networkx as nx
import hypernetx as hnx
import community as community_louvain  # For Louvain on graph
from collections import defaultdict
from itertools import combinations

# Step 1: Load undirected YouTube network data and create both graph and hypergraph representations
def load_youtube_network_data(filename):
    """Load the YouTube network data and return graph and hypergraph representations."""
    G = nx.Graph()  # For the graph-based representation
    hyperedges = defaultdict(list)  # For the hypergraph-based representation

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):  # Ignore comments
                nodes = list(map(int, line.strip().split()))
                u, v = nodes[0], nodes[1:]
                G.add_edges_from([(u, vi) for vi in v])  # Add edges to graph

                # For hypergraph, treat the first node as a "hyperedge" connected to all subsequent nodes
                hyperedges[u] = v

    H = hnx.Hypergraph(hyperedges)  # Create the hypergraph using HyperNetX
    return G, H

# Step 2: Convert hypergraph to bipartite graph manually
def convert_hypergraph_to_bipartite(H):
    """Convert hypergraph to a bipartite graph."""
    B = nx.Graph()  # Bipartite graph

    for edge_id, nodes in H.incidence_dict.items():
        # Add an edge between the hyperedge (edge_id) and each node in the hyperedge
        for node in nodes:
            B.add_edge(f"edge_{edge_id}", f"node_{node}")

    return B

# Step 3: Apply Louvain community detection on graph
def apply_louvain_on_graph(G):
    """Apply Louvain algorithm for community detection on graph and return partitions."""
    partition = community_louvain.best_partition(G)
    return partition

# Step 4: Apply Louvain-like community detection on hypergraph (via bipartite graph)
def apply_louvain_on_hypergraph(H):
    """Apply Louvain-like algorithm on hypergraph (based on converting to bipartite graph) and return partitions."""
    bipartite_graph = convert_hypergraph_to_bipartite(H)  # Convert hypergraph to bipartite graph
    partition = community_louvain.best_partition(bipartite_graph)  # Apply Louvain on bipartite graph
    return partition

# Helper function: Group nodes by community
def group_nodes_by_community(partition):
    """Group nodes by their community from the partition."""
    communities = defaultdict(list)
    for node, community in partition.items():
        communities[community].append(node)
    return communities

# Step 5: Calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    """Calculate Jaccard similarity between two sets."""
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union != 0 else 0

# Step 6: Find similar communities based on Jaccard similarity
def find_similar_communities(graph_partition, hypergraph_partition, threshold=0.1):
    """Find similar communities between the graph and hypergraph partitions."""
    graph_communities = group_nodes_by_community(graph_partition)
    hypergraph_communities = group_nodes_by_community(hypergraph_partition)

    similar_communities = []

    for g_comm, g_nodes in graph_communities.items():
        g_set = set(g_nodes)
        for h_comm, h_nodes in hypergraph_communities.items():
            h_set = set(int(node.split('_')[1]) for node in h_nodes if node.startswith('node_'))
            similarity = jaccard_similarity(g_set, h_set)
            if similarity > threshold:
                similar_communities.append((g_comm, h_comm, similarity, g_set & h_set))

    return similar_communities

# Step 7: Find the community pair with the maximum number of shared nodes
def find_maximum_shared_nodes(similar_communities):
    """Find the pair of communities with the maximum number of shared nodes."""
    max_shared_nodes = 0
    max_shared_pair = None

    for g_comm, h_comm, similarity, common_nodes in similar_communities:
        if len(common_nodes) > max_shared_nodes:
            max_shared_nodes = len(common_nodes)
            max_shared_pair = (g_comm, h_comm, common_nodes)

    return max_shared_pair, max_shared_nodes

# Main function
def main():
    filename = '/content/drive/My Drive/CSE551/Undirected_Youtube_network.txt' # Path to the YouTube network data

    # Step 1: Load data and create graph/hypergraph
    G, H = load_youtube_network_data(filename)
    print(f"Loaded graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Loaded hypergraph with {len(H.edges)} hyperedges.")

    # Step 2: Apply community detection on graph
    graph_partition = apply_louvain_on_graph(G)
    graph_communities = group_nodes_by_community(graph_partition)
    print(f"Detected {len(graph_communities)} communities in the graph.")

    # Step 3: Apply community detection on hypergraph
    hypergraph_partition = apply_louvain_on_hypergraph(H)
    hypergraph_communities = group_nodes_by_community(hypergraph_partition)
    print(f"Detected {len(hypergraph_communities)} communities in the hypergraph.")

    '''
    # Step 4: Print information about the communities in the graph
    print("\nGraph communities:")
    for comm, nodes in graph_communities.items():
        print(f"Community {comm}: {nodes}")

    # Step 5: Print information about the communities in the hypergraph
    print("\nHypergraph communities:")
    for comm, nodes in hypergraph_communities.items():
        print(f"Community {comm}: {nodes}")
    '''

    # Step 6: Find similar communities based on Jaccard similarity
    similar_communities = find_similar_communities(graph_partition, hypergraph_partition, threshold=0.2)
    print(f"\nFound {len(similar_communities)} similar communities between graph and hypergraph with a threshold of 0.2.")

    # Step 7: Print similar communities and shared nodes
    for g_comm, h_comm, similarity, common_nodes in similar_communities:
        print(f"Graph community {g_comm} and Hypergraph community {h_comm} have a Jaccard similarity of {similarity:.2f}.")
        print(f"Common nodes: {common_nodes}")

    # Step 8: Find and print the community pair with the maximum number of shared nodes
    max_shared_pair, max_shared_nodes = find_maximum_shared_nodes(similar_communities)
    if max_shared_pair:
        g_comm, h_comm, common_nodes = max_shared_pair
        print(f"\nCommunity pair with the maximum number of shared nodes:")
        print(f"Graph community {g_comm} and Hypergraph community {h_comm} share {max_shared_nodes} nodes.")
        print(f"Shared nodes: {common_nodes}")
    else:
        print("\nNo communities with shared nodes found.")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Graph community 4339 and Hypergraph community 21483 have a Jaccard similarity of 0.33.
# Common nodes: {956435}
# Graph community 4339 and Hypergraph community 73002 have a Jaccard similarity of 0.33.
# Common nodes: {1000878}
# Graph community 4340 and Hypergraph community 92329 have a Jaccard similarity of 0.33.
# Common nodes: {1131240}
# Graph community 4340 and Hypergraph community 110581 have a Jaccard similarity of 0.33.
# Common nodes: {1131242}
# Graph community 4341 and Hypergraph community 161959 have a Jaccard similarity of 0.25.
# Common nodes: {848386}
# Graph community 4341 and Hypergraph community 46098 have a Jaccard similarity of 0.25.
# Common nodes: {977883}
# Graph community 4342 and Hypergraph community 161960 have a Jaccard similarity of 0.25.
# Common nodes: {848393}
# Graph community 4342 and Hypergraph community 250170 have a Jaccard similarity of 0.25.
# Common nodes: {619880}
# Graph community 4343 and Hypergraph community 161974 have a Jaccard similarity of 0.25.
# Common nodes: {566483}
# Graph community 4343 and Hypergraph community 250142 have a Jaccard similarity of 0.25.
# Common nodes: {566482}
# Graph community 4346 and Hypergraph community 162132 have a Jaccard similarity of 0.25.
# Common nodes: {848451}
# Graph community 4346 and Hypergraph community 46115 have a Jaccard similarity of 0.25.
# Common nodes: {977895}
# Graph community 4346 and Hypergraph community 78390 have a Jaccard similarity of 0.25.
# Common nodes: {1005600}
# Graph community 4350 and Hypergraph community 93296 have a Jaccard similarity of 0.25.
# Common nodes: {759641}
# Graph community 4350 and Hypergraph community 21605 have a Jaccard similarity of 0.25.
# Common nodes: {956405}
# Graph community 4350 and Hypergraph community 72997 have a Jaccard similarity of 0.25.
# Common nodes: {1000872}
# Graph community 4351 and Hypergraph community 162347 have a Jaccard similarity of 0.33.
# Common nodes: {566710}
# Graph community 4351 and Hypergraph community 250246 have a Jaccard similarity of 0.33.
# Common nodes: {619881}
# Graph community 4352 and Hypergraph community 21681 have a Jaccard similarity of 0.25.
# Common nodes: {956451}
# Graph community 4352 and Hypergraph community 73005 have a Jaccard similarity of 0.25.
# Common nodes: {1000880}
# Graph community 4354 and Hypergraph community 162704 have a Jaccard similarity of 0.33.
# Common nodes: {1074607}
# Graph community 4357 and Hypergraph community 162673 have a Jaccard similarity of 0.25.
# Common nodes: {566870}
# Graph community 4357 and Hypergraph community 250303 have a Jaccard similarity of 0.25.
# Common nodes: {566869}
# Graph community 4363 and Hypergraph community 162956 have a Jaccard similarity of 0.25.
# Common nodes: {567186}
# Graph community 4367 and Hypergraph community 163094 have a Jaccard similarity of 0.33.
# Common nodes: {620044}
# Graph community 4370 and Hypergraph community 163322 have a Jaccard similarity of 0.33.
# Common nodes: {848884}
# Graph community 4371 and Hypergraph community 94315 have a Jaccard similarity of 0.33.
# Common nodes: {1120915}
# Graph community 4371 and Hypergraph community 108592 have a Jaccard similarity of 0.33.
# Common nodes: {1120916}
# Graph community 4371 and Hypergraph community 108595 have a Jaccard similarity of 0.33.
# Common nodes: {1120918}
# Graph community 4372 and Hypergraph community 163633 have a Jaccard similarity of 0.25.
# Common nodes: {848874}
# Graph community 4373 and Hypergraph community 21837 have a Jaccard similarity of 0.33.
# Common nodes: {1000898}
# Graph community 4374 and Hypergraph community 94339 have a Jaccard similarity of 0.33.
# Common nodes: {760119}
# Graph community 4374 and Hypergraph community 21785 have a Jaccard similarity of 0.33.
# Common nodes: {956541}
# Graph community 4374 and Hypergraph community 73026 have a Jaccard similarity of 0.33.
# Common nodes: {1031730}
# Graph community 4376 and Hypergraph community 163376 have a Jaccard similarity of 0.33.
# Common nodes: {567321}
# Graph community 4376 and Hypergraph community 250474 have a Jaccard similarity of 0.33.
# Common nodes: {879816}
# Graph community 4377 and Hypergraph community 163536 have a Jaccard similarity of 0.33.
# Common nodes: {1127056}
# Graph community 4378 and Hypergraph community 163539 have a Jaccard similarity of 0.25.
# Common nodes: {848821}
# Graph community 4378 and Hypergraph community 46218 have a Jaccard similarity of 0.25.
# Common nodes: {977984}
# Graph community 4380 and Hypergraph community 21847 have a Jaccard similarity of 0.33.
# Common nodes: {1044464}
# Graph community 4381 and Hypergraph community 163574 have a Jaccard similarity of 0.33.
# Common nodes: {567414}
# Graph community 4381 and Hypergraph community 250513 have a Jaccard similarity of 0.33.
# Common nodes: {620045}
# Graph community 4384 and Hypergraph community 94601 have a Jaccard similarity of 0.33.
# Common nodes: {1063838}
# Graph community 4384 and Hypergraph community 97667 have a Jaccard similarity of 0.33.
# Common nodes: {1129589}
# Graph community 4384 and Hypergraph community 110291 have a Jaccard similarity of 0.33.
# Common nodes: {1129590}
# Graph community 4390 and Hypergraph community 96913 have a Jaccard similarity of 0.25.
# Common nodes: {1060400}
# Graph community 4390 and Hypergraph community 96917 have a Jaccard similarity of 0.25.
# Common nodes: {1060401}
# Graph community 4390 and Hypergraph community 96919 have a Jaccard similarity of 0.25.
# Common nodes: {1060402}
# Graph community 4392 and Hypergraph community 95456 have a Jaccard similarity of 0.25.
# Common nodes: {760875}
# Graph community 4392 and Hypergraph community 22069 have a Jaccard similarity of 0.25.
# Common nodes: {956711}
# Graph community 4394 and Hypergraph community 208026 have a Jaccard similarity of 0.25.
# Common nodes: {863608}
# Graph community 4398 and Hypergraph community 96147 have a Jaccard similarity of 0.25.
# Common nodes: {761490}
# Graph community 4398 and Hypergraph community 22228 have a Jaccard similarity of 0.25.
# Common nodes: {1050937}
# Graph community 4400 and Hypergraph community 164725 have a Jaccard similarity of 0.25.
# Common nodes: {849288}
# Graph community 4401 and Hypergraph community 164705 have a Jaccard similarity of 0.25.
# Common nodes: {849168}
# Graph community 4404 and Hypergraph community 165040 have a Jaccard similarity of 0.33.
# Common nodes: {568319}
# Graph community 4404 and Hypergraph community 250862 have a Jaccard similarity of 0.33.
# Common nodes: {620275}
# Graph community 4407 and Hypergraph community 97503 have a Jaccard similarity of 0.25.
# Common nodes: {369984}
# Graph community 4407 and Hypergraph community 165311 have a Jaccard similarity of 0.25.
# Common nodes: {849354}
# Graph community 4408 and Hypergraph community 165267 have a Jaccard similarity of 0.25.
# Common nodes: {568467}
# Graph community 4408 and Hypergraph community 250927 have a Jaccard similarity of 0.25.
# Common nodes: {879963}
# Graph community 4412 and Hypergraph community 251034 have a Jaccard similarity of 0.25.
# Common nodes: {568728}
# Graph community 4412 and Hypergraph community 251037 have a Jaccard similarity of 0.25.
# Common nodes: {620340}
# Graph community 4414 and Hypergraph community 165557 have a Jaccard similarity of 0.33.
# Common nodes: {568760}
# Graph community 4414 and Hypergraph community 251051 have a Jaccard similarity of 0.33.
# Common nodes: {620360}
# Graph community 4415 and Hypergraph community 98333 have a Jaccard similarity of 0.33.
# Common nodes: {762188}
# Graph community 4415 and Hypergraph community 22441 have a Jaccard similarity of 0.33.
# Common nodes: {1119203}
# Graph community 4422 and Hypergraph community 166193 have a Jaccard similarity of 0.25.
# Common nodes: {849645}
# Graph community 4423 and Hypergraph community 165004 have a Jaccard similarity of 0.25.
# Common nodes: {372494}
# Graph community 4423 and Hypergraph community 166443 have a Jaccard similarity of 0.25.
# Common nodes: {569318}
# Graph community 4423 and Hypergraph community 251257 have a Jaccard similarity of 0.25.
# Common nodes: {880112}
# Graph community 4424 and Hypergraph community 166023 have a Jaccard similarity of 0.25.
# Common nodes: {807959}
# Graph community 4424 and Hypergraph community 34807 have a Jaccard similarity of 0.25.
# Common nodes: {968137}
# Graph community 4425 and Hypergraph community 22434 have a Jaccard similarity of 0.33.
# Common nodes: {957404}
# Graph community 4427 and Hypergraph community 166111 have a Jaccard similarity of 0.25.
# Common nodes: {849576}
# Graph community 4429 and Hypergraph community 166293 have a Jaccard similarity of 0.25.
# Common nodes: {849660}
# Graph community 4430 and Hypergraph community 166412 have a Jaccard similarity of 0.25.
# Common nodes: {1101552}
# Graph community 4432 and Hypergraph community 166410 have a Jaccard similarity of 0.33.
# Common nodes: {849689}
# Graph community 4432 and Hypergraph community 46495 have a Jaccard similarity of 0.33.
# Common nodes: {978266}
# Graph community 4436 and Hypergraph community 99113 have a Jaccard similarity of 0.33.
# Common nodes: {372710}
# Graph community 4436 and Hypergraph community 166496 have a Jaccard similarity of 0.33.
# Common nodes: {569342}
# Graph community 4437 and Hypergraph community 166491 have a Jaccard similarity of 0.25.
# Common nodes: {849690}
# Graph community 4437 and Hypergraph community 46496 have a Jaccard similarity of 0.25.
# Common nodes: {1051169}
# Graph community 4437 and Hypergraph community 94925 have a Jaccard similarity of 0.25.
# Common nodes: {1051170}
# Graph community 4439 and Hypergraph community 166458 have a Jaccard similarity of 0.33.
# Common nodes: {849676}
# Graph community 4440 and Hypergraph community 99193 have a Jaccard similarity of 0.33.
# Common nodes: {1144591}
# Graph community 4440 and Hypergraph community 112977 have a Jaccard similarity of 0.33.
# Common nodes: {1153420}
# Graph community 4441 and Hypergraph community 99221 have a Jaccard similarity of 0.25.
# Common nodes: {762385}
# Graph community 4441 and Hypergraph community 22504 have a Jaccard similarity of 0.25.
# Common nodes: {1137675}
# Graph community 4441 and Hypergraph community 94127 have a Jaccard similarity of 0.25.
# Common nodes: {1047536}
# Graph community 4445 and Hypergraph community 166578 have a Jaccard similarity of 0.33.
# Common nodes: {849715}
# Graph community 4456 and Hypergraph community 100161 have a Jaccard similarity of 0.25.
# Common nodes: {373870}
# Graph community 4456 and Hypergraph community 166941 have a Jaccard similarity of 0.25.
# Common nodes: {849825}
# Graph community 4456 and Hypergraph community 46531 have a Jaccard similarity of 0.25.
# Common nodes: {978291}
# Graph community 4461 and Hypergraph community 167205 have a Jaccard similarity of 0.33.
# Common nodes: {569891}
# Graph community 4465 and Hypergraph community 22659 have a Jaccard similarity of 0.25.
# Common nodes: {1152068}
# Graph community 4467 and Hypergraph community 167504 have a Jaccard similarity of 0.25.
# Common nodes: {570079}
# Graph community 4467 and Hypergraph community 251485 have a Jaccard similarity of 0.25.
# Common nodes: {570078}
# Graph community 4468 and Hypergraph community 101098 have a Jaccard similarity of 0.25.
# Common nodes: {763197}
# Graph community 4468 and Hypergraph community 22674 have a Jaccard similarity of 0.25.
# Common nodes: {1134036}
# Graph community 4471 and Hypergraph community 251518 have a Jaccard similarity of 0.33.
# Common nodes: {570187}
# Graph community 4472 and Hypergraph community 101476 have a Jaccard similarity of 0.33.
# Common nodes: {763597}
# Graph community 4472 and Hypergraph community 22778 have a Jaccard similarity of 0.33.
# Common nodes: {957831}
# Graph community 4478 and Hypergraph community 101973 have a Jaccard similarity of 0.33.
# Common nodes: {376853}
# Graph community 4478 and Hypergraph community 168212 have a Jaccard similarity of 0.33.
# Common nodes: {850355}
# Graph community 4482 and Hypergraph community 102172 have a Jaccard similarity of 0.33.
# Common nodes: {377092}
# Graph community 4482 and Hypergraph community 168340 have a Jaccard similarity of 0.33.
# Common nodes: {850525}
# Graph community 4484 and Hypergraph community 168563 have a Jaccard similarity of 0.25.
# Common nodes: {850426}
# Graph community 4484 and Hypergraph community 46681 have a Jaccard similarity of 0.25.
# Common nodes: {978428}
# Graph community 4490 and Hypergraph community 87386 have a Jaccard similarity of 0.25.
# Common nodes: {1041443}
# Graph community 4496 and Hypergraph community 103796 have a Jaccard similarity of 0.25.
# Common nodes: {764585}
# Graph community 4496 and Hypergraph community 23088 have a Jaccard similarity of 0.25.
# Common nodes: {958085}
# Graph community 4498 and Hypergraph community 103926 have a Jaccard similarity of 0.33.
# Common nodes: {379640}
# Graph community 4498 and Hypergraph community 169506 have a Jaccard similarity of 0.33.
# Common nodes: {571410}
# Graph community 4506 and Hypergraph community 105203 have a Jaccard similarity of 0.25.
# Common nodes: {380640}
# Graph community 4506 and Hypergraph community 169927 have a Jaccard similarity of 0.25.
# Common nodes: {571720}
# Graph community 4507 and Hypergraph community 105376 have a Jaccard similarity of 0.25.
# Common nodes: {380937}
# Graph community 4507 and Hypergraph community 170046 have a Jaccard similarity of 0.25.
# Common nodes: {850914}
# Graph community 4508 and Hypergraph community 170048 have a Jaccard similarity of 0.33.
# Common nodes: {1083590}
# Graph community 4512 and Hypergraph community 106260 have a Jaccard similarity of 0.25.
# Common nodes: {381716}
# Graph community 4512 and Hypergraph community 170460 have a Jaccard similarity of 0.25.
# Common nodes: {572158}
# Graph community 4513 and Hypergraph community 170498 have a Jaccard similarity of 0.25.
# Common nodes: {572190}
# Graph community 4514 and Hypergraph community 170805 have a Jaccard similarity of 0.25.
# Common nodes: {572381}
# Graph community 4515 and Hypergraph community 170789 have a Jaccard similarity of 0.33.
# Common nodes: {572374}
# Graph community 4515 and Hypergraph community 252270 have a Jaccard similarity of 0.33.
# Common nodes: {621068}
# Graph community 4516 and Hypergraph community 106718 have a Jaccard similarity of 0.33.
# Common nodes: {382401}
# Graph community 4516 and Hypergraph community 170856 have a Jaccard similarity of 0.33.
# Common nodes: {851095}
# Graph community 4518 and Hypergraph community 171076 have a Jaccard similarity of 0.25.
# Common nodes: {572684}
# Graph community 4518 and Hypergraph community 252417 have a Jaccard similarity of 0.25.
# Common nodes: {880405}
# Graph community 4518 and Hypergraph community 55661 have a Jaccard similarity of 0.25.
# Common nodes: {986567}
# Graph community 4519 and Hypergraph community 170973 have a Jaccard similarity of 0.25.
# Common nodes: {572516}
# Graph community 4519 and Hypergraph community 252344 have a Jaccard similarity of 0.25.
# Common nodes: {621166}
# Graph community 4519 and Hypergraph community 270287 have a Jaccard similarity of 0.25.
# Common nodes: {1049894}
# Graph community 4529 and Hypergraph community 107884 have a Jaccard similarity of 0.25.
# Common nodes: {383953}
# Graph community 4529 and Hypergraph community 171646 have a Jaccard similarity of 0.25.
# Common nodes: {851365}
# Graph community 4533 and Hypergraph community 23549 have a Jaccard similarity of 0.33.
# Common nodes: {1128767}
# Graph community 4533 and Hypergraph community 110116 have a Jaccard similarity of 0.33.
# Common nodes: {1128768}
# Graph community 4534 and Hypergraph community 172757 have a Jaccard similarity of 0.33.
# Common nodes: {573656}
# Graph community 4535 and Hypergraph community 172481 have a Jaccard similarity of 0.25.
# Common nodes: {573494}
# Graph community 4543 and Hypergraph community 172767 have a Jaccard similarity of 0.33.
# Common nodes: {1117908}
# Graph community 4545 and Hypergraph community 23617 have a Jaccard similarity of 0.25.
# Common nodes: {958683}
# Graph community 4556 and Hypergraph community 109781 have a Jaccard similarity of 0.25.
# Common nodes: {766570}
# Graph community 4556 and Hypergraph community 23684 have a Jaccard similarity of 0.25.
# Common nodes: {958794}
# Graph community 4559 and Hypergraph community 173617 have a Jaccard similarity of 0.33.
# Common nodes: {574295}
# Graph community 4559 and Hypergraph community 253125 have a Jaccard similarity of 0.33.
# Common nodes: {880682}
# Graph community 4562 and Hypergraph community 111669 have a Jaccard similarity of 0.33.
# Common nodes: {389740}
# Graph community 4562 and Hypergraph community 174024 have a Jaccard similarity of 0.33.
# Common nodes: {574599}
# Graph community 4562 and Hypergraph community 253252 have a Jaccard similarity of 0.33.
# Common nodes: {621736}
# Graph community 4566 and Hypergraph community 112133 have a Jaccard similarity of 0.25.
# Common nodes: {1093117}
# Graph community 4566 and Hypergraph community 103179 have a Jaccard similarity of 0.25.
# Common nodes: {1093120}
# Graph community 4567 and Hypergraph community 24101 have a Jaccard similarity of 0.33.
# Common nodes: {958999}
# Graph community 4567 and Hypergraph community 73613 have a Jaccard similarity of 0.33.
# Common nodes: {1001424}
# Graph community 4569 and Hypergraph community 112635 have a Jaccard similarity of 0.25.
# Common nodes: {767799}
# Graph community 4569 and Hypergraph community 24070 have a Jaccard similarity of 0.25.
# Common nodes: {1137679}
# Graph community 4572 and Hypergraph community 112953 have a Jaccard similarity of 0.25.
# Common nodes: {767814}
# Graph community 4572 and Hypergraph community 24073 have a Jaccard similarity of 0.25.
# Common nodes: {958994}
# Graph community 4572 and Hypergraph community 73611 have a Jaccard similarity of 0.25.
# Common nodes: {1001423}
# Graph community 4573 and Hypergraph community 174939 have a Jaccard similarity of 0.25.
# Common nodes: {852359}
# Graph community 4573 and Hypergraph community 47269 have a Jaccard similarity of 0.25.
# Common nodes: {979023}
# Graph community 4575 and Hypergraph community 113108 have a Jaccard similarity of 0.25.
# Common nodes: {1063892}
# Graph community 4575 and Hypergraph community 97682 have a Jaccard similarity of 0.25.
# Common nodes: {1063893}
# Graph community 4575 and Hypergraph community 97683 have a Jaccard similarity of 0.25.
# Common nodes: {1063895}
# Graph community 4579 and Hypergraph community 175638 have a Jaccard similarity of 0.25.
# Common nodes: {575612}
# Graph community 4579 and Hypergraph community 253663 have a Jaccard similarity of 0.25.
# Common nodes: {880766}
# Graph community 4581 and Hypergraph community 212015 have a Jaccard similarity of 0.33.
# Common nodes: {864851}
# Graph community 4581 and Hypergraph community 50767 have a Jaccard similarity of 0.33.
# Common nodes: {982250}
# Graph community 4585 and Hypergraph community 176098 have a Jaccard similarity of 0.25.
# Common nodes: {575987}
# Graph community 4587 and Hypergraph community 3307 have a Jaccard similarity of 0.25.
# Common nodes: {935136}
# Graph community 4587 and Hypergraph community 68057 have a Jaccard similarity of 0.25.
# Common nodes: {997046}
# Graph community 4587 and Hypergraph community 83002 have a Jaccard similarity of 0.25.
# Common nodes: {1010027}
# Graph community 4588 and Hypergraph community 114822 have a Jaccard similarity of 0.33.
# Common nodes: {394391}
# Graph community 4588 and Hypergraph community 176255 have a Jaccard similarity of 0.33.
# Common nodes: {852726}
# Graph community 4588 and Hypergraph community 47373 have a Jaccard similarity of 0.33.
# Common nodes: {979129}
# Graph community 4589 and Hypergraph community 176214 have a Jaccard similarity of 0.33.
# Common nodes: {575960}
# Graph community 4589 and Hypergraph community 253793 have a Jaccard similarity of 0.33.
# Common nodes: {880825}
# Graph community 4590 and Hypergraph community 176219 have a Jaccard similarity of 0.25.
# Common nodes: {575992}
# Graph community 4590 and Hypergraph community 253801 have a Jaccard similarity of 0.25.
# Common nodes: {1094300}
# Graph community 4591 and Hypergraph community 176222 have a Jaccard similarity of 0.33.
# Common nodes: {576083}
# Graph community 4591 and Hypergraph community 253847 have a Jaccard similarity of 0.33.
# Common nodes: {621998}
# Graph community 4597 and Hypergraph community 92425 have a Jaccard similarity of 0.33.
# Common nodes: {1048158}
# Graph community 4597 and Hypergraph community 94265 have a Jaccard similarity of 0.33.
# Common nodes: {1048159}
# Graph community 4598 and Hypergraph community 108610 have a Jaccard similarity of 0.33.
# Common nodes: {1148743}
# Graph community 4598 and Hypergraph community 113606 have a Jaccard similarity of 0.33.
# Common nodes: {1148744}
# Graph community 4599 and Hypergraph community 218675 have a Jaccard similarity of 0.33.
# Common nodes: {870031}
# Graph community 4600 and Hypergraph community 24316 have a Jaccard similarity of 0.33.
# Common nodes: {959228}
# Graph community 4602 and Hypergraph community 115358 have a Jaccard similarity of 0.33.
# Common nodes: {1096881}
# Graph community 4602 and Hypergraph community 103806 have a Jaccard similarity of 0.33.
# Common nodes: {1141467}
# Graph community 4603 and Hypergraph community 115373 have a Jaccard similarity of 0.33.
# Common nodes: {768614}
# Graph community 4603 and Hypergraph community 24305 have a Jaccard similarity of 0.33.
# Common nodes: {1022269}
# Graph community 4605 and Hypergraph community 176698 have a Jaccard similarity of 0.33.
# Common nodes: {576309}
# Graph community 4606 and Hypergraph community 115442 have a Jaccard similarity of 0.33.
# Common nodes: {768824}
# Graph community 4606 and Hypergraph community 24394 have a Jaccard similarity of 0.33.
# Common nodes: {959305}
# Graph community 4606 and Hypergraph community 73676 have a Jaccard similarity of 0.33.
# Common nodes: {1001469}
# Graph community 4607 and Hypergraph community 176665 have a Jaccard similarity of 0.25.
# Common nodes: {852814}
# Graph community 4608 and Hypergraph community 177154 have a Jaccard similarity of 0.33.
# Common nodes: {853024}
# Graph community 4611 and Hypergraph community 176702 have a Jaccard similarity of 0.33.
# Common nodes: {576272}
# Graph community 4613 and Hypergraph community 177274 have a Jaccard similarity of 0.33.
# Common nodes: {853046}
# Graph community 4614 and Hypergraph community 176977 have a Jaccard similarity of 0.33.
# Common nodes: {576464}
# Graph community 4614 and Hypergraph community 253965 have a Jaccard similarity of 0.33.
# Common nodes: {622044}
# Graph community 4615 and Hypergraph community 176978 have a Jaccard similarity of 0.25.
# Common nodes: {576439}
# Graph community 4615 and Hypergraph community 253959 have a Jaccard similarity of 0.25.
# Common nodes: {880992}
# Graph community 4616 and Hypergraph community 95977 have a Jaccard similarity of 0.33.
# Common nodes: {1055864}
# Graph community 4616 and Hypergraph community 95980 have a Jaccard similarity of 0.33.
# Common nodes: {1055865}
# Graph community 4618 and Hypergraph community 177074 have a Jaccard similarity of 0.33.
# Common nodes: {576481}
# Graph community 4618 and Hypergraph community 253975 have a Jaccard similarity of 0.33.
# Common nodes: {880903}
# Graph community 4619 and Hypergraph community 176996 have a Jaccard similarity of 0.33.
# Common nodes: {1064646}
# Graph community 4620 and Hypergraph community 177038 have a Jaccard similarity of 0.25.
# Common nodes: {852965}
# Graph community 4620 and Hypergraph community 177040 have a Jaccard similarity of 0.25.
# Common nodes: {1056896}
# Graph community 4624 and Hypergraph community 24477 have a Jaccard similarity of 0.33.
# Common nodes: {959379}
# Graph community 4625 and Hypergraph community 177237 have a Jaccard similarity of 0.33.
# Common nodes: {853077}
# Graph community 4625 and Hypergraph community 47483 have a Jaccard similarity of 0.33.
# Common nodes: {979198}
# Graph community 4628 and Hypergraph community 177292 have a Jaccard similarity of 0.25.
# Common nodes: {576692}
# Graph community 4628 and Hypergraph community 254043 have a Jaccard similarity of 0.25.
# Common nodes: {1094301}
# Graph community 4629 and Hypergraph community 107838 have a Jaccard similarity of 0.33.
# Common nodes: {1117192}
# Graph community 4630 and Hypergraph community 177581 have a Jaccard similarity of 0.33.
# Common nodes: {853349}
# Graph community 4630 and Hypergraph community 47552 have a Jaccard similarity of 0.33.
# Common nodes: {979255}
# Graph community 4632 and Hypergraph community 177440 have a Jaccard similarity of 0.25.
# Common nodes: {576711}
# Graph community 4632 and Hypergraph community 254053 have a Jaccard similarity of 0.25.
# Common nodes: {880970}
# Graph community 4634 and Hypergraph community 177488 have a Jaccard similarity of 0.33.
# Common nodes: {576742}
# Graph community 4634 and Hypergraph community 254072 have a Jaccard similarity of 0.33.
# Common nodes: {1071680}
# Graph community 4635 and Hypergraph community 116844 have a Jaccard similarity of 0.25.
# Common nodes: {769432}
# Graph community 4635 and Hypergraph community 24607 have a Jaccard similarity of 0.25.
# Common nodes: {1034749}
# Graph community 4637 and Hypergraph community 117041 have a Jaccard similarity of 0.33.
# Common nodes: {397580}
# Graph community 4637 and Hypergraph community 177731 have a Jaccard similarity of 0.33.
# Common nodes: {576946}
# Graph community 4638 and Hypergraph community 24614 have a Jaccard similarity of 0.33.
# Common nodes: {959425}
# Graph community 4638 and Hypergraph community 73697 have a Jaccard similarity of 0.33.
# Common nodes: {1148067}
# Graph community 4640 and Hypergraph community 117279 have a Jaccard similarity of 0.33.
# Common nodes: {1126150}
# Graph community 4640 and Hypergraph community 109627 have a Jaccard similarity of 0.33.
# Common nodes: {1126151}
# Graph community 4640 and Hypergraph community 109629 have a Jaccard similarity of 0.33.
# Common nodes: {1126155}
# Graph community 4641 and Hypergraph community 177879 have a Jaccard similarity of 0.25.
# Common nodes: {853465}
# Graph community 4641 and Hypergraph community 47565 have a Jaccard similarity of 0.25.
# Common nodes: {979263}
# Graph community 4641 and Hypergraph community 78648 have a Jaccard similarity of 0.25.
# Common nodes: {1141301}
# Graph community 4642 and Hypergraph community 178175 have a Jaccard similarity of 0.33.
# Common nodes: {853522}
# Graph community 4645 and Hypergraph community 178010 have a Jaccard similarity of 0.33.
# Common nodes: {577013}
# Graph community 4645 and Hypergraph community 254150 have a Jaccard similarity of 0.33.
# Common nodes: {622154}
# Graph community 4649 and Hypergraph community 178132 have a Jaccard similarity of 0.25.
# Common nodes: {853493}
# Graph community 4649 and Hypergraph community 254172 have a Jaccard similarity of 0.25.
# Common nodes: {622187}
# Graph community 4650 and Hypergraph community 178203 have a Jaccard similarity of 0.33.
# Common nodes: {1046555}
# Graph community 4651 and Hypergraph community 178324 have a Jaccard similarity of 0.33.
# Common nodes: {1080253}
# Graph community 4652 and Hypergraph community 178154 have a Jaccard similarity of 0.33.
# Common nodes: {577097}
# Graph community 4653 and Hypergraph community 178174 have a Jaccard similarity of 0.33.
# Common nodes: {577090}
# Graph community 4654 and Hypergraph community 24766 have a Jaccard similarity of 0.33.
# Common nodes: {959569}
# Graph community 4655 and Hypergraph community 118358 have a Jaccard similarity of 0.33.
# Common nodes: {661724}
# Graph community 4655 and Hypergraph community 279473 have a Jaccard similarity of 0.33.
# Common nodes: {1132937}
# Graph community 4656 and Hypergraph community 178386 have a Jaccard similarity of 0.33.
# Common nodes: {853661}
# Graph community 4658 and Hypergraph community 178604 have a Jaccard similarity of 0.33.
# Common nodes: {853735}
# Graph community 4659 and Hypergraph community 178492 have a Jaccard similarity of 0.25.
# Common nodes: {1093995}
# Graph community 4661 and Hypergraph community 24934 have a Jaccard similarity of 0.25.
# Common nodes: {959723}
# Graph community 4663 and Hypergraph community 178683 have a Jaccard similarity of 0.33.
# Common nodes: {577414}
# Graph community 4664 and Hypergraph community 118820 have a Jaccard similarity of 0.33.
# Common nodes: {1131355}
# Graph community 4664 and Hypergraph community 110594 have a Jaccard similarity of 0.33.
# Common nodes: {1138797}
# Graph community 4665 and Hypergraph community 178731 have a Jaccard similarity of 0.25.
# Common nodes: {853670}
# Graph community 4665 and Hypergraph community 47625 have a Jaccard similarity of 0.25.
# Common nodes: {979295}
# Graph community 4667 and Hypergraph community 178697 have a Jaccard similarity of 0.25.
# Common nodes: {1114099}
# Graph community 4667 and Hypergraph community 107195 have a Jaccard similarity of 0.25.
# Common nodes: {1114100}
# Graph community 4667 and Hypergraph community 107196 have a Jaccard similarity of 0.25.
# Common nodes: {1114101}
# Graph community 4668 and Hypergraph community 178909 have a Jaccard similarity of 0.33.
# Common nodes: {577584}
# Graph community 4668 and Hypergraph community 254362 have a Jaccard similarity of 0.33.
# Common nodes: {881089}
# Graph community 4676 and Hypergraph community 178905 have a Jaccard similarity of 0.33.
# Common nodes: {577549}
# Graph community 4677 and Hypergraph community 179238 have a Jaccard similarity of 0.33.
# Common nodes: {1097652}
# Graph community 4677 and Hypergraph community 103949 have a Jaccard similarity of 0.33.
# Common nodes: {1097653}
# Graph community 4680 and Hypergraph community 178992 have a Jaccard similarity of 0.33.
# Common nodes: {577596}
# Graph community 4680 and Hypergraph community 254364 have a Jaccard similarity of 0.33.
# Common nodes: {881124}
# Graph community 4682 and Hypergraph community 24983 have a Jaccard similarity of 0.33.
# Common nodes: {959785}
# Graph community 4685 and Hypergraph community 178967 have a Jaccard similarity of 0.33.
# Common nodes: {853700}
# Graph community 4686 and Hypergraph community 179023 have a Jaccard similarity of 0.33.
# Common nodes: {853717}
# Graph community 4687 and Hypergraph community 179014 have a Jaccard similarity of 0.25.
# Common nodes: {1105211}
# Graph community 4687 and Hypergraph community 254413 have a Jaccard similarity of 0.25.
# Common nodes: {577680}
# Graph community 4689 and Hypergraph community 119610 have a Jaccard similarity of 0.25.
# Common nodes: {400899}
# Graph community 4689 and Hypergraph community 179363 have a Jaccard similarity of 0.25.
# Common nodes: {1086903}
# Graph community 4689 and Hypergraph community 254458 have a Jaccard similarity of 0.25.
# Common nodes: {622378}
# Graph community 4692 and Hypergraph community 179260 have a Jaccard similarity of 0.33.
# Common nodes: {577803}
# Graph community 4692 and Hypergraph community 254453 have a Jaccard similarity of 0.33.
# Common nodes: {622376}
# Graph community 4693 and Hypergraph community 179271 have a Jaccard similarity of 0.25.
# Common nodes: {853766}
# Graph community 4693 and Hypergraph community 47653 have a Jaccard similarity of 0.25.
# Common nodes: {979347}
# Graph community 4695 and Hypergraph community 179521 have a Jaccard similarity of 0.33.
# Common nodes: {577908}
# Graph community 4696 and Hypergraph community 179807 have a Jaccard similarity of 0.33.
# Common nodes: {854060}
# Graph community 4697 and Hypergraph community 119900 have a Jaccard similarity of 0.33.
# Common nodes: {401223}
# Graph community 4697 and Hypergraph community 179453 have a Jaccard similarity of 0.33.
# Common nodes: {577856}
# Graph community 4697 and Hypergraph community 254475 have a Jaccard similarity of 0.33.
# Common nodes: {622344}
# Graph community 4699 and Hypergraph community 179699 have a Jaccard similarity of 0.33.
# Common nodes: {578021}
# Graph community 4701 and Hypergraph community 120066 have a Jaccard similarity of 0.33.
# Common nodes: {401822}
# Graph community 4701 and Hypergraph community 179694 have a Jaccard similarity of 0.33.
# Common nodes: {853982}
# Graph community 4701 and Hypergraph community 47708 have a Jaccard similarity of 0.33.
# Common nodes: {979372}
# Graph community 4703 and Hypergraph community 179653 have a Jaccard similarity of 0.25.
# Common nodes: {1097655}
# Graph community 4703 and Hypergraph community 47688 have a Jaccard similarity of 0.25.
# Common nodes: {979360}
# Graph community 4706 and Hypergraph community 25114 have a Jaccard similarity of 0.33.
# Common nodes: {959961}
# Graph community 4707 and Hypergraph community 179578 have a Jaccard similarity of 0.33.
# Common nodes: {853842}
# Graph community 4709 and Hypergraph community 179881 have a Jaccard similarity of 0.33.
# Common nodes: {578101}
# Graph community 4711 and Hypergraph community 179885 have a Jaccard similarity of 0.33.
# Common nodes: {578060}
# Graph community 4711 and Hypergraph community 254534 have a Jaccard similarity of 0.33.
# Common nodes: {881101}
# Graph community 4713 and Hypergraph community 179897 have a Jaccard similarity of 0.25.
# Common nodes: {1077447}
# Graph community 4714 and Hypergraph community 180106 have a Jaccard similarity of 0.33.
# Common nodes: {578205}
# Graph community 4714 and Hypergraph community 254589 have a Jaccard similarity of 0.33.
# Common nodes: {622426}
# Graph community 4718 and Hypergraph community 179907 have a Jaccard similarity of 0.33.
# Common nodes: {578107}
# Graph community 4719 and Hypergraph community 179915 have a Jaccard similarity of 0.33.
# Common nodes: {578145}
# Graph community 4720 and Hypergraph community 180134 have a Jaccard similarity of 0.25.
# Common nodes: {854198}
# Graph community 4720 and Hypergraph community 47743 have a Jaccard similarity of 0.25.
# Common nodes: {979395}
# Graph community 4721 and Hypergraph community 180096 have a Jaccard similarity of 0.33.
# Common nodes: {578195}
# Graph community 4721 and Hypergraph community 254583 have a Jaccard similarity of 0.33.
# Common nodes: {622425}
# Graph community 4723 and Hypergraph community 180116 have a Jaccard similarity of 0.33.
# Common nodes: {854181}
# Graph community 4724 and Hypergraph community 180243 have a Jaccard similarity of 0.33.
# Common nodes: {578292}
# Graph community 4724 and Hypergraph community 254611 have a Jaccard similarity of 0.33.
# Common nodes: {622434}
# Graph community 4726 and Hypergraph community 120939 have a Jaccard similarity of 0.33.
# Common nodes: {771868}
# Graph community 4726 and Hypergraph community 25213 have a Jaccard similarity of 0.33.
# Common nodes: {960134}
# Graph community 4727 and Hypergraph community 180405 have a Jaccard similarity of 0.25.
# Common nodes: {854234}
# Graph community 4729 and Hypergraph community 180480 have a Jaccard similarity of 0.33.
# Common nodes: {854257}
# Graph community 4730 and Hypergraph community 180424 have a Jaccard similarity of 0.33.
# Common nodes: {578369}
# Graph community 4731 and Hypergraph community 180468 have a Jaccard similarity of 0.33.
# Common nodes: {854356}
# Graph community 4731 and Hypergraph community 47782 have a Jaccard similarity of 0.33.
# Common nodes: {979417}
# Graph community 4732 and Hypergraph community 180528 have a Jaccard similarity of 0.25.
# Common nodes: {1140185}
# Graph community 4733 and Hypergraph community 180702 have a Jaccard similarity of 0.33.
# Common nodes: {854354}
# Graph community 4735 and Hypergraph community 25283 have a Jaccard similarity of 0.33.
# Common nodes: {960022}
# Graph community 4735 and Hypergraph community 73887 have a Jaccard similarity of 0.33.
# Common nodes: {1001640}
# Graph community 4736 and Hypergraph community 180930 have a Jaccard similarity of 0.25.
# Common nodes: {854456}
# Graph community 4737 and Hypergraph community 25227 have a Jaccard similarity of 0.33.
# Common nodes: {959933}
# Graph community 4737 and Hypergraph community 73851 have a Jaccard similarity of 0.33.
# Common nodes: {1001623}
# Graph community 4740 and Hypergraph community 180859 have a Jaccard similarity of 0.25.
# Common nodes: {578583}
# Graph community 4740 and Hypergraph community 254733 have a Jaccard similarity of 0.25.
# Common nodes: {622539}
# Graph community 4741 and Hypergraph community 180801 have a Jaccard similarity of 0.33.
# Common nodes: {578548}
# Graph community 4744 and Hypergraph community 180770 have a Jaccard similarity of 0.33.
# Common nodes: {578535}
# Graph community 4745 and Hypergraph community 180870 have a Jaccard similarity of 0.33.
# Common nodes: {854421}
# Graph community 4745 and Hypergraph community 47793 have a Jaccard similarity of 0.33.
# Common nodes: {979423}
# Graph community 4747 and Hypergraph community 180779 have a Jaccard similarity of 0.25.
# Common nodes: {1049479}
# Graph community 4747 and Hypergraph community 94571 have a Jaccard similarity of 0.25.
# Common nodes: {1049480}
# Graph community 4747 and Hypergraph community 94573 have a Jaccard similarity of 0.25.
# Common nodes: {1049481}
# Graph community 4748 and Hypergraph community 25286 have a Jaccard similarity of 0.33.
# Common nodes: {959969}
# Graph community 4748 and Hypergraph community 73868 have a Jaccard similarity of 0.33.
# Common nodes: {1001629}
# Graph community 4749 and Hypergraph community 121960 have a Jaccard similarity of 0.33.
# Common nodes: {405082}
# Graph community 4749 and Hypergraph community 180897 have a Jaccard similarity of 0.33.
# Common nodes: {578602}
# Graph community 4749 and Hypergraph community 254744 have a Jaccard similarity of 0.33.
# Common nodes: {622516}
# Graph community 4752 and Hypergraph community 180974 have a Jaccard similarity of 0.33.
# Common nodes: {578625}
# Graph community 4757 and Hypergraph community 25378 have a Jaccard similarity of 0.25.
# Common nodes: {960044}
# Graph community 4758 and Hypergraph community 181513 have a Jaccard similarity of 0.25.
# Common nodes: {854618}
# Graph community 4758 and Hypergraph community 47859 have a Jaccard similarity of 0.25.
# Common nodes: {1027908}
# Graph community 4759 and Hypergraph community 25323 have a Jaccard similarity of 0.33.
# Common nodes: {960003}
# Graph community 4759 and Hypergraph community 73878 have a Jaccard similarity of 0.33.
# Common nodes: {1001637}
# Graph community 4761 and Hypergraph community 181490 have a Jaccard similarity of 0.33.
# Common nodes: {854628}
# Graph community 4761 and Hypergraph community 47865 have a Jaccard similarity of 0.33.
# Common nodes: {979481}
# Graph community 4763 and Hypergraph community 181559 have a Jaccard similarity of 0.33.
# Common nodes: {578921}
# Graph community 4763 and Hypergraph community 254860 have a Jaccard similarity of 0.33.
# Common nodes: {622557}
# Graph community 4764 and Hypergraph community 123071 have a Jaccard similarity of 0.33.
# Common nodes: {772655}
# Graph community 4764 and Hypergraph community 25420 have a Jaccard similarity of 0.33.
# Common nodes: {960084}
# Graph community 4765 and Hypergraph community 103814 have a Jaccard similarity of 0.33.
# Common nodes: {1096909}
# Graph community 4769 and Hypergraph community 181689 have a Jaccard similarity of 0.33.
# Common nodes: {854708}
# Graph community 4769 and Hypergraph community 47897 have a Jaccard similarity of 0.33.
# Common nodes: {979505}
# Graph community 4772 and Hypergraph community 181973 have a Jaccard similarity of 0.33.
# Common nodes: {579096}
# Graph community 4778 and Hypergraph community 181997 have a Jaccard similarity of 0.25.
# Common nodes: {854734}
# Graph community 4778 and Hypergraph community 47919 have a Jaccard similarity of 0.25.
# Common nodes: {979517}
# Graph community 4779 and Hypergraph community 182247 have a Jaccard similarity of 0.33.
# Common nodes: {1043411}
# Graph community 4781 and Hypergraph community 182032 have a Jaccard similarity of 0.33.
# Common nodes: {579155}
# Graph community 4783 and Hypergraph community 25491 have a Jaccard similarity of 0.25.
# Common nodes: {960091}
# Graph community 4783 and Hypergraph community 73906 have a Jaccard similarity of 0.25.
# Common nodes: {1001650}
# Graph community 4784 and Hypergraph community 25513 have a Jaccard similarity of 0.33.
# Common nodes: {1066411}
# Graph community 4787 and Hypergraph community 182365 have a Jaccard similarity of 0.25.
# Common nodes: {579316}
# Graph community 4787 and Hypergraph community 254999 have a Jaccard similarity of 0.25.
# Common nodes: {622661}
# Graph community 4788 and Hypergraph community 113782 have a Jaccard similarity of 0.33.
# Common nodes: {1149817}
# Graph community 4789 and Hypergraph community 124887 have a Jaccard similarity of 0.33.
# Common nodes: {773057}
# Graph community 4789 and Hypergraph community 25548 have a Jaccard similarity of 0.33.
# Common nodes: {1047589}
# Graph community 4790 and Hypergraph community 182608 have a Jaccard similarity of 0.33.
# Common nodes: {854988}
# Graph community 4793 and Hypergraph community 182660 have a Jaccard similarity of 0.33.
# Common nodes: {854999}
# Graph community 4794 and Hypergraph community 182600 have a Jaccard similarity of 0.33.
# Common nodes: {854996}
# Graph community 4795 and Hypergraph community 182630 have a Jaccard similarity of 0.33.
# Common nodes: {855291}
# Graph community 4795 and Hypergraph community 48065 have a Jaccard similarity of 0.33.
# Common nodes: {979652}
# Graph community 4796 and Hypergraph community 182789 have a Jaccard similarity of 0.33.
# Common nodes: {855265}
# Graph community 4796 and Hypergraph community 48056 have a Jaccard similarity of 0.33.
# Common nodes: {979637}
# Graph community 4801 and Hypergraph community 125393 have a Jaccard similarity of 0.25.
# Common nodes: {409626}
# Graph community 4801 and Hypergraph community 182864 have a Jaccard similarity of 0.25.
# Common nodes: {855061}
# Graph community 4802 and Hypergraph community 182826 have a Jaccard similarity of 0.25.
# Common nodes: {579539}
# Graph community 4802 and Hypergraph community 255080 have a Jaccard similarity of 0.25.
# Common nodes: {648686}
# Graph community 4805 and Hypergraph community 182848 have a Jaccard similarity of 0.33.
# Common nodes: {579696}
# Graph community 4805 and Hypergraph community 255144 have a Jaccard similarity of 0.33.
# Common nodes: {622719}
# Graph community 4806 and Hypergraph community 182948 have a Jaccard similarity of 0.33.
# Common nodes: {579622}
# Graph community 4806 and Hypergraph community 255113 have a Jaccard similarity of 0.33.
# Common nodes: {622694}
# Graph community 4808 and Hypergraph community 126052 have a Jaccard similarity of 0.33.
# Common nodes: {410114}
# Graph community 4808 and Hypergraph community 183143 have a Jaccard similarity of 0.33.
# Common nodes: {855154}
# Graph community 4809 and Hypergraph community 126209 have a Jaccard similarity of 0.33.
# Common nodes: {773691}
# Graph community 4809 and Hypergraph community 25706 have a Jaccard similarity of 0.33.
# Common nodes: {1022316}
# Graph community 4809 and Hypergraph community 88779 have a Jaccard similarity of 0.33.
# Common nodes: {1022317}
# Graph community 4810 and Hypergraph community 255199 have a Jaccard similarity of 0.25.
# Common nodes: {622735}
# Graph community 4810 and Hypergraph community 270801 have a Jaccard similarity of 0.25.
# Common nodes: {632563}
# Graph community 4812 and Hypergraph community 265336 have a Jaccard similarity of 0.25.
# Common nodes: {410643}
# Graph community 4812 and Hypergraph community 183435 have a Jaccard similarity of 0.25.
# Common nodes: {579907}
# Graph community 4812 and Hypergraph community 255230 have a Jaccard similarity of 0.25.
# Common nodes: {881292}
# Graph community 4812 and Hypergraph community 55889 have a Jaccard similarity of 0.25.
# Common nodes: {986791}
# Graph community 4813 and Hypergraph community 183762 have a Jaccard similarity of 0.33.
# Common nodes: {855464}
# Graph community 4815 and Hypergraph community 276020 have a Jaccard similarity of 0.25.
# Common nodes: {773967}
# Graph community 4815 and Hypergraph community 25830 have a Jaccard similarity of 0.25.
# Common nodes: {960494}
# Graph community 4816 and Hypergraph community 183774 have a Jaccard similarity of 0.25.
# Common nodes: {580165}
# Graph community 4816 and Hypergraph community 255355 have a Jaccard similarity of 0.25.
# Common nodes: {881352}
# Graph community 4817 and Hypergraph community 127798 have a Jaccard similarity of 0.33.
# Common nodes: {1131374}
# Graph community 4817 and Hypergraph community 110600 have a Jaccard similarity of 0.33.
# Common nodes: {1131379}
# Graph community 4820 and Hypergraph community 184006 have a Jaccard similarity of 0.33.
# Common nodes: {855487}
# Graph community 4820 and Hypergraph community 48115 have a Jaccard similarity of 0.33.
# Common nodes: {979691}
# Graph community 4822 and Hypergraph community 184068 have a Jaccard similarity of 0.33.
# Common nodes: {855606}
# Graph community 4822 and Hypergraph community 48144 have a Jaccard similarity of 0.33.
# Common nodes: {979717}
# Graph community 4823 and Hypergraph community 184070 have a Jaccard similarity of 0.33.
# Common nodes: {580267}
# Graph community 4823 and Hypergraph community 255415 have a Jaccard similarity of 0.33.
# Common nodes: {622881}
# Graph community 4825 and Hypergraph community 128166 have a Jaccard similarity of 0.25.
# Common nodes: {774213}
# Graph community 4825 and Hypergraph community 25906 have a Jaccard similarity of 0.25.
# Common nodes: {960442}
# Graph community 4825 and Hypergraph community 73991 have a Jaccard similarity of 0.25.
# Common nodes: {1031732}
# Graph community 4826 and Hypergraph community 183998 have a Jaccard similarity of 0.33.
# Common nodes: {855481}
# Graph community 4826 and Hypergraph community 48113 have a Jaccard similarity of 0.33.
# Common nodes: {979689}
# Graph community 4828 and Hypergraph community 184028 have a Jaccard similarity of 0.33.
# Common nodes: {855725}
# Graph community 4828 and Hypergraph community 48189 have a Jaccard similarity of 0.33.
# Common nodes: {979764}
# Graph community 4830 and Hypergraph community 184223 have a Jaccard similarity of 0.33.
# Common nodes: {855576}
# Graph community 4831 and Hypergraph community 184289 have a Jaccard similarity of 0.33.
# Common nodes: {855727}
# Graph community 4834 and Hypergraph community 128870 have a Jaccard similarity of 0.25.
# Common nodes: {774626}
# Graph community 4834 and Hypergraph community 26082 have a Jaccard similarity of 0.25.
# Common nodes: {960513}
# Graph community 4835 and Hypergraph community 184422 have a Jaccard similarity of 0.33.
# Common nodes: {580520}
# Graph community 4835 and Hypergraph community 255516 have a Jaccard similarity of 0.33.
# Common nodes: {622906}
# Graph community 4836 and Hypergraph community 184426 have a Jaccard similarity of 0.25.
# Common nodes: {580504}
# Graph community 4836 and Hypergraph community 255512 have a Jaccard similarity of 0.25.
# Common nodes: {622891}
# Graph community 4840 and Hypergraph community 129077 have a Jaccard similarity of 0.33.
# Common nodes: {1035970}
# Graph community 4840 and Hypergraph community 91714 have a Jaccard similarity of 0.33.
# Common nodes: {1035972}
# Graph community 4841 and Hypergraph community 184580 have a Jaccard similarity of 0.25.
# Common nodes: {580638}
# Graph community 4843 and Hypergraph community 184589 have a Jaccard similarity of 0.25.
# Common nodes: {979785}
# Graph community 4843 and Hypergraph community 78768 have a Jaccard similarity of 0.25.
# Common nodes: {1051414}
# Graph community 4844 and Hypergraph community 129415 have a Jaccard similarity of 0.33.
# Common nodes: {413040}
# Graph community 4844 and Hypergraph community 184630 have a Jaccard similarity of 0.33.
# Common nodes: {855777}
# Graph community 4844 and Hypergraph community 48206 have a Jaccard similarity of 0.33.
# Common nodes: {979771}
# Graph community 4847 and Hypergraph community 185373 have a Jaccard similarity of 0.33.
# Common nodes: {581050}
# Graph community 4853 and Hypergraph community 131014 have a Jaccard similarity of 0.25.
# Common nodes: {415445}
# Graph community 4853 and Hypergraph community 185512 have a Jaccard similarity of 0.25.
# Common nodes: {856109}
# Graph community 4855 and Hypergraph community 26283 have a Jaccard similarity of 0.33.
# Common nodes: {960720}
# Graph community 4856 and Hypergraph community 185605 have a Jaccard similarity of 0.33.
# Common nodes: {581184}
# Graph community 4856 and Hypergraph community 255762 have a Jaccard similarity of 0.33.
# Common nodes: {623028}
# Graph community 4857 and Hypergraph community 185607 have a Jaccard similarity of 0.33.
# Common nodes: {856098}
# Graph community 4859 and Hypergraph community 185853 have a Jaccard similarity of 0.33.
# Common nodes: {581343}
# Graph community 4860 and Hypergraph community 26352 have a Jaccard similarity of 0.25.
# Common nodes: {1022339}
# Graph community 4860 and Hypergraph community 74074 have a Jaccard similarity of 0.25.
# Common nodes: {1148068}
# Graph community 4861 and Hypergraph community 26353 have a Jaccard similarity of 0.33.
# Common nodes: {960810}
# ...
# Common nodes: {967981}
# Graph community 7119 and Hypergraph community 75801 have a Jaccard similarity of 0.33.
# Common nodes: {1003392}
# Graph community 7122 and Hypergraph community 76215 have a Jaccard similarity of 0.33.
# Common nodes: {1003749}
# Graph community 7129 and Hypergraph community 39310 have a Jaccard similarity of 0.33.
# Common nodes: {971886}
# Graph community 7129 and Hypergraph community 76824 have a Jaccard similarity of 0.33.
# Common nodes: {1004241}
# Graph community 7132 and Hypergraph community 77167 have a Jaccard similarity of 0.25.
# Common nodes: {1004591}
# Graph community 7133 and Hypergraph community 77154 have a Jaccard similarity of 0.25.
# Common nodes: {1004581}
# Graph community 7134 and Hypergraph community 41884 have a Jaccard similarity of 0.33.
# Common nodes: {1115477}
# Graph community 7134 and Hypergraph community 107465 have a Jaccard similarity of 0.33.
# Common nodes: {1115479}
# Graph community 7135 and Hypergraph community 42355 have a Jaccard similarity of 0.25.
# Common nodes: {974462}
# Graph community 7135 and Hypergraph community 77493 have a Jaccard similarity of 0.25.
# Common nodes: {1004846}
# Graph community 7135 and Hypergraph community 84918 have a Jaccard similarity of 0.25.
# Common nodes: {1011862}
# Graph community 7135 and Hypergraph community 86611 have a Jaccard similarity of 0.25.
# Common nodes: {1095698}
# Graph community 7136 and Hypergraph community 77507 have a Jaccard similarity of 0.25.
# Common nodes: {1004856}
# Graph community 7136 and Hypergraph community 84919 have a Jaccard similarity of 0.25.
# Common nodes: {1011864}
# Graph community 7137 and Hypergraph community 77565 have a Jaccard similarity of 0.25.
# Common nodes: {1066803}
# Graph community 7137 and Hypergraph community 84926 have a Jaccard similarity of 0.25.
# Common nodes: {1011868}
# Graph community 7139 and Hypergraph community 77699 have a Jaccard similarity of 0.33.
# Common nodes: {1004982}
# Graph community 7141 and Hypergraph community 108288 have a Jaccard similarity of 0.25.
# Common nodes: {1125468}
# Graph community 7146 and Hypergraph community 50422 have a Jaccard similarity of 0.33.
# Common nodes: {1098993}
# Graph community 7146 and Hypergraph community 104212 have a Jaccard similarity of 0.33.
# Common nodes: {1098994}
# Graph community 7146 and Hypergraph community 104213 have a Jaccard similarity of 0.33.
# Common nodes: {1098995}
# Graph community 7151 and Hypergraph community 51873 have a Jaccard similarity of 0.25.
# Common nodes: {983110}
# Graph community 7151 and Hypergraph community 79666 have a Jaccard similarity of 0.25.
# Common nodes: {1006721}
# Graph community 7151 and Hypergraph community 85373 have a Jaccard similarity of 0.25.
# Common nodes: {1012433}
# Graph community 7153 and Hypergraph community 53533 have a Jaccard similarity of 0.33.
# Common nodes: {1091794}
# Graph community 7153 and Hypergraph community 102941 have a Jaccard similarity of 0.33.
# Common nodes: {1091795}
# Graph community 7153 and Hypergraph community 102943 have a Jaccard similarity of 0.33.
# Common nodes: {1120092}
# Graph community 7158 and Hypergraph community 59821 have a Jaccard similarity of 0.25.
# Common nodes: {1075956}
# Graph community 7158 and Hypergraph community 99978 have a Jaccard similarity of 0.25.
# Common nodes: {1088878}
# Graph community 7159 and Hypergraph community 60312 have a Jaccard similarity of 0.25.
# Common nodes: {991205}
# Graph community 7159 and Hypergraph community 81521 have a Jaccard similarity of 0.25.
# Common nodes: {1008623}
# Graph community 7159 and Hypergraph community 85892 have a Jaccard similarity of 0.25.
# Common nodes: {1012959}
# Graph community 7163 and Hypergraph community 61445 have a Jaccard similarity of 0.33.
# Common nodes: {992096}
# Graph community 7163 and Hypergraph community 81742 have a Jaccard similarity of 0.33.
# Common nodes: {1008809}
# Graph community 7165 and Hypergraph community 62797 have a Jaccard similarity of 0.33.
# Common nodes: {993219}
# Graph community 7165 and Hypergraph community 82037 have a Jaccard similarity of 0.33.
# Common nodes: {1009076}
# Graph community 7166 and Hypergraph community 82077 have a Jaccard similarity of 0.33.
# Common nodes: {1009117}
# Graph community 7167 and Hypergraph community 82091 have a Jaccard similarity of 0.25.
# Common nodes: {1009127}
# Graph community 7170 and Hypergraph community 108297 have a Jaccard similarity of 0.25.
# Common nodes: {1119467}
# Graph community 7170 and Hypergraph community 108298 have a Jaccard similarity of 0.25.
# Common nodes: {1119468}
# Graph community 7171 and Hypergraph community 82356 have a Jaccard similarity of 0.25.
# Common nodes: {1009404}
# Graph community 7171 and Hypergraph community 86056 have a Jaccard similarity of 0.25.
# Common nodes: {1013135}
# Graph community 7172 and Hypergraph community 64933 have a Jaccard similarity of 0.25.
# Common nodes: {1038409}
# Graph community 7172 and Hypergraph community 92223 have a Jaccard similarity of 0.25.
# Common nodes: {1038412}
# Graph community 7177 and Hypergraph community 69799 have a Jaccard similarity of 0.25.
# Common nodes: {998373}
# Graph community 7177 and Hypergraph community 86274 have a Jaccard similarity of 0.25.
# Common nodes: {1010370}
# Graph community 7178 and Hypergraph community 102326 have a Jaccard similarity of 0.33.
# Common nodes: {1088499}
# Graph community 7181 and Hypergraph community 82444 have a Jaccard similarity of 0.25.
# Common nodes: {1062928}
# Graph community 7181 and Hypergraph community 97466 have a Jaccard similarity of 0.25.
# Common nodes: {1062930}
# Graph community 7181 and Hypergraph community 97469 have a Jaccard similarity of 0.25.
# Common nodes: {1062931}
# Graph community 7184 and Hypergraph community 87228 have a Jaccard similarity of 0.33.
# Common nodes: {1103123}
# Graph community 7184 and Hypergraph community 104976 have a Jaccard similarity of 0.33.
# Common nodes: {1103125}
# Graph community 7185 and Hypergraph community 100373 have a Jaccard similarity of 0.33.
# Common nodes: {1078628}
# Graph community 7186 and Hypergraph community 87401 have a Jaccard similarity of 0.33.
# Common nodes: {1015847}
# Graph community 7186 and Hypergraph community 87402 have a Jaccard similarity of 0.33.
# Common nodes: {1015849}
# Graph community 7188 and Hypergraph community 87421 have a Jaccard similarity of 0.33.
# Common nodes: {1035261}
# Graph community 7188 and Hypergraph community 91528 have a Jaccard similarity of 0.33.
# Common nodes: {1099349}
# Graph community 7190 and Hypergraph community 87590 have a Jaccard similarity of 0.25.
# Common nodes: {1076095}
# Graph community 7190 and Hypergraph community 100003 have a Jaccard similarity of 0.25.
# Common nodes: {1076098}
# Graph community 7192 and Hypergraph community 89190 have a Jaccard similarity of 0.25.
# Common nodes: {1081959}
# Graph community 7197 and Hypergraph community 90404 have a Jaccard similarity of 0.25.
# Common nodes: {1069999}
# Graph community 7197 and Hypergraph community 98892 have a Jaccard similarity of 0.25.
# Common nodes: {1070001}
# Graph community 7197 and Hypergraph community 98893 have a Jaccard similarity of 0.25.
# Common nodes: {1070004}
# Graph community 7199 and Hypergraph community 90813 have a Jaccard similarity of 0.33.
# Common nodes: {1076156}
# Graph community 7199 and Hypergraph community 100007 have a Jaccard similarity of 0.33.
# Common nodes: {1076158}
# Graph community 7203 and Hypergraph community 101668 have a Jaccard similarity of 0.25.
# Common nodes: {1085358}
# Graph community 7205 and Hypergraph community 101672 have a Jaccard similarity of 0.25.
# Common nodes: {1085367}
# Graph community 7209 and Hypergraph community 114862 have a Jaccard similarity of 0.25.
# Common nodes: {1156870}
# Graph community 7209 and Hypergraph community 114865 have a Jaccard similarity of 0.25.
# Common nodes: {1156875}
# Graph community 7213 and Hypergraph community 92993 have a Jaccard similarity of 0.25.
# Common nodes: {1042111}
# Graph community 7213 and Hypergraph community 92998 have a Jaccard similarity of 0.25.
# Common nodes: {1042114}
# Graph community 7217 and Hypergraph community 94250 have a Jaccard similarity of 0.25.
# Common nodes: {1048111}
# Graph community 7219 and Hypergraph community 95033 have a Jaccard similarity of 0.25.
# Common nodes: {1051587}
# Graph community 7220 and Hypergraph community 96602 have a Jaccard similarity of 0.25.
# Common nodes: {1063308}
# Graph community 7222 and Hypergraph community 96627 have a Jaccard similarity of 0.25.
# Common nodes: {1059186}
# Graph community 7224 and Hypergraph community 98315 have a Jaccard similarity of 0.25.
# Common nodes: {1066950}
# Graph community 7224 and Hypergraph community 98322 have a Jaccard similarity of 0.25.
# Common nodes: {1066958}
# Graph community 7229 and Hypergraph community 110243 have a Jaccard similarity of 0.25.
# Common nodes: {1129372}
# Graph community 7229 and Hypergraph community 110249 have a Jaccard similarity of 0.25.
# Common nodes: {1129375}
# Graph community 7230 and Hypergraph community 114198 have a Jaccard similarity of 0.25.
# Common nodes: {1152678}
# Graph community 7230 and Hypergraph community 114200 have a Jaccard similarity of 0.25.
# Common nodes: {1152680}
# Graph community 7230 and Hypergraph community 114201 have a Jaccard similarity of 0.25.
# Common nodes: {1152681}
# Graph community 7233 and Hypergraph community 93639 have a Jaccard similarity of 0.25.
# Common nodes: {1107556}
# Graph community 7233 and Hypergraph community 105847 have a Jaccard similarity of 0.25.
# Common nodes: {1143774}
# Graph community 7236 and Hypergraph community 93512 have a Jaccard similarity of 0.33.
# Common nodes: {1044609}
# Graph community 7236 and Hypergraph community 93513 have a Jaccard similarity of 0.33.
# Common nodes: {1044611}
# Graph community 7237 and Hypergraph community 107599 have a Jaccard similarity of 0.33.
# Common nodes: {1116132}
# Graph community 7239 and Hypergraph community 114208 have a Jaccard similarity of 0.25.
# Common nodes: {1152736}
# Graph community 7240 and Hypergraph community 94745 have a Jaccard similarity of 0.25.
# Common nodes: {1055402}
# Graph community 7240 and Hypergraph community 95862 have a Jaccard similarity of 0.25.
# Common nodes: {1055422}
# Graph community 7243 and Hypergraph community 98360 have a Jaccard similarity of 0.25.
# Common nodes: {1067239}
# Graph community 7244 and Hypergraph community 101052 have a Jaccard similarity of 0.33.
# Common nodes: {1082150}
# Graph community 7247 and Hypergraph community 108382 have a Jaccard similarity of 0.33.
# Common nodes: {1119897}
# Graph community 7247 and Hypergraph community 108383 have a Jaccard similarity of 0.33.
# Common nodes: {1119898}
# Graph community 7248 and Hypergraph community 110287 have a Jaccard similarity of 0.33.
# Common nodes: {1129584}
# Graph community 7249 and Hypergraph community 114892 have a Jaccard similarity of 0.25.
# Common nodes: {1157020}
# Graph community 7249 and Hypergraph community 114894 have a Jaccard similarity of 0.25.
# Common nodes: {1157021}
# Graph community 7250 and Hypergraph community 97776 have a Jaccard similarity of 0.33.
# Common nodes: {1064451}
# Graph community 7251 and Hypergraph community 97778 have a Jaccard similarity of 0.33.
# Common nodes: {1064453}
# Graph community 7252 and Hypergraph community 98211 have a Jaccard similarity of 0.33.
# Common nodes: {1135145}
# Graph community 7252 and Hypergraph community 111330 have a Jaccard similarity of 0.33.
# Common nodes: {1135147}
# Graph community 7252 and Hypergraph community 111332 have a Jaccard similarity of 0.33.
# Common nodes: {1135149}
# Graph community 7256 and Hypergraph community 98581 have a Jaccard similarity of 0.33.
# Common nodes: {1147636}
# Graph community 7256 and Hypergraph community 113440 have a Jaccard similarity of 0.33.
# Common nodes: {1147638}
# Graph community 7257 and Hypergraph community 108395 have a Jaccard similarity of 0.33.
# Common nodes: {1119955}
# Graph community 7261 and Hypergraph community 103654 have a Jaccard similarity of 0.33.
# Common nodes: {1107884}
# Graph community 7262 and Hypergraph community 105081 have a Jaccard similarity of 0.25.
# Common nodes: {1103636}
# Graph community 7262 and Hypergraph community 105084 have a Jaccard similarity of 0.25.
# Common nodes: {1120252}
# Graph community 7264 and Hypergraph community 101719 have a Jaccard similarity of 0.33.
# Common nodes: {1116380}
# Graph community 7264 and Hypergraph community 107652 have a Jaccard similarity of 0.33.
# Common nodes: {1116382}
# Graph community 7267 and Hypergraph community 102649 have a Jaccard similarity of 0.33.
# Common nodes: {1096207}
# Graph community 7267 and Hypergraph community 103678 have a Jaccard similarity of 0.33.
# Common nodes: {1096208}
# Graph community 7267 and Hypergraph community 103680 have a Jaccard similarity of 0.33.
# Common nodes: {1096209}
# Graph community 7268 and Hypergraph community 104355 have a Jaccard similarity of 0.25.
# Common nodes: {1099697}
# Graph community 7268 and Hypergraph community 104357 have a Jaccard similarity of 0.25.
# Common nodes: {1116472}
# Graph community 7271 and Hypergraph community 103236 have a Jaccard similarity of 0.33.
# Common nodes: {1093680}
# Graph community 7271 and Hypergraph community 103237 have a Jaccard similarity of 0.33.
# Common nodes: {1141457}
# Graph community 7272 and Hypergraph community 106862 have a Jaccard similarity of 0.33.
# Common nodes: {1112343}
# Graph community 7272 and Hypergraph community 106864 have a Jaccard similarity of 0.33.
# Common nodes: {1112345}
# Graph community 7274 and Hypergraph community 104153 have a Jaccard similarity of 0.25.
# Common nodes: {1157222}
# Graph community 7274 and Hypergraph community 114912 have a Jaccard similarity of 0.25.
# Common nodes: {1157225}
# Graph community 7275 and Hypergraph community 104317 have a Jaccard similarity of 0.25.
# Common nodes: {1099487}
# Graph community 7275 and Hypergraph community 104320 have a Jaccard similarity of 0.25.
# Common nodes: {1099489}
# Graph community 7275 and Hypergraph community 104321 have a Jaccard similarity of 0.25.
# Common nodes: {1099490}
# Graph community 7277 and Hypergraph community 104673 have a Jaccard similarity of 0.25.
# Common nodes: {1116490}
# Graph community 7277 and Hypergraph community 107673 have a Jaccard similarity of 0.25.
# Common nodes: {1116492}
# Graph community 7277 and Hypergraph community 107676 have a Jaccard similarity of 0.25.
# Common nodes: {1116493}
# Graph community 7278 and Hypergraph community 113587 have a Jaccard similarity of 0.33.
# Common nodes: {1148601}
# Graph community 7278 and Hypergraph community 113589 have a Jaccard similarity of 0.33.
# Common nodes: {1148602}
# Graph community 7280 and Hypergraph community 104803 have a Jaccard similarity of 0.33.
# Common nodes: {1135489}
# Graph community 7280 and Hypergraph community 111385 have a Jaccard similarity of 0.33.
# Common nodes: {1135491}
# Graph community 7283 and Hypergraph community 107164 have a Jaccard similarity of 0.25.
# Common nodes: {1141568}
# Graph community 7283 and Hypergraph community 112438 have a Jaccard similarity of 0.25.
# Common nodes: {1141571}
# Graph community 7283 and Hypergraph community 112439 have a Jaccard similarity of 0.25.
# Common nodes: {1141572}
# Graph community 7288 and Hypergraph community 111424 have a Jaccard similarity of 0.25.
# Common nodes: {1135841}
# Graph community 7288 and Hypergraph community 111455 have a Jaccard similarity of 0.25.
# Common nodes: {1135856}
# Graph community 7289 and Hypergraph community 114246 have a Jaccard similarity of 0.25.
# Common nodes: {1153185}
# Graph community 7289 and Hypergraph community 114257 have a Jaccard similarity of 0.25.
# Common nodes: {1153189}
# Graph community 139 and Hypergraph community 111107 have a Jaccard similarity of 0.25.
# Common nodes: {1133889}
# Graph community 59 and Hypergraph community 111972 have a Jaccard similarity of 0.25.
# Common nodes: {1138855}
# Graph community 125 and Hypergraph community 114634 have a Jaccard similarity of 0.33.
# Common nodes: {1155495}
# Graph community 125 and Hypergraph community 114635 have a Jaccard similarity of 0.33.
# Common nodes: {1155497}
#
# Community pair with the maximum number of shared nodes:
# Graph community 45 and Hypergraph community 26336 share 1 nodes.
# Shared nodes: {228026}

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **based on neighborhood structure**

# %%
import networkx as nx
import hypernetx as hnx
import community as community_louvain  # For Louvain on graph
from collections import defaultdict

# %%
# Load YouTube network data as graph and hypergraph
def load_youtube_network_data(filename):
    G = nx.Graph()
    hyperedges = defaultdict(list)

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                nodes = list(map(int, line.strip().split()))
                u, v = nodes[0], nodes[1:]
                G.add_edges_from([(u, vi) for vi in v])
                hyperedges[u] = v

    H = hnx.Hypergraph(hyperedges)
    return G, H

# Convert hypergraph to bipartite graph manually
def convert_hypergraph_to_bipartite(H):
    """Convert hypergraph to a bipartite graph."""
    B = nx.Graph()
    for edge_id, nodes in H.incidence_dict.items():
        for node in nodes:
            B.add_edge(f"edge_{edge_id}", f"node_{node}")
    return B

# Apply Louvain on graph
def apply_louvain_on_graph(G):
    partition = community_louvain.best_partition(G)
    return partition

# Apply Louvain on hypergraph via bipartite graph conversion
def apply_louvain_on_hypergraph(H):
    bipartite_graph = convert_hypergraph_to_bipartite(H)
    partition = community_louvain.best_partition(bipartite_graph)
    return partition

# %%
# Group by neighborhood-based structure
def group_by_neighborhood(G, partition):
    community_groups = defaultdict(set)
    for node, community in partition.items():
        # Check if the node is a string prefixed with "node_"
        if isinstance(node, str) and node.startswith("node_"):
            actual_node = int(node.split('_')[1])  # Convert back to original node ID
        else:
            actual_node = node  # If integer, keep as-is

        # Get neighborhood and add to community groups
        neighborhood = set(G.neighbors(actual_node))
        neighborhood.add(actual_node)
        community_groups[community] |= neighborhood  # Union neighborhoods within a community

    return community_groups

# Calculate Jaccard similarity between two sets
def jaccard_similarity(set1, set2):
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union != 0 else 0

# %%
# Find similar communities based on neighborhood structure
def find_similar_communities(graph_communities, hypergraph_communities, threshold=0.2):
    similar_communities = []
    for g_comm, g_nodes in graph_communities.items():
        for h_comm, h_nodes in hypergraph_communities.items():
            similarity = jaccard_similarity(g_nodes, h_nodes)
            if similarity >= threshold:
                similar_communities.append((g_comm, h_comm, similarity, g_nodes & h_nodes))
    return similar_communities

# %%
# Main function
def main():
    filename = '/content/drive/My Drive/CSE551/Undirected_Youtube_network.txt'

    # Load network as graph and hypergraph
    G, H = load_youtube_network_data(filename)

    # Apply community detection
    graph_partition = apply_louvain_on_graph(G)
    hypergraph_partition = apply_louvain_on_hypergraph(H)

    # Group by neighborhood-based communities
    graph_communities = group_by_neighborhood(G, graph_partition)
    hypergraph_communities = group_by_neighborhood(G, hypergraph_partition)

    # Find and print similar communities
    similar_communities = find_similar_communities(graph_communities, hypergraph_communities, threshold=0.2)
    print(f"\nSimilar communities based on neighborhood structure with Jaccard similarity >= 0.2:")
    for g_comm, h_comm, similarity, common_nodes in similar_communities:
        print(f"Graph community {g_comm} and Hypergraph community {h_comm} have similarity {similarity:.2f}.")
        print(f"Common nodes: {common_nodes}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/networkx/classes/graph.py in neighbors(self, n)
#    1371         try:
# -> 1372             return iter(self._adj[n])
#    1373         except KeyError as err:
#
# KeyError: 'edge_1'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-8-e39513ef73fd> in <cell line: 97>()
#      96
#      97 if __name__ == "__main__":
# ---> 98     main()
#
# <ipython-input-8-e39513ef73fd> in main()
#      86     # Group by neighborhood-based communities
#      87     graph_communities = group_by_neighborhood(G, graph_partition)
# ---> 88     hypergraph_communities = group_by_neighborhood(G, hypergraph_partition)
#      89
#      90     # Find and print similar communities
#
# <ipython-input-8-e39513ef73fd> in group_by_neighborhood(G, partition)
#      51
#      52         # Get neighborhood and add to community groups
# ---> 53         neighborhood = set(G.neighbors(actual_node))
#      54         neighborhood.add(actual_node)
#      55         community_groups[community] |= neighborhood  # Union neighborhoods within a community
#
# /usr/local/lib/python3.10/dist-packages/networkx/classes/graph.py in neighbors(self, n)
#    1372             return iter(self._adj[n])
#    1373         except KeyError as err:
# -> 1374             raise NetworkXError(f"The node {n} is not in the graph.") from err
#    1375
#    1376     @cached_property
#
# NetworkXError: The node edge_1 is not in the graph.
