# %%
# !pip install hypernetx matplotlib scikit-learn
# Out:
# Requirement already satisfied: hypernetx in /usr/local/lib/python3.10/dist-packages (2.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: celluloid>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (0.2.0)
# Requirement already satisfied: decorator>=5.1.1 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (5.1.1)
# Requirement already satisfied: igraph>=0.11.4 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (0.11.6)
# Requirement already satisfied: networkx>=3.3 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (3.3)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from hypernetx) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph>=0.11.4->hypernetx) (1.7.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.2->hypernetx) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.2->hypernetx) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # **Unweighted Hypergraph Clustering on a Sample Dataset**

# %%
import hypernetx as hnx
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eig

# Sample dataset
edges = {
    0: [72, 165, 517],
    1: [875, 1024, 1742, 2059],
    2: [2252, 2429, 3622],
    3: [5036, 5080, 5088, 5703],
    4: [5873, 6723, 6752],
    5: [8459, 8752, 8885, 9553],
}

# Create a hypergraph from the dataset
H = hnx.Hypergraph(edges)

# Convert hypergraph to a bipartite graph
bipartite_graph = H.bipartite()

# Find connected components in the bipartite graph
components = list(nx.connected_components(bipartite_graph))

print(f"There are {len(components)} connected components.")

# Filter only node components (not edge components)
node_components = [comp for comp in components if any(node in H.nodes for node in comp)]

# Helper function to compute the Laplacian from the incidence matrix
def compute_laplacian(H):
    incidence_matrix = H.incidence_matrix().toarray()
    D_v = np.diag(np.sum(incidence_matrix, axis=1))  # Degree matrix for vertices
    D_e = np.diag(np.sum(incidence_matrix, axis=0))  # Degree matrix for edges
    L = D_v - np.dot(incidence_matrix, np.linalg.inv(D_e).dot(incidence_matrix.T))
    return L

# Perform clustering on each connected component
for i, component in enumerate(node_components):
    print(f"\nProcessing component {i + 1} with {len(component)} nodes.")
    sub_hypergraph = H.restrict_to_nodes(component)  # Restrict to the connected component

    # Adjust k to be less than the number of nodes in the component
    num_clusters = min(2, len(component) - 1)  # Set k appropriately

    if num_clusters > 1:
        # Compute Laplacian
        L = compute_laplacian(sub_hypergraph)  # Get the Laplacian matrix
        e, v = eig(L)  # Use dense eig for small graphs

        # Sort eigenvalues and corresponding eigenvectors
        sorted_indices = np.argsort(e)
        sorted_eigenvectors = v[:, sorted_indices]

        # Perform clustering based on eigenvectors
        clusters = {}
        for idx, node in enumerate(sub_hypergraph.nodes):
            cluster_id = np.argmax(sorted_eigenvectors[idx, :num_clusters])
            if cluster_id not in clusters:
                clusters[cluster_id] = []
            clusters[cluster_id].append(node)

        print(f"Clustering result for component {i + 1}:")
        print(clusters)

        # Visualize the clusters
        colors = ['r', 'g', 'b']
        node_colors = dict()
        for k, v in clusters.items():
            node_colors.update({vv: colors[k % len(colors)] for vv in v})

        hnx.draw(sub_hypergraph, nodes_kwargs={'color': node_colors})
        plt.show()
    else:
        print(f"Component {i + 1} is too small for clustering.")
# Out:
# There are 6 connected components.
#
# Processing component 1 with 4 nodes.
# Clustering result for component 1:
# {1: [72, 165, 517]}
# Processing component 2 with 5 nodes.
# Clustering result for component 2:
# {1: [875, 1024, 1742, 2059]}
# Processing component 3 with 4 nodes.
# Clustering result for component 3:
# {1: [2252, 2429, 3622]}
# Processing component 4 with 5 nodes.
# Clustering result for component 4:
# {1: [5036, 5080, 5088, 5703]}
# Processing component 5 with 4 nodes.
# Clustering result for component 5:
# {1: [5873, 6723, 6752]}
# Processing component 6 with 5 nodes.
# Clustering result for component 6:
# {1: [8459, 8752, 8885, 9553]}

# %% [markdown]
# # **Weighted Hypergraph Clustering Using TF-IDF Weights**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import coo_matrix
import numpy as np
import hypernetx as hnx

# Sample dataset with vertex-hyperedge incidence relationships
documents = [
    "data analysis machine learning",
    "deep learning machine learning",
    "data science machine learning",
    "artificial intelligence deep learning",
]

# Convert documents to a TF-IDF matrix (this is just an example)
tfidf_vect = TfidfVectorizer()
X_tfidf = tfidf_vect.fit_transform(documents)

# Convert TF-IDF matrix to an incidence matrix
mat = coo_matrix(X_tfidf)

# Create a hypergraph from the incidence matrix
H_weighted = hnx.Hypergraph.from_incidence_matrix(mat)

# Perform weighted spectral clustering with 2 clusters
clusters_weighted = hnx.spec_clus(H_weighted, 2, weights=True)

# Display the resulting clusters
print("Weighted Hypergraph Clustering Result:")
print(clusters_weighted)

# Visualize clusters
colors = ['r', 'g']
node_colors = dict()
for k, v in clusters_weighted.items():
    node_colors.update({vv: colors[k] for vv in v})

hnx.draw(H_weighted, nodes_kwargs={'color': node_colors})
plt.show()
# Out:
# Weighted Hypergraph Clustering Result:
# {0: [0, 2], 1: [1, 3]}

# %% [markdown]
# ## **playing with youtube_top5000.txt dataset **

# %%
import pandas as pd
import hypernetx as hnx

# Step 1: Read the file without specifying a delimiter
with open('youtube_top5000.txt', 'r') as file:
    data = file.readlines()

# Print the first few lines to inspect the structure
print("First 10 lines of the dataset:")
for line in data[:10]:  # Display the first 10 lines
    print(line.strip())

# Step 2: Process the data to create a list of edges
edges = []
for line in data:
    edges.append(line.strip().split())  # Adjust split method based on your inspection

# Step 3: Convert the list of edges to a DataFrame for hypernetx
# Here we assume each line represents a hyperedge
df = pd.DataFrame(edges)

# Step 4: Convert the DataFrame to a dictionary format suitable for hypernetx
hypergraph_edges = {i: df.iloc[i].dropna().tolist() for i in range(df.shape[0])}

# Create hypergraph
H = hnx.Hypergraph(hypergraph_edges)
# Out:
# First 10 lines of the dataset:
# 72	165	517	875	1024	1742	2059	2252	2429	3622	5036	5080	5088	5703	5873	6723	6752	8459	8752	8885	9553	10243	10763	13040	13841	15059	15231	15310	16100	19170	19573	20572	26797	27414	28080	28084	28755	40404	43824	48404	48423	48431	61005	83295	103527	108236	139888	156355	156534	175210	180201	181647	181664	181665	183004	203349	224411	279007	282577	287218	319813	458127	526519	645203
# 1	3	5	539	551	554	571	626	642	673	678	684	698	700	9314	24047	33897	36675	521325
# 519665	608725
# 157240	459129
# 590	29649
# 84114	382726
# 2	2014	3438	95969	132967	132972	132973	132978	132981	132982	132987	443577
# 1024	1291	1825	1864	1886	1970	1999	2287	2529	6444	6656	9532	11414	11897	16009	16010	18690	19989	20221	20328	20395	20426	20444	20509	20599	20796	20842	20889	21018	21021	21049	23130	24804	25746	28594	29293	30077	30191	36467	45639	49498	57083	63140	63616	64005	64042	65390	66862	72470	72550	73918	73921	78452	86337	87033	90490	91005	91307	91331	91778	91922	92031	92302	92719	93053	93149	93150	93167	93627	93849	94042	95497	95741	96057	96277	96984	97158	105021	105767	117172	117236	125448	129584	130073	132238	132499	145200	165476	167993	174805	180244	181462	181469	182271	182276	190636	191350	196365	212060	214933	216834	225151	228896	230927	234120	235623	240877	241326	242761	243726	246413	248768	249664	250023	252038	256836	257303	262718	262741	262769	262810	268038	353177	354876	360361	374132	374142	374216	374226	374250	374304	374336	394361	409115	517233	519228
# 273419	530605
# 5	580	636	642

# %%
import pandas as pd
import hypernetx as hnx
import numpy as np
from scipy.sparse.csgraph import connected_components  # Import the connected_components function
from scipy.sparse import csr_matrix  # Import for sparse matrix handling

# Step 1: Read the file without specifying a delimiter
with open('youtube_top5000.txt', 'r') as file:
    data = file.readlines()

# Step 2: Process the data to create a list of edges
edges = []
for line in data:
    # Assuming space or comma as delimiter; adjust according to the actual file format
    edges.append(line.strip().split())  # Split each line into a list of vertices

# Step 3: Convert the list of edges to a DataFrame for hypernetx
# Here we assume each line represents a hyperedge
df = pd.DataFrame(edges)

# Step 4: Convert the DataFrame to a dictionary format suitable for hypernetx
hypergraph_edges = {i: df.iloc[i].dropna().tolist() for i in range(df.shape[0])}

# Create hypergraph
H = hnx.Hypergraph(hypergraph_edges)

# %%
# Step 5: Check if the hypergraph is connected
if H.is_connected():
    print("The hypergraph is connected. Performing spectral clustering...")
    num_clusters = 3  # Define the number of clusters
    clusters = hnx.spec_clus(H, num_clusters)
    print("Clustering result:")
    print(clusters)
else:
    print("The hypergraph is not connected. Analyzing connected components...")

    # Convert the incidence matrix to a bipartite adjacency matrix
    incidence_matrix = H.incidence_matrix()
    adjacency_matrix = incidence_matrix @ incidence_matrix.T  # Get the adjacency matrix

    # Find connected components
    num_components, labels = connected_components(adjacency_matrix.toarray(), directed=False)

    print(f"There are {num_components} connected components.")

    # Process each component separately
    for i in range(num_components):
        # Extract nodes corresponding to this component
        component_nodes = np.where(labels == i)[0]
        component = [H.nodes[j] for j in component_nodes]  # Get the original node labels

        print(f"\nProcessing component {i + 1} with {len(component)} nodes.")
        sub_hypergraph = H.restrict_to_nodes(component)  # Restrict to the connected component

        # Perform spectral clustering on the sub-hypergraph
        if len(component) > 1:  # Only perform clustering if there are at least 2 nodes
            try:
                clusters = hnx.spec_clus(sub_hypergraph, 3)  # Number of clusters can be adjusted
                print(f"Clustering result for component {i + 1}:")
                print(clusters)
            except Exception as e:
                print(f"Error during clustering for component {i + 1}: {e}")
        else:
            print("Not enough nodes to perform clustering.")
# Out:
# The hypergraph is not connected. Analyzing connected components...

# %%
# Step 5: Check if the hypergraph is connected
if H.is_connected():
    print("The hypergraph is connected. Performing spectral clustering...")
    num_clusters = 3  # Define the number of clusters
    clusters = hnx.spec_clus(H, num_clusters)
    print("Clustering result:")
    print(clusters)
else:
    print("The hypergraph is not connected. Analyzing connected components...")

    # Convert the incidence matrix to a bipartite adjacency matrix
    incidence_matrix = H.incidence_matrix()
    adjacency_matrix = incidence_matrix @ incidence_matrix.T  # Get the adjacency matrix

    # Find connected components
    num_components, labels = connected_components(adjacency_matrix.toarray(), directed=False)

    print(f"There are {num_components} connected components.")

    # Process each component separately
    for i in range(num_components):
        # Extract nodes corresponding to this component
        component_nodes = np.where(labels == i)[0]
        component = [H.nodes[j] for j in component_nodes]  # Get the original node labels

        print(f"\nProcessing component {i + 1} with {len(component)} nodes.")
        sub_hypergraph = H.restrict_to_nodes(component)  # Restrict to the connected component

        # Perform spectral clustering on the sub-hypergraph
        if len(component) > 1:  # Only perform clustering if there are at least 2 nodes
            try:
                clusters = hnx.spec_clus(sub_hypergraph, 3)  # Number of clusters can be adjusted
                print(f"Clustering result for component {i + 1}:")
                print(clusters)
            except Exception as e:
                print(f"Error during clustering for component {i + 1}: {e}")
        else:
            print("Not enough nodes to perform clustering.")
# Out:
# Not enough nodes to perform clustering.

# %% [markdown]
# # **using first 100 data**

# %%
import pandas as pd
import hypernetx as hnx
import numpy as np
from scipy.sparse.csgraph import connected_components  # Import the connected_components function
from scipy.sparse import csr_matrix  # Import for sparse matrix handling

# Step 1: Read the first hundred lines from the file
with open('youtube_top5000.txt', 'r') as file:
    data = [file.readline().strip() for _ in range(100)]  # Read first 100 lines

# Step 2: Process the data to create a list of edges
edges = []
for line in data:
    edges.append(line.split())  # Split each line into a list of vertices

# Step 3: Convert the list of edges to a DataFrame for hypernetx
df = pd.DataFrame(edges)

# Step 4: Convert the DataFrame to a dictionary format suitable for hypernetx
hypergraph_edges = {i: df.iloc[i].dropna().tolist() for i in range(df.shape[0])}

# Create hypergraph
H = hnx.Hypergraph(hypergraph_edges)

# Step 5: Check if the hypergraph is connected
if H.is_connected():
    print("The hypergraph is connected. Performing spectral clustering...")
    num_clusters = 3  # Define the number of clusters
    clusters = hnx.spec_clus(H, num_clusters)
    print("Clustering result:")
    print(clusters)
else:
    print("The hypergraph is not connected. Analyzing connected components...")

    # Convert the incidence matrix to a bipartite adjacency matrix
    incidence_matrix = H.incidence_matrix()
    adjacency_matrix = incidence_matrix @ incidence_matrix.T  # Get the adjacency matrix

    # Find connected components
    num_components, labels = connected_components(adjacency_matrix.toarray(), directed=False)

    print(f"There are {num_components} connected components.")

    # Process each component separately
    for i in range(num_components):
        # Extract nodes corresponding to this component
        component_nodes = np.where(labels == i)[0]
        component = [H.nodes[j] for j in component_nodes]  # Get the original node labels

        print(f"\nProcessing component {i + 1} with {len(component)} nodes.")
        sub_hypergraph = H.restrict_to_nodes(component)  # Restrict to the connected component

        # Perform spectral clustering on the sub-hypergraph
        if len(component) > 1:  # Only perform clustering if there are at least 2 nodes
            try:
                clusters = hnx.spec_clus(sub_hypergraph, 3)  # Number of clusters can be adjusted
                print(f"Clustering result for component {i + 1}:")
                print(clusters)
            except Exception as e:
                print(f"Error during clustering for component {i + 1}: {e}")
        else:
            print("Not enough nodes to perform clustering.")
# Out:
# The hypergraph is not connected. Analyzing connected components...
# There are 67 connected components.
#
# Processing component 1 with 70 nodes.
# Error during clustering for component 1: cannot infer dimensions from zero sized index arrays
#
# Processing component 2 with 4656 nodes.
# Error during clustering for component 2: cannot infer dimensions from zero sized index arrays
#
# Processing component 3 with 2 nodes.
# Error during clustering for component 3: cannot infer dimensions from zero sized index arrays
#
# Processing component 4 with 2 nodes.
# Error during clustering for component 4: cannot infer dimensions from zero sized index arrays
#
# Processing component 5 with 2 nodes.
# Error during clustering for component 5: cannot infer dimensions from zero sized index arrays
#
# Processing component 6 with 2 nodes.
# Error during clustering for component 6: cannot infer dimensions from zero sized index arrays
#
# Processing component 7 with 2 nodes.
# Error during clustering for component 7: cannot infer dimensions from zero sized index arrays
#
# Processing component 8 with 4 nodes.
# Error during clustering for component 8: cannot infer dimensions from zero sized index arrays
#
# Processing component 9 with 2 nodes.
# Error during clustering for component 9: cannot infer dimensions from zero sized index arrays
#
# Processing component 10 with 2 nodes.
# Error during clustering for component 10: cannot infer dimensions from zero sized index arrays
#
# Processing component 11 with 12 nodes.
# Error during clustering for component 11: cannot infer dimensions from zero sized index arrays
#
# Processing component 12 with 2 nodes.
# Error during clustering for component 12: cannot infer dimensions from zero sized index arrays
#
# Processing component 13 with 3 nodes.
# Error during clustering for component 13: cannot infer dimensions from zero sized index arrays
#
# Processing component 14 with 2 nodes.
# Error during clustering for component 14: cannot infer dimensions from zero sized index arrays
#
# Processing component 15 with 2 nodes.
# Error during clustering for component 15: cannot infer dimensions from zero sized index arrays
#
# Processing component 16 with 2 nodes.
# Error during clustering for component 16: cannot infer dimensions from zero sized index arrays
#
# Processing component 17 with 2 nodes.
# Error during clustering for component 17: cannot infer dimensions from zero sized index arrays
#
# Processing component 18 with 2 nodes.
# Error during clustering for component 18: cannot infer dimensions from zero sized index arrays
#
# Processing component 19 with 2 nodes.
# Error during clustering for component 19: cannot infer dimensions from zero sized index arrays
#
# Processing component 20 with 8 nodes.
# Error during clustering for component 20: cannot infer dimensions from zero sized index arrays
#
# Processing component 21 with 2 nodes.
# Error during clustering for component 21: cannot infer dimensions from zero sized index arrays
#
# Processing component 22 with 7 nodes.
# Error during clustering for component 22: cannot infer dimensions from zero sized index arrays
#
# Processing component 23 with 2 nodes.
# Error during clustering for component 23: cannot infer dimensions from zero sized index arrays
#
# Processing component 24 with 4 nodes.
# Error during clustering for component 24: cannot infer dimensions from zero sized index arrays
#
# Processing component 25 with 2 nodes.
# Error during clustering for component 25: cannot infer dimensions from zero sized index arrays
#
# Processing component 26 with 2 nodes.
# Error during clustering for component 26: cannot infer dimensions from zero sized index arrays
#
# Processing component 27 with 2 nodes.
# Error during clustering for component 27: cannot infer dimensions from zero sized index arrays
#
# Processing component 28 with 2 nodes.
# Error during clustering for component 28: cannot infer dimensions from zero sized index arrays
#
# Processing component 29 with 3 nodes.
# Error during clustering for component 29: cannot infer dimensions from zero sized index arrays
#
# Processing component 30 with 2 nodes.
# Error during clustering for component 30: cannot infer dimensions from zero sized index arrays
#
# Processing component 31 with 2 nodes.
# Error during clustering for component 31: cannot infer dimensions from zero sized index arrays
#
# Processing component 32 with 2 nodes.
# Error during clustering for component 32: cannot infer dimensions from zero sized index arrays
#
# Processing component 33 with 4 nodes.
# Error during clustering for component 33: cannot infer dimensions from zero sized index arrays
#
# Processing component 34 with 2 nodes.
# Error during clustering for component 34: cannot infer dimensions from zero sized index arrays
#
# Processing component 35 with 2 nodes.
# Error during clustering for component 35: cannot infer dimensions from zero sized index arrays
#
# Processing component 36 with 2 nodes.
# Error during clustering for component 36: cannot infer dimensions from zero sized index arrays
#
# Processing component 37 with 2 nodes.
# Error during clustering for component 37: cannot infer dimensions from zero sized index arrays
#
# Processing component 38 with 2 nodes.
# Error during clustering for component 38: cannot infer dimensions from zero sized index arrays
#
# Processing component 39 with 2 nodes.
# Error during clustering for component 39: cannot infer dimensions from zero sized index arrays
#
# Processing component 40 with 3 nodes.
# Error during clustering for component 40: cannot infer dimensions from zero sized index arrays
#
# Processing component 41 with 3 nodes.
# Error during clustering for component 41: cannot infer dimensions from zero sized index arrays
#
# Processing component 42 with 2 nodes.
# Error during clustering for component 42: cannot infer dimensions from zero sized index arrays
#
# Processing component 43 with 2 nodes.
# Error during clustering for component 43: cannot infer dimensions from zero sized index arrays
#
# Processing component 44 with 2 nodes.
# Error during clustering for component 44: cannot infer dimensions from zero sized index arrays
#
# Processing component 45 with 2 nodes.
# Error during clustering for component 45: cannot infer dimensions from zero sized index arrays
#
# Processing component 46 with 4 nodes.
# Error during clustering for component 46: cannot infer dimensions from zero sized index arrays
#
# Processing component 47 with 2 nodes.
# Error during clustering for component 47: cannot infer dimensions from zero sized index arrays
#
# Processing component 48 with 2 nodes.
# Error during clustering for component 48: cannot infer dimensions from zero sized index arrays
#
# Processing component 49 with 2 nodes.
# Error during clustering for component 49: cannot infer dimensions from zero sized index arrays
#
# Processing component 50 with 2 nodes.
# Error during clustering for component 50: cannot infer dimensions from zero sized index arrays
#
# Processing component 51 with 2 nodes.
# Error during clustering for component 51: cannot infer dimensions from zero sized index arrays
#
# Processing component 52 with 2 nodes.
# Error during clustering for component 52: cannot infer dimensions from zero sized index arrays
#
# Processing component 53 with 2 nodes.
# Error during clustering for component 53: cannot infer dimensions from zero sized index arrays
#
# Processing component 54 with 2 nodes.
# Error during clustering for component 54: cannot infer dimensions from zero sized index arrays
#
# Processing component 55 with 2 nodes.
# Error during clustering for component 55: cannot infer dimensions from zero sized index arrays
#
# Processing component 56 with 2 nodes.
# Error during clustering for component 56: cannot infer dimensions from zero sized index arrays
#
# Processing component 57 with 2 nodes.
# Error during clustering for component 57: cannot infer dimensions from zero sized index arrays
#
# Processing component 58 with 2 nodes.
# Error during clustering for component 58: cannot infer dimensions from zero sized index arrays
#
# Processing component 59 with 2 nodes.
# Error during clustering for component 59: cannot infer dimensions from zero sized index arrays
#
# Processing component 60 with 2 nodes.
# Error during clustering for component 60: cannot infer dimensions from zero sized index arrays
#
# Processing component 61 with 2 nodes.
# Error during clustering for component 61: cannot infer dimensions from zero sized index arrays
#
# Processing component 62 with 2 nodes.
# Error during clustering for component 62: cannot infer dimensions from zero sized index arrays
#
# Processing component 63 with 2 nodes.
# Error during clustering for component 63: cannot infer dimensions from zero sized index arrays
#
# Processing component 64 with 3 nodes.
# Error during clustering for component 64: cannot infer dimensions from zero sized index arrays
#
# Processing component 65 with 2 nodes.
# Error during clustering for component 65: cannot infer dimensions from zero sized index arrays
#
# Processing component 66 with 2 nodes.
# Error during clustering for component 66: cannot infer dimensions from zero sized index arrays
#
# Processing component 67 with 2 nodes.
# Error during clustering for component 67: cannot infer dimensions from zero sized index arrays
