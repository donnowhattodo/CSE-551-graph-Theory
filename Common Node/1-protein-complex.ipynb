# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cse551/Youtube_communities.txt
# /kaggle/input/cse551/Collin_CYC_Graph.txt
# /kaggle/input/cse551/CYC2008_complexes.txt
# /kaggle/input/cse551/roadNet_Texas.txt
# /kaggle/input/cse551/Undirected_Youtube_network.txt
# /kaggle/input/cse551/Email-Enron.txt

# %%
# !pip install hypernetx matplotlib scikit-learn
# !pip install networkx numpy scikit-learn matplotlib
# !pip install python-louvain
# Out:
# Collecting hypernetx
#   Downloading hypernetx-2.3.8-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Collecting celluloid>=0.2.0 (from hypernetx)
#   Downloading celluloid-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: decorator>=5.1.1 in /opt/conda/lib/python3.10/site-packages (from hypernetx) (5.1.1)
# Requirement already satisfied: igraph>=0.11.4 in /opt/conda/lib/python3.10/site-packages (from hypernetx) (0.11.6)
# Requirement already satisfied: networkx>=3.3 in /opt/conda/lib/python3.10/site-packages (from hypernetx) (3.3)
# Requirement already satisfied: pandas>=2.2.2 in /opt/conda/lib/python3.10/site-packages (from hypernetx) (2.2.3)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy>=1.13 in /opt/conda/lib/python3.10/site-packages (from hypernetx) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: texttable>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from igraph>=0.11.4->hypernetx) (1.7.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.2.2->hypernetx) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.2.2->hypernetx) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading hypernetx-2.3.8-py3-none-any.whl (583 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.8/583.8 kB 9.0 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 76.6 MB/s eta 0:00:00:00:010:01
# Downloading celluloid-0.2.0-py3-none-any.whl (5.4 kB)
# Installing collected packages: scikit-learn, celluloid, hypernetx
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.3 which is incompatible.
# cesium 0.12.3 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# Successfully installed celluloid-0.2.0 hypernetx-2.3.8 scikit-learn-1.5.2
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (3.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: python-louvain in /opt/conda/lib/python3.10/site-packages (0.16)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from python-louvain) (3.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from python-louvain) (1.26.4)

# %%
import networkx as nx
import hypernetx as hnx
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.metrics import (
    normalized_mutual_info_score,
    adjusted_rand_score,
    jaccard_score,
    f1_score,
    precision_score,
    recall_score,
    homogeneity_score,
    completeness_score,
    v_measure_score,
)
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.metrics.cluster import contingency_matrix
from collections import defaultdict
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import community as community_louvain


# Step 1: Load Network Data
def load_collin_cyc_data(filename):
    G = nx.Graph()

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                node1, node2 = line.strip().split()
                G.add_edge(node1, node2)

    # Convert graph to hypergraph representation
    hyperedges = defaultdict(set)
    for node in G.nodes:
        neighbors = set(G.neighbors(node))
        hyperedges[node] = neighbors

    H = hnx.Hypergraph(hyperedges)
    return G, H


# Step 2: Graph Community Detection (Louvain)
def graph_community_detection(G):
    return community_louvain.best_partition(G)


# Step 3: Hypergraph Community Detection (Spectral Clustering)
def build_incidence_matrix(H):
    nodes = list(H.nodes)
    edges = list(H.edges)
    node_index = {node: i for i, node in enumerate(nodes)}
    edge_index = {edge: i for i, edge in enumerate(edges)}

    incidence_data = []
    row_indices = []
    col_indices = []

    for edge_id, nodes in H.incidence_dict.items():
        for node in nodes:
            if node in node_index:
                row_indices.append(node_index[node])
                col_indices.append(edge_index[edge_id])
                incidence_data.append(1)

    incidence_matrix = csr_matrix((incidence_data, (row_indices, col_indices)), shape=(len(H.nodes), len(H.edges)))
    return incidence_matrix


def hypergraph_community_detection(H, num_clusters=5):
    nodes = list(H.nodes)
    incidence_matrix = build_incidence_matrix(H)
    adjacency = incidence_matrix @ incidence_matrix.T
    clustering = SpectralClustering(n_clusters=num_clusters, affinity="precomputed", random_state=42)
    labels = clustering.fit_predict(adjacency.toarray())
    return {node: labels[i] for i, node in enumerate(nodes)}


# Step 4: Extract Communities
def extract_communities(partition):
    communities = defaultdict(set)
    for node, community in partition.items():
        communities[community].add(node)
    return communities


# Step 5: Find Common Nodes
def find_common_nodes(graph_partition, hypergraph_partition):
    common_nodes = {}
    for node, graph_comm in graph_partition.items():
        if node in hypergraph_partition:
            common_nodes[node] = (graph_comm, hypergraph_partition[node])
    return common_nodes


# Step 6: Cluster Common Nodes
def cluster_common_nodes(common_nodes, num_clusters=3):
    if len(common_nodes) < num_clusters:
        print(f"Not enough nodes to form {num_clusters} clusters. Using {len(common_nodes)} clusters instead.")
        num_clusters = len(common_nodes)

    common_node_ids = list(common_nodes.keys())
    common_labels = np.array([val[0] for val in common_nodes.values()]).reshape(-1, 1)
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    clustered_labels = kmeans.fit_predict(common_labels)
    return common_node_ids, clustered_labels


# Step 7: Evaluate Clustering Metrics
def evaluate_clustering_metrics(true_labels, pred_labels):
    nmi = normalized_mutual_info_score(true_labels, pred_labels)
    ari = adjusted_rand_score(true_labels, pred_labels)
    jaccard = jaccard_score(true_labels, pred_labels, average='macro', zero_division=0)
    f1 = f1_score(true_labels, pred_labels, average='macro', zero_division=0)
    precision = precision_score(true_labels, pred_labels, average='macro', zero_division=0)
    recall = recall_score(true_labels, pred_labels, average='macro', zero_division=0)
    homogeneity = homogeneity_score(true_labels, pred_labels)
    completeness = completeness_score(true_labels, pred_labels)
    v_measure = v_measure_score(true_labels, pred_labels)

    # Calculate Purity
    contingency = contingency_matrix(true_labels, pred_labels)
    purity = np.sum(np.amax(contingency, axis=0)) / np.sum(contingency)

    print(f"NMI: {nmi:.4f}")
    print(f"ARI: {ari:.4f}")
    print(f"Jaccard Similarity Index: {jaccard:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    #print(f"Purity: {purity:.4f}")
    print(f"Homogeneity: {homogeneity:.4f}")
    print(f"Completeness: {completeness:.4f}")
    print(f"V-measure: {v_measure:.4f}")


# Step 8: Visualize Clusters
def visualize_clusters(node_ids, labels):
    labels = np.array(labels)
    plt.figure(figsize=(10, 7))
    scatter = plt.scatter(range(len(labels)), labels, c=labels, cmap='viridis', alpha=0.8)
    plt.title("Visualization of Clusters for Common Nodes")
    plt.xlabel("Node Index")
    plt.ylabel("Cluster Label")
    plt.colorbar(scatter, label="Cluster Label")
    plt.grid(True)
    plt.show()


# Main Function
def main():
    filename = '/kaggle/input/cse551/Collin_CYC_Graph.txt'

    # Step 1: Load Network Data
    G, H = load_collin_cyc_data(filename)
    print(f"Graph loaded with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Hypergraph loaded with {len(H.edges)} hyperedges.")

    # Step 2: Graph Community Detection
    graph_partition = graph_community_detection(G)
    graph_comm = extract_communities(graph_partition)

    # Step 3: Hypergraph Community Detection
    hypergraph_partition = hypergraph_community_detection(H, num_clusters=5)
    hypergraph_comm = extract_communities(hypergraph_partition)

    # Step 4: Find Common Nodes
    common_nodes = find_common_nodes(graph_partition, hypergraph_partition)
    print(f"Number of common nodes: {len(common_nodes)}")

    # Step 5: Cluster Common Nodes
    if len(common_nodes) > 0:
        common_node_ids, cluster_labels = cluster_common_nodes(common_nodes, num_clusters=3)

        # Step 6: Evaluate Clustering
        true_labels = [val[1] for val in common_nodes.values()]
        evaluate_clustering_metrics(true_labels, cluster_labels)

        # Step 7: Visualize Clusters
        visualize_clusters(common_node_ids, cluster_labels)
    else:
        print("No common nodes to cluster and visualize.")


if __name__ == "__main__":
    main()
# Out:
# Graph loaded with 1097 nodes and 6392 edges.
# Hypergraph loaded with 1097 hyperedges.
# /opt/conda/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Number of common nodes: 1097
# NMI: 0.0571
# ARI: 0.0454
# Jaccard Similarity Index: 0.0883
# F1 Score: 0.1400
# Precision: 0.2116
# Recall: 0.2248
# Purity: 0.9316
# Homogeneity: 0.1176
# Completeness: 0.0377
# V-measure: 0.0571

# %%
import networkx as nx
import hypernetx as hnx
import numpy as np
from collections import defaultdict
import community as community_louvain
from sklearn.metrics import (
    normalized_mutual_info_score,
    adjusted_rand_score,
    homogeneity_score,
    completeness_score,
    v_measure_score,
    precision_score,
    recall_score,
    f1_score,
)


# Step 1: Load Graph and Hypergraph
def load_collin_cyc_data(filename):
    G = nx.Graph()
    hyperedges = defaultdict(set)

    with open(filename, 'r') as file:
        for line in file:
            if not line.startswith('#'):
                node1, node2 = line.strip().split()
                G.add_edge(node1, node2)
                hyperedges[node1].add(node2)
                hyperedges[node2].add(node1)

    # Convert to hypergraph
    H = hnx.Hypergraph(hyperedges)
    return G, H


# Step 2: Convert Hypergraph to Weighted Graph
def hypergraph_to_weighted_graph(H):
    G_weighted = nx.Graph()
    for edge, nodes in H.incidence_dict.items():
        nodes = list(nodes)
        for i, u in enumerate(nodes):
            for v in nodes[i + 1:]:
                if G_weighted.has_edge(u, v):
                    G_weighted[u][v]['weight'] += 1
                else:
                    G_weighted.add_edge(u, v, weight=1)
    return G_weighted


# Step 3: Graph Community Detection
def graph_community_detection(G):
    return community_louvain.best_partition(G)


# Step 4: Hypergraph Community Detection (Louvain)
def hypergraph_community_detection(H):
    G_weighted = hypergraph_to_weighted_graph(H)
    if G_weighted.number_of_edges() == 0:
        print("No edges in the weighted graph derived from hypergraph. Cannot detect communities.")
        return {}

    partition = community_louvain.best_partition(G_weighted, weight='weight')
    return partition


# Step 5: Extract Communities
def extract_communities(partition):
    communities = defaultdict(set)
    for node, community in partition.items():
        communities[community].add(node)
    return communities


# Step 6: Find Common Nodes
def find_common_nodes(graph_partition, hypergraph_partition):
    return {node for node in graph_partition if node in hypergraph_partition}


# Step 7: Compute Clustering Metrics
def evaluate_clustering_metrics(graph_partition, hypergraph_partition):
    common_nodes = find_common_nodes(graph_partition, hypergraph_partition)
    if not common_nodes:
        print("No common nodes between graph and hypergraph.")
        return

    true_labels = [graph_partition[node] for node in common_nodes]
    pred_labels = [hypergraph_partition[node] for node in common_nodes]

    nmi = normalized_mutual_info_score(true_labels, pred_labels)
    ari = adjusted_rand_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted', zero_division=0)
    recall = recall_score(true_labels, pred_labels, average='weighted', zero_division=0)
    f1 = f1_score(true_labels, pred_labels, average='weighted', zero_division=0)
    homogeneity = homogeneity_score(true_labels, pred_labels)
    completeness = completeness_score(true_labels, pred_labels)
    v_measure = v_measure_score(true_labels, pred_labels)

    print("\nEvaluation Metrics:")
    print(f"NMI: {nmi:.4f}")
    print(f"ARI: {ari:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Homogeneity: {homogeneity:.4f}")
    print(f"Completeness: {completeness:.4f}")
    print(f"V-measure: {v_measure:.4f}")


# Step 8: Print Communities
def print_communities(communities, label="Community"):
    print(f"\n{label}s:")
    for community_id, nodes in communities.items():
        print(f"{label} {community_id}: size: {len(nodes)}")


# Main Function
def main():
    filename = '/kaggle/input/cse551/Collin_CYC_Graph.txt'

    # Step 1: Load Network Data
    G, H = load_collin_cyc_data(filename)
    print(f"Graph loaded with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print(f"Hypergraph loaded with {len(H.edges)} hyperedges.")

    # Step 2: Graph Community Detection
    graph_partition = graph_community_detection(G)
    graph_comm = extract_communities(graph_partition)
    print(f"\nTotal Graph Communities: {len(graph_comm)}")
    print_communities(graph_comm, label="Graph Community")

    # Step 3: Hypergraph Community Detection
    hypergraph_partition = hypergraph_community_detection(H)
    if not hypergraph_partition:
        print("No hypergraph communities detected.")
        return

    hypergraph_comm = extract_communities(hypergraph_partition)
    print(f"\nTotal Hypergraph Communities: {len(hypergraph_comm)}")
    print_communities(hypergraph_comm, label="Hypergraph Community")

    # Step 4: Compare Communities
    print("\nComparing Graph and Hypergraph Communities:")
    for graph_id, graph_nodes in graph_comm.items():
        for hyper_id, hyper_nodes in hypergraph_comm.items():
            overlap = len(graph_nodes & hyper_nodes)
            if overlap > 0:
                print(f"Graph Community {graph_id} overlaps with Hypergraph Community {hyper_id}: {overlap} shared nodes")

    # Step 5: Evaluate Clustering Metrics
    evaluate_clustering_metrics(graph_partition, hypergraph_partition)


if __name__ == "__main__":
    main()
# Out:
# Graph loaded with 1097 nodes and 6392 edges.
# Hypergraph loaded with 1097 hyperedges.
#
# Total Graph Communities: 153
#
# Graph Communitys:
# Graph Community 0: size: 6
# Graph Community 1: size: 7
# Graph Community 3: size: 22
# Graph Community 4: size: 4
# Graph Community 16: size: 51
# Graph Community 6: size: 48
# Graph Community 7: size: 43
# Graph Community 8: size: 25
# Graph Community 54: size: 27
# Graph Community 10: size: 33
# Graph Community 11: size: 4
# Graph Community 12: size: 5
# Graph Community 13: size: 3
# Graph Community 15: size: 2
# Graph Community 18: size: 61
# Graph Community 19: size: 9
# Graph Community 20: size: 4
# Graph Community 21: size: 114
# Graph Community 22: size: 18
# Graph Community 23: size: 6
# Graph Community 24: size: 3
# Graph Community 25: size: 3
# Graph Community 26: size: 2
# Graph Community 27: size: 35
# Graph Community 28: size: 4
# Graph Community 29: size: 6
# Graph Community 30: size: 4
# Graph Community 31: size: 3
# Graph Community 32: size: 8
# Graph Community 33: size: 4
# Graph Community 34: size: 3
# Graph Community 35: size: 28
# Graph Community 36: size: 44
# Graph Community 37: size: 2
# Graph Community 38: size: 2
# Graph Community 39: size: 3
# Graph Community 40: size: 2
# Graph Community 41: size: 10
# Graph Community 42: size: 2
# Graph Community 43: size: 28
# Graph Community 44: size: 25
# Graph Community 45: size: 4
# Graph Community 46: size: 2
# Graph Community 47: size: 6
# Graph Community 48: size: 9
# Graph Community 49: size: 5
# Graph Community 50: size: 8
# Graph Community 51: size: 7
# Graph Community 52: size: 7
# Graph Community 53: size: 4
# Graph Community 55: size: 3
# Graph Community 56: size: 11
# Graph Community 57: size: 4
# Graph Community 58: size: 3
# Graph Community 59: size: 8
# Graph Community 60: size: 2
# Graph Community 61: size: 7
# Graph Community 62: size: 10
# Graph Community 63: size: 4
# Graph Community 64: size: 4
# Graph Community 65: size: 7
# Graph Community 66: size: 2
# Graph Community 67: size: 3
# Graph Community 68: size: 2
# Graph Community 69: size: 6
# Graph Community 70: size: 3
# Graph Community 71: size: 3
# Graph Community 72: size: 4
# Graph Community 73: size: 6
# Graph Community 74: size: 3
# Graph Community 75: size: 2
# Graph Community 76: size: 3
# Graph Community 77: size: 13
# Graph Community 78: size: 2
# Graph Community 79: size: 3
# Graph Community 80: size: 6
# Graph Community 81: size: 2
# Graph Community 82: size: 2
# Graph Community 83: size: 3
# Graph Community 84: size: 2
# Graph Community 85: size: 4
# Graph Community 86: size: 7
# Graph Community 87: size: 3
# Graph Community 88: size: 2
# Graph Community 89: size: 2
# Graph Community 90: size: 2
# Graph Community 91: size: 2
# Graph Community 92: size: 2
# Graph Community 93: size: 2
# Graph Community 94: size: 2
# Graph Community 95: size: 2
# Graph Community 96: size: 2
# Graph Community 97: size: 2
# Graph Community 98: size: 3
# Graph Community 99: size: 2
# Graph Community 100: size: 2
# Graph Community 101: size: 2
# Graph Community 102: size: 4
# Graph Community 103: size: 6
# Graph Community 104: size: 4
# Graph Community 105: size: 6
# Graph Community 106: size: 2
# Graph Community 107: size: 2
# Graph Community 108: size: 2
# Graph Community 109: size: 4
# Graph Community 110: size: 2
# Graph Community 111: size: 6
# Graph Community 112: size: 2
# Graph Community 113: size: 2
# Graph Community 114: size: 8
# Graph Community 115: size: 2
# Graph Community 116: size: 5
# Graph Community 117: size: 2
# Graph Community 118: size: 2
# Graph Community 119: size: 2
# Graph Community 120: size: 2
# Graph Community 121: size: 2
# Graph Community 122: size: 2
# Graph Community 123: size: 6
# Graph Community 124: size: 3
# Graph Community 125: size: 2
# Graph Community 126: size: 4
# Graph Community 127: size: 2
# Graph Community 128: size: 5
# Graph Community 129: size: 2
# Graph Community 130: size: 2
# Graph Community 131: size: 2
# Graph Community 132: size: 2
# Graph Community 133: size: 3
# Graph Community 134: size: 3
# Graph Community 135: size: 2
# Graph Community 136: size: 3
# Graph Community 137: size: 2
# Graph Community 138: size: 5
# Graph Community 139: size: 2
# Graph Community 140: size: 2
# Graph Community 141: size: 2
# Graph Community 142: size: 2
# Graph Community 143: size: 2
# Graph Community 144: size: 2
# Graph Community 145: size: 2
# Graph Community 146: size: 2
# Graph Community 147: size: 2
# Graph Community 148: size: 3
# Graph Community 149: size: 2
# Graph Community 150: size: 2
# Graph Community 151: size: 2
# Graph Community 152: size: 2
# Graph Community 2: size: 2
# Graph Community 5: size: 2
# Graph Community 9: size: 2
# Graph Community 14: size: 2
# Graph Community 17: size: 2
#
# Total Hypergraph Communities: 79
#
# Hypergraph Communitys:
# Hypergraph Community 0: size: 6
# Hypergraph Community 1: size: 7
# Hypergraph Community 2: size: 21
# Hypergraph Community 3: size: 4
# Hypergraph Community 20: size: 154
# Hypergraph Community 5: size: 4
# Hypergraph Community 6: size: 5
# Hypergraph Community 7: size: 9
# Hypergraph Community 8: size: 4
# Hypergraph Community 9: size: 35
# Hypergraph Community 10: size: 4
# Hypergraph Community 11: size: 6
# Hypergraph Community 12: size: 50
# Hypergraph Community 13: size: 4
# Hypergraph Community 14: size: 3
# Hypergraph Community 15: size: 63
# Hypergraph Community 16: size: 121
# Hypergraph Community 17: size: 4
# Hypergraph Community 18: size: 28
# Hypergraph Community 19: size: 54
# Hypergraph Community 22: size: 10
# Hypergraph Community 23: size: 28
# Hypergraph Community 24: size: 50
# Hypergraph Community 25: size: 4
# Hypergraph Community 26: size: 6
# Hypergraph Community 27: size: 9
# Hypergraph Community 28: size: 5
# Hypergraph Community 29: size: 8
# Hypergraph Community 30: size: 7
# Hypergraph Community 31: size: 6
# Hypergraph Community 32: size: 4
# Hypergraph Community 33: size: 26
# Hypergraph Community 34: size: 2
# Hypergraph Community 35: size: 3
# Hypergraph Community 36: size: 4
# Hypergraph Community 37: size: 3
# Hypergraph Community 38: size: 7
# Hypergraph Community 39: size: 8
# Hypergraph Community 40: size: 7
# Hypergraph Community 41: size: 4
# Hypergraph Community 42: size: 4
# Hypergraph Community 43: size: 3
# Hypergraph Community 44: size: 6
# Hypergraph Community 45: size: 3
# Hypergraph Community 46: size: 2
# Hypergraph Community 47: size: 3
# Hypergraph Community 48: size: 7
# Hypergraph Community 49: size: 6
# Hypergraph Community 50: size: 3
# Hypergraph Community 51: size: 13
# Hypergraph Community 52: size: 3
# Hypergraph Community 53: size: 4
# Hypergraph Community 54: size: 7
# Hypergraph Community 55: size: 3
# Hypergraph Community 56: size: 7
# Hypergraph Community 57: size: 3
# Hypergraph Community 58: size: 6
# Hypergraph Community 59: size: 6
# Hypergraph Community 60: size: 2
# Hypergraph Community 61: size: 6
# Hypergraph Community 62: size: 4
# Hypergraph Community 63: size: 8
# Hypergraph Community 64: size: 6
# Hypergraph Community 65: size: 2
# Hypergraph Community 66: size: 6
# Hypergraph Community 67: size: 4
# Hypergraph Community 68: size: 5
# Hypergraph Community 69: size: 5
# Hypergraph Community 70: size: 2
# Hypergraph Community 71: size: 3
# Hypergraph Community 72: size: 3
# Hypergraph Community 73: size: 5
# Hypergraph Community 74: size: 4
# Hypergraph Community 75: size: 2
# Hypergraph Community 76: size: 2
# Hypergraph Community 77: size: 2
# Hypergraph Community 78: size: 2
# Hypergraph Community 21: size: 2
# Hypergraph Community 4: size: 2
#
# Comparing Graph and Hypergraph Communities:
# Graph Community 0 overlaps with Hypergraph Community 0: 6 shared nodes
# Graph Community 1 overlaps with Hypergraph Community 1: 7 shared nodes
# Graph Community 3 overlaps with Hypergraph Community 2: 21 shared nodes
# Graph Community 3 overlaps with Hypergraph Community 16: 1 shared nodes
# Graph Community 4 overlaps with Hypergraph Community 3: 4 shared nodes
# Graph Community 16 overlaps with Hypergraph Community 20: 51 shared nodes
# Graph Community 6 overlaps with Hypergraph Community 20: 48 shared nodes
# Graph Community 7 overlaps with Hypergraph Community 20: 43 shared nodes
# Graph Community 8 overlaps with Hypergraph Community 24: 25 shared nodes
# Graph Community 54 overlaps with Hypergraph Community 20: 1 shared nodes
# Graph Community 54 overlaps with Hypergraph Community 33: 26 shared nodes
# Graph Community 10 overlaps with Hypergraph Community 12: 32 shared nodes
# Graph Community 10 overlaps with Hypergraph Community 16: 1 shared nodes
# Graph Community 11 overlaps with Hypergraph Community 5: 4 shared nodes
# Graph Community 12 overlaps with Hypergraph Community 6: 5 shared nodes
# Graph Community 13 overlaps with Hypergraph Community 70: 2 shared nodes
# Graph Community 18 overlaps with Hypergraph Community 15: 61 shared nodes
# Graph Community 19 overlaps with Hypergraph Community 7: 9 shared nodes
# Graph Community 20 overlaps with Hypergraph Community 8: 4 shared nodes
# Graph Community 21 overlaps with Hypergraph Community 15: 2 shared nodes
# Graph Community 21 overlaps with Hypergraph Community 16: 112 shared nodes
# Graph Community 22 overlaps with Hypergraph Community 12: 18 shared nodes
# Graph Community 23 overlaps with Hypergraph Community 31: 6 shared nodes
# Graph Community 24 overlaps with Hypergraph Community 16: 3 shared nodes
# Graph Community 25 overlaps with Hypergraph Community 16: 3 shared nodes
# Graph Community 27 overlaps with Hypergraph Community 9: 35 shared nodes
# Graph Community 28 overlaps with Hypergraph Community 10: 4 shared nodes
# Graph Community 29 overlaps with Hypergraph Community 11: 6 shared nodes
# Graph Community 30 overlaps with Hypergraph Community 13: 4 shared nodes
# Graph Community 31 overlaps with Hypergraph Community 14: 3 shared nodes
# Graph Community 32 overlaps with Hypergraph Community 16: 1 shared nodes
# Graph Community 32 overlaps with Hypergraph Community 56: 7 shared nodes
# Graph Community 33 overlaps with Hypergraph Community 17: 4 shared nodes
# Graph Community 34 overlaps with Hypergraph Community 21: 2 shared nodes
# Graph Community 35 overlaps with Hypergraph Community 18: 28 shared nodes
# Graph Community 36 overlaps with Hypergraph Community 19: 44 shared nodes
# Graph Community 39 overlaps with Hypergraph Community 35: 3 shared nodes
# Graph Community 41 overlaps with Hypergraph Community 22: 10 shared nodes
# Graph Community 43 overlaps with Hypergraph Community 23: 28 shared nodes
# Graph Community 44 overlaps with Hypergraph Community 24: 25 shared nodes
# Graph Community 45 overlaps with Hypergraph Community 25: 4 shared nodes
# Graph Community 47 overlaps with Hypergraph Community 26: 6 shared nodes
# Graph Community 48 overlaps with Hypergraph Community 27: 9 shared nodes
# Graph Community 49 overlaps with Hypergraph Community 28: 5 shared nodes
# Graph Community 50 overlaps with Hypergraph Community 29: 8 shared nodes
# Graph Community 51 overlaps with Hypergraph Community 30: 7 shared nodes
# Graph Community 52 overlaps with Hypergraph Community 38: 7 shared nodes
# Graph Community 53 overlaps with Hypergraph Community 32: 4 shared nodes
# Graph Community 55 overlaps with Hypergraph Community 34: 2 shared nodes
# Graph Community 56 overlaps with Hypergraph Community 20: 11 shared nodes
# Graph Community 57 overlaps with Hypergraph Community 36: 4 shared nodes
# Graph Community 58 overlaps with Hypergraph Community 37: 3 shared nodes
# Graph Community 59 overlaps with Hypergraph Community 39: 8 shared nodes
# Graph Community 61 overlaps with Hypergraph Community 40: 7 shared nodes
# Graph Community 62 overlaps with Hypergraph Community 19: 10 shared nodes
# Graph Community 63 overlaps with Hypergraph Community 41: 4 shared nodes
# Graph Community 64 overlaps with Hypergraph Community 42: 4 shared nodes
# Graph Community 65 overlaps with Hypergraph Community 48: 7 shared nodes
# Graph Community 67 overlaps with Hypergraph Community 43: 3 shared nodes
# Graph Community 69 overlaps with Hypergraph Community 44: 6 shared nodes
# Graph Community 70 overlaps with Hypergraph Community 45: 3 shared nodes
# Graph Community 71 overlaps with Hypergraph Community 46: 2 shared nodes
# Graph Community 72 overlaps with Hypergraph Community 47: 3 shared nodes
# Graph Community 73 overlaps with Hypergraph Community 49: 6 shared nodes
# Graph Community 74 overlaps with Hypergraph Community 77: 2 shared nodes
# Graph Community 76 overlaps with Hypergraph Community 76: 2 shared nodes
# Graph Community 77 overlaps with Hypergraph Community 51: 13 shared nodes
# Graph Community 79 overlaps with Hypergraph Community 50: 3 shared nodes
# Graph Community 80 overlaps with Hypergraph Community 58: 6 shared nodes
# Graph Community 83 overlaps with Hypergraph Community 52: 3 shared nodes
# Graph Community 85 overlaps with Hypergraph Community 53: 4 shared nodes
# Graph Community 86 overlaps with Hypergraph Community 54: 7 shared nodes
# Graph Community 87 overlaps with Hypergraph Community 55: 3 shared nodes
# Graph Community 98 overlaps with Hypergraph Community 57: 3 shared nodes
# Graph Community 102 overlaps with Hypergraph Community 74: 4 shared nodes
# Graph Community 103 overlaps with Hypergraph Community 59: 6 shared nodes
# Graph Community 104 overlaps with Hypergraph Community 60: 2 shared nodes
# Graph Community 104 overlaps with Hypergraph Community 65: 2 shared nodes
# Graph Community 105 overlaps with Hypergraph Community 61: 6 shared nodes
# Graph Community 109 overlaps with Hypergraph Community 62: 4 shared nodes
# Graph Community 111 overlaps with Hypergraph Community 64: 6 shared nodes
# Graph Community 114 overlaps with Hypergraph Community 63: 8 shared nodes
# Graph Community 116 overlaps with Hypergraph Community 68: 5 shared nodes
# Graph Community 123 overlaps with Hypergraph Community 66: 6 shared nodes
# Graph Community 124 overlaps with Hypergraph Community 4: 2 shared nodes
# Graph Community 126 overlaps with Hypergraph Community 67: 4 shared nodes
# Graph Community 128 overlaps with Hypergraph Community 69: 5 shared nodes
# Graph Community 133 overlaps with Hypergraph Community 75: 2 shared nodes
# Graph Community 134 overlaps with Hypergraph Community 71: 3 shared nodes
# Graph Community 136 overlaps with Hypergraph Community 72: 3 shared nodes
# Graph Community 138 overlaps with Hypergraph Community 73: 5 shared nodes
# Graph Community 148 overlaps with Hypergraph Community 78: 2 shared nodes
#
# Evaluation Metrics:
# NMI: 0.9457
# ARI: 0.7263
# Precision: 0.0157
# Recall: 0.0157
# F1 Score: 0.0157
# Homogeneity: 0.9041
# Completeness: 0.9914
# V-measure: 0.9457
